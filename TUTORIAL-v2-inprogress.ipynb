# %%
import synthpop 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pdb

# %%
mod2=0
mod2 = synthpop.SynthPop('huston2025_defaults.synthpop_conf',
                         extinction_map_kwargs={'name':'maps_from_dustmaps', 
                                                'dustmap_name': 'marshall'},
                         chosen_bands = ['Bessell_V','Bessell_I', '2MASS_Ks'],
                         maglim = ['Bessell_I', 99, "keep"],
                         multiplicity_kwargs={"name":"Raghavan"},
                         post_processing_kwargs=None, #[{"name": "CombineTables"}],
                         name_for_output='mod2test',
                         combine_system_mags = True,
                        )
# Out:
#  4320 - Execution Date: 2025-11-21 11:51:26
#
#
# ################################ Settings #################################
#  4335 - # reading default parameters from
#  4337 - default_config_file =  /System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/config_files/_default.synthpop_conf
#  4356 - # read configuration from
#  4358 - config_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/config_files/huston2025_defaults.synthpop_conf'
#
#
# # copy the following to a config file to redo this model generation -------
#  4374 - {
#     "l_set": null,
#     "l_set_type": null,
#     "b_set": null,
#     "b_set_type": null,
#     "name_for_output": "mod2test",
#     "model_name": "Huston2025",
#     "field_shape": "circle",
#     "field_scale": null,
#     "field_scale_unit": "deg",
#     "random_seed": 380226455,
#     "sun": {
#         "x": -8.178,
#         "y": 0.0,
#         "z": 0.017,
#         "u": 12.9,
#         "v": 245.6,
#         "w": 7.78,
#         "l_apex_deg": 56.24,
#         "b_apex_deg": 22.54
#     },
#     "lsr": {
#         "u_lsr": 1.8,
#         "v_lsr": 233.4,
#         "w_lsr": 0.53
#     },
#     "warp": {
#         "r_warp": 7.72,
#         "amp_warp": 0.06,
#         "amp_warp_pos": null,
#         "amp_warp_neg": null,
#         "alpha_warp": 1.33,
#         "phi_warp_deg": 17.5
#     },
#     "max_distance": 25,
#     "distance_step_size": 0.1,
#     "mass_lims": {
#         "min_mass": 0.08,
#         "max_mass": 100
#     },
#     "N_mc_totmass": 10000,
#     "lost_mass_option": 1,
#     "N_av_mass": 50000,
#     "kinematics_at_the_end": false,
#     "scale_factor": 1,
#     "skip_lowmass_stars": false,
#     "chunk_size": 250000,
#     "star_generator": "StarGenerator",
#     "extinction_map_kwargs": {
#         "name": "maps_from_dustmaps",
#         "dustmap_name": "marshall"
#     },
#     "extinction_law_kwargs": [
#         {
#             "name": "SODC",
#             "R_V": 2.5
#         }
#     ],
#     "evolution_class": {
#         "name": "MIST",
#         "interpolator": "CharonInterpolator"
#     },
#     "ifmr_kwargs": {
#         "name": "PopsycleIfmrs",
#         "ifmr_name": "SukhboldN20"
#     },
#     "multiplicity_kwargs": {
#         "name": "Raghavan"
#     },
#     "maglim": [
#         "Bessell_I",
#         99,
#         "keep"
#     ],
#     "chosen_bands": [
#         "Bessell_V",
#         "Bessell_I",
#         "2MASS_Ks"
#     ],
#     "obsmag": true,
#     "combine_system_mags": true,
#     "opt_iso_props": [
#         "log_L",
#         "log_Teff",
#         "log_g",
#         "[Fe/H]",
#         "log_R",
#         "phase"
#     ],
#     "post_processing_kwargs": null,
#     "output_location": "outputfiles/default",
#     "output_filename_pattern": "{name_for_output}_l{l_deg:.3f}_b{b_deg:.3f}",
#     "output_file_type": "csv",
#     "overwrite": true
# }
#  4375 - Location or solid_angle_sr are not  defined in the settings! Can not run main() or process_all()

# %%
mod2.init_populations()
# Out:
# ######################### Initialize populations ##########################
#  4421 - read Population files from Huston2025
#
#
# # Population 0;  bulge ----------------------------------------------------
#  4436 - # Initialize Population 0 (bulge) from
#  4437 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/bulge.popjson'
#
#
# # Population 1;  halo -----------------------------------------------------
#  15368 - # Initialize Population 1 (halo) from
#  15370 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/halo.popjson'
#
#
# # Population 2;  nsd ------------------------------------------------------
#  16722 - # Initialize Population 2 (nsd) from
#  16723 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/nsd.popjson'
#
#
# # Population 3;  thick_disk -----------------------------------------------
#  18928 - # Initialize Population 3 (thick_disk) from
#  18929 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thick_disk.popjson'
#
#
# # Population 4;  thin_disk_1 ----------------------------------------------
#  20263 - # Initialize Population 4 (thin_disk_1) from
#  20265 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thin_disk_1.popjson'
#
#
# # Population 5;  thin_disk_2 ----------------------------------------------
#  21649 - # Initialize Population 5 (thin_disk_2) from
#  21651 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thin_disk_2.popjson'
#
#
# # Population 6;  thin_disk_3 ----------------------------------------------
#  22944 - # Initialize Population 6 (thin_disk_3) from
#  22946 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thin_disk_3.popjson'
#
#
# # Population 7;  thin_disk_4 ----------------------------------------------
#  24280 - # Initialize Population 7 (thin_disk_4) from
#  24282 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thin_disk_4.popjson'
#
#
# # Population 8;  thin_disk_5 ----------------------------------------------
#  25544 - # Initialize Population 8 (thin_disk_5) from
#  25546 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thin_disk_5.popjson'
#
#
# # Population 9;  thin_disk_6 ----------------------------------------------
#  26829 - # Initialize Population 9 (thin_disk_6) from
#  26831 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thin_disk_6.popjson'
#
#
# # Population 10;  thin_disk_7 ---------------------------------------------
#  28102 - # Initialize Population 10 (thin_disk_7) from
#  28104 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thin_disk_7.popjson'
#  29373 - # All populations are initialized

# %%
systems, companions = mod2.process_location(l_deg=3, b_deg=-1, field_shape='circle', field_scale=0.003, field_scale_unit='deg')
# Out:
#  29437 - Execution Date: 2025-11-21 11:51:51
#
#
# ################################ Settings #################################
#
#
# # Copy the following to a config file to redo this model generation: ------
#  29440 - {
#     "l_set": [
#         3
#     ],
#     "l_set_type": "pairs",
#     "b_set": [
#         -1
#     ],
#     "b_set_type": "pairs",
#     "name_for_output": "mod2test",
#     "model_name": "Huston2025",
#     "field_shape": "circle",
#     "field_scale": 0.003,
#     "field_scale_unit": "deg",
#     "random_seed": 380226455,
#     "sun": {
#         "x": -8.178,
#         "y": 0.0,
#         "z": 0.017,
#         "u": 12.9,
#         "v": 245.6,
#         "w": 7.78,
#         "l_apex_deg": 56.24,
#         "b_apex_deg": 22.54
#     },
#     "lsr": {
#         "u_lsr": 1.8,
#         "v_lsr": 233.4,
#         "w_lsr": 0.53
#     },
#     "warp": {
#         "r_warp": 7.72,
#         "amp_warp": 0.06,
#         "amp_warp_pos": null,
#         "amp_warp_neg": null,
#         "alpha_warp": 1.33,
#         "phi_warp_deg": 17.5
#     },
#     "max_distance": 25,
#     "distance_step_size": 0.1,
#     "mass_lims": {
#         "min_mass": 0.08,
#         "max_mass": 100
#     },
#     "N_mc_totmass": 10000,
#     "lost_mass_option": 1,
#     "N_av_mass": 50000,
#     "kinematics_at_the_end": false,
#     "scale_factor": 1,
#     "skip_lowmass_stars": false,
#     "chunk_size": 250000,
#     "star_generator": "StarGenerator",
#     "extinction_map_kwargs": {
#         "name": "maps_from_dustmaps",
#         "dustmap_name": "marshall"
#     },
#     "extinction_law_kwargs": [
#         {
#             "name": "SODC",
#             "R_V": 2.5
#         }
#     ],
#     "evolution_class": {
#         "name": "MIST",
#         "interpolator": "CharonInterpolator"
#     },
#     "ifmr_kwargs": {
#         "name": "PopsycleIfmrs",
#         "ifmr_name": "SukhboldN20"
#     },
#     "multiplicity_kwargs": {
#         "name": "Raghavan"
#     },
#     "maglim": [
#         "Bessell_I",
#         99,
#         "keep"
#     ],
#     "chosen_bands": [
#         "Bessell_V",
#         "Bessell_I",
#         "2MASS_Ks"
#     ],
#     "obsmag": true,
#     "combine_system_mags": true,
#     "opt_iso_props": [
#         "log_L",
#         "log_Teff",
#         "log_g",
#         "[Fe/H]",
#         "log_R",
#         "phase"
#     ],
#     "post_processing_kwargs": null,
#     "output_location": "outputfiles/default",
#     "output_filename_pattern": "{name_for_output}_l{l_deg:.3f}_b{b_deg:.3f}",
#     "output_file_type": "csv",
#     "overwrite": true
# }
#
#
# ############################# Update location #############################
#  29443 - # set location to:
#  29446 - l, b = (3.00 deg, -1.00 deg)
#  29449 - # set field scale to:
#  29453 - field_scale = 3.000e-03 deg
#
#
# ############################# Generate Field ##############################
#
#
# # Population 0;  bulge ----------------------------------------------------
#  47151 - # From density profile (number density)
#  47160 - expected_total_iMass = 4400.7425
#  47170 - expected_total_eMass = 3621.5266
#  47177 - average_iMass_per_star = 0.5739
#  47188 - mass_loss_correction = 0.8229
#  47199 - n_expected_stars = 7668.5896
#  47213 - # Determine velocities when position are generated
#  49033 - # From Generated Field:
#  49036 - generated_stars = 7635
#  49040 - generated_total_iMass = 4257.0689
#  49052 - generated_total_eMass = 2561.2031
#  49056 - det_mass_loss_corr = 0.6016
#  49061 - # Done
#
#
# # Population 1;  halo -----------------------------------------------------
#  50040 - # From density profile (number density)
#  50044 - expected_total_iMass = 8.3883
#  50048 - expected_total_eMass = 6.6051
#  50051 - average_iMass_per_star = 0.5739
#  50055 - mass_loss_correction = 0.7874
#  50058 - n_expected_stars = 14.6171
#  50080 - # Determine velocities when position are generated
#  50195 - # From Generated Field:
#  50198 - generated_stars = 14
#  50202 - generated_total_iMass = 6.5141
#  50213 - generated_total_eMass = 4.6329
#  50216 - det_mass_loss_corr = 0.7112
#  50221 - # Done
#
#
# # Population 2;  nsd ------------------------------------------------------
#  52032 - # From density profile (number density)
#  52036 - expected_total_iMass = 15.8170
#  52039 - expected_total_eMass = 13.3383
#  52042 - average_iMass_per_star = 0.5739
#  52045 - mass_loss_correction = 0.8433
#  52048 - n_expected_stars = 27.5623
#  52054 - # Determine velocities when position are generated
#  52529 - # From Generated Field:
#  52532 - generated_stars = 21
#  52535 - generated_total_iMass = 8.6005
#  52547 - generated_total_eMass = 6.1213
#  52551 - det_mass_loss_corr = 0.7117
#  52555 - # Done
#
#
# # Population 3;  thick_disk -----------------------------------------------
#  53500 - # From density profile (number density)
#  53515 - expected_total_iMass = 87.0797
#  53529 - expected_total_eMass = 70.9400
#  53547 - average_iMass_per_star = 0.5739
#  53558 - mass_loss_correction = 0.8147
#  53578 - n_expected_stars = 151.7423
#  53584 - # Determine velocities when position are generated
#  53767 - # From Generated Field:
#  53769 - generated_stars = 150
#  53772 - generated_total_iMass = 99.0026
#  53797 - generated_total_eMass = 45.8238
#  53804 - det_mass_loss_corr = 0.4629
#  53809 - # Done
#
#
# # Population 4;  thin_disk_1 ----------------------------------------------
#  54745 - # From density profile (number density)
#  54748 - expected_total_iMass = 1.1933
#  54752 - expected_total_eMass = 1.3322
#  54760 - average_iMass_per_star = 0.5739
#  54774 - mass_loss_correction = 1.1164
#  54792 - n_expected_stars = 2.0794
#  54822 - # Determine velocities when position are generated
# /System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/star_generator.py:190: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   star_systems.loc[unique_pris,"n_companions"] = comp_count
#  54917 - # From Generated Field:
#  54920 - generated_stars = 2
#  54923 - generated_total_iMass = 0.2260
#  54933 - generated_total_eMass = 0.2260
#  54937 - det_mass_loss_corr = 1.0000
#  54942 - # Done
#
#
# # Population 5;  thin_disk_2 ----------------------------------------------
#  55927 - # From density profile (number density)
#  55931 - expected_total_iMass = 22.6254
#  55934 - expected_total_eMass = 22.4114
#  55937 - average_iMass_per_star = 0.5739
#  55940 - mass_loss_correction = 0.9905
#  55942 - n_expected_stars = 39.4262
#  55952 - # Determine velocities when position are generated
#  56227 - # From Generated Field:
#  56238 - generated_stars = 40
#  56250 - generated_total_iMass = 57.5969
#  56268 - generated_total_eMass = 23.5340
#  56271 - det_mass_loss_corr = 0.4086
#  56276 - # Done
#
#
# # Population 6;  thin_disk_3 ----------------------------------------------
#  57269 - # From density profile (number density)
#  57273 - expected_total_iMass = 57.7528
#  57276 - expected_total_eMass = 53.5514
#  57279 - average_iMass_per_star = 0.5739
#  57283 - mass_loss_correction = 0.9273
#  57286 - n_expected_stars = 100.6382
#  57292 - # Determine velocities when position are generated
#  57569 - # From Generated Field:
#  57572 - generated_stars = 111
#  57575 - generated_total_iMass = 52.5966
#  57586 - generated_total_eMass = 44.0666
#  57590 - det_mass_loss_corr = 0.8378
#  57595 - # Done
#
#
# # Population 7;  thin_disk_4 ----------------------------------------------
#  58459 - # From density profile (number density)
#  58463 - expected_total_iMass = 82.7505
#  58466 - expected_total_eMass = 72.7281
#  58469 - average_iMass_per_star = 0.5739
#  58472 - mass_loss_correction = 0.8789
#  58475 - n_expected_stars = 144.1982
#  58481 - # Determine velocities when position are generated
#  58718 - # From Generated Field:
#  58725 - generated_stars = 133
#  58732 - generated_total_iMass = 66.1153
#  58745 - generated_total_eMass = 52.0916
#  58751 - det_mass_loss_corr = 0.7879
#  58775 - # Done
#
#
# # Population 8;  thin_disk_5 ----------------------------------------------
#  59680 - # From density profile (number density)
#  59684 - expected_total_iMass = 218.1929
#  59687 - expected_total_eMass = 189.5555
#  59690 - average_iMass_per_star = 0.5739
#  59693 - mass_loss_correction = 0.8688
#  59697 - n_expected_stars = 380.2159
#  59703 - # Determine velocities when position are generated
#  60126 - # From Generated Field:
#  60129 - generated_stars = 378
#  60133 - generated_total_iMass = 184.6965
#  60144 - generated_total_eMass = 134.9196
#  60147 - det_mass_loss_corr = 0.7305
#  60152 - # Done
#
#
# # Population 9;  thin_disk_6 ----------------------------------------------
#  61059 - # From density profile (number density)
#  61063 - expected_total_iMass = 284.8993
#  61067 - expected_total_eMass = 242.0200
#  61070 - average_iMass_per_star = 0.5739
#  61073 - mass_loss_correction = 0.8495
#  61076 - n_expected_stars = 496.4563
#  61082 - # Determine velocities when position are generated
#  61455 - # From Generated Field:
#  61459 - generated_stars = 472
#  61462 - generated_total_iMass = 293.0814
#  61474 - generated_total_eMass = 173.9077
#  61478 - det_mass_loss_corr = 0.5934
#  61491 - # Done
#
#
# # Population 10;  thin_disk_7 ---------------------------------------------
#  62333 - # From density profile (number density)
#  62337 - expected_total_iMass = 601.7560
#  62340 - expected_total_eMass = 501.9234
#  62344 - average_iMass_per_star = 0.5739
#  62347 - mass_loss_correction = 0.8341
#  62350 - n_expected_stars = 1048.6004
#  62356 - # Determine velocities when position are generated
#  62965 - # From Generated Field:
#  62969 - generated_stars = 1103
#  62972 - generated_total_iMass = 609.8991
#  62983 - generated_total_eMass = 362.0617
#  62987 - det_mass_loss_corr = 0.5936
#  62991 - # Done
#
#
# ########################### Combine Populations ###########################
#  62999 - Number of star systems generated: 10059 (32 columns)
#  63002 - included_columns = ['iMass', 'age', 'Fe/H_initial', 'n_companions', 'system_idx', 'Mass', 'system_Mass', 'log_R', 'log_Teff', 'log_g', '[Fe/H]', 'Bessell_V', 'phase', 'star_mass', 'log_L', 'Bessell_I', '2MASS_Ks', 'x', 'y', 'z', 'Dist', 'l', 'b', 'vr_bc', 'mul', 'mub', 'U', 'V', 'W', 'VR_LSR', 'A_Ks', 'pop']
#
#
# # Save result -------------------------------------------------------------
#  63006 - write result to "outputfiles/default/mod2test_l3.000_b-1.000.csv"
#  63484 - write result to "outputfiles/default/mod2test_l3.000_b-1.000_companions.csv"
#  63662 - ---------------------------------------------------------------

# %%
# systems1, companions1 = mod2.process_location(l_deg=4, b_deg=-1, field_shape='circle', field_scale=0.003, field_scale_unit='deg')

# %%
systems.loc[0,'Mass']
# Out:
# 0.0934745111841959

# %%
systems.index[systems.Mass>0.2]
# Out:
# Int64Index([    1,     2,     3,     4,     5,     7,    13,    15,    17,
#                19,
#             ...
#             10038, 10039, 10040, 10041, 10044, 10047, 10048, 10050, 10054,
#             10056],
#            dtype='int64', length=5683)

# %%
companions
# Out:
#          iMass      Mass  system_idx        period  eccentricity     log_R  \
# 0     0.063880  0.063880           0  1.467130e+08      0.826024  0.063880
# 1     1.027926  0.506044           2  1.313642e+04      0.553322       NaN
# 2     0.197658  0.197655           3  2.111636e+02      0.564809 -0.675096
# 3     1.004350  1.003841           4  3.803902e+06      0.419272  0.163105
# 4     1.637710  0.572510           5  2.440525e+07      0.265501       NaN
# ...        ...       ...         ...           ...           ...       ...
# 7189  0.041171  0.041171       10053  3.790944e+05      0.433338  0.041171
# 7190  0.219641  0.219638       10054  8.018069e+04      0.115206 -0.641339
# 7191  0.150608  0.150606       10056  4.599617e+06      0.026405 -0.754949
# 7192  0.124900  0.124899       10057  1.715222e+04      0.448054 -0.845663
# 7193  0.067286  0.067286       10058  1.663734e+03      0.731877  0.067286
#
#       log_Teff     log_g    [Fe/H]  Bessell_V       phase  star_mass  \
# 0     0.063880  0.063880  0.063880  24.685616    0.063880   0.063880
# 1          NaN       NaN       NaN        NaN  101.000000   0.506044
# 2     3.556732  5.083596 -0.478462  36.478334    0.000000   0.197655
# 3     3.755119  4.113470  0.011344  29.800998    0.000000   1.003841
# 4          NaN       NaN       NaN        NaN  101.000000   0.572510
# ...        ...       ...       ...        ...         ...        ...
# 7189  0.041171  0.041171  0.041171  33.391087    0.041171   0.041171
# 7190  3.557052  5.059917 -0.432071  49.528831    0.000000   0.219638
# 7191  3.506426  5.125346 -0.073233  51.675053    0.000000   0.150606
# 7192  3.512496  5.217163 -0.369462  51.844309    0.000000   0.124899
# 7193  0.067286  0.067286  0.067286  44.271720    0.067286   0.067286
#
#          log_L  Bessell_I   2MASS_Ks  pop
# 0     0.063880  19.872128  14.311787    0
# 1          NaN        NaN        NaN    0
# 2    -2.168621  29.647680  21.985306    0
# 3     0.301332  23.823428  16.916136    0
# 4          NaN        NaN        NaN    0
# ...        ...        ...        ...  ...
# 7189  0.041171  26.114575  17.709051   10
# 7190 -2.099825  38.223231  25.401810   10
# 7191 -2.529549  39.600672  26.400402   10
# 7192 -2.686696  39.937520  26.801461   10
# 7193  0.067286  32.346121  18.570167   10
#
# [7194 rows x 16 columns]

# %%
np.sum(systems['Mass']) + np.sum(companions['Mass']), np.sum(systems['system_Mass'])
# Out:
# (4785.730781480908, 4785.730781480908)

# %%
mod2.populations[0].av_mass_corr #, mod0.populations[0].av_mass_corr
# Out:
# 0.8229353614749315

# %%
import synthpop 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pdb

# %%
mod0=0
mod0 = synthpop.SynthPop('huston2025_defaults.synthpop_conf',
                         extinction_map_kwargs={'name':'maps_from_dustmaps', 
                                                'dustmap_name': 'marshall'},
                         chosen_bands = ['Bessell_U', 'Bessell_B', 'Bessell_V', 'Bessell_R', 'Bessell_I'],
                         maglim = ['Bessell_I', 99, "keep"],
                         #multiplicity_kwargs={"name":"Raghavan"},
                         #post_processing_kwargs=[{"name": "DeriveBinaryParameters"}],
                         name_for_output='mod0test',
                         field_shape='circle', field_scale_unit='deg'
                        )
# Out:
# ################################ Settings #################################
#  74513 - # reading default parameters from
#  74516 - default_config_file =  /System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/config_files/_default.synthpop_conf
#  74520 - # read configuration from
#  74524 - config_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/config_files/huston2025_defaults.synthpop_conf'
#
#
# # copy the following to a config file to redo this model generation -------
#  74528 - {
#     "l_set": null,
#     "l_set_type": null,
#     "b_set": null,
#     "b_set_type": null,
#     "name_for_output": "mod0test",
#     "model_name": "Huston2025",
#     "field_shape": "circle",
#     "field_scale": null,
#     "field_scale_unit": "deg",
#     "random_seed": 609145378,
#     "sun": {
#         "x": -8.178,
#         "y": 0.0,
#         "z": 0.017,
#         "u": 12.9,
#         "v": 245.6,
#         "w": 7.78,
#         "l_apex_deg": 56.24,
#         "b_apex_deg": 22.54
#     },
#     "lsr": {
#         "u_lsr": 1.8,
#         "v_lsr": 233.4,
#         "w_lsr": 0.53
#     },
#     "warp": {
#         "r_warp": 7.72,
#         "amp_warp": 0.06,
#         "amp_warp_pos": null,
#         "amp_warp_neg": null,
#         "alpha_warp": 1.33,
#         "phi_warp_deg": 17.5
#     },
#     "max_distance": 25,
#     "distance_step_size": 0.1,
#     "mass_lims": {
#         "min_mass": 0.08,
#         "max_mass": 100
#     },
#     "N_mc_totmass": 10000,
#     "lost_mass_option": 1,
#     "N_av_mass": 50000,
#     "kinematics_at_the_end": false,
#     "scale_factor": 1,
#     "skip_lowmass_stars": false,
#     "chunk_size": 250000,
#     "star_generator": "StarGenerator",
#     "extinction_map_kwargs": {
#         "name": "maps_from_dustmaps",
#         "dustmap_name": "marshall"
#     },
#     "extinction_law_kwargs": [
#         {
#             "name": "SODC",
#             "R_V": 2.5
#         }
#     ],
#     "evolution_class": {
#         "name": "MIST",
#         "interpolator": "CharonInterpolator"
#     },
#     "ifmr_kwargs": {
#         "name": "PopsycleIfmrs",
#         "ifmr_name": "SukhboldN20"
#     },
#     "multiplicity_kwargs": null,
#     "maglim": [
#         "Bessell_I",
#         99,
#         "keep"
#     ],
#     "chosen_bands": [
#         "Bessell_U",
#         "Bessell_B",
#         "Bessell_V",
#         "Bessell_R",
#         "Bessell_I"
#     ],
#     "obsmag": true,
#     "combine_system_mags": false,
#     "opt_iso_props": [
#         "log_L",
#         "log_Teff",
#         "log_g",
#         "[Fe/H]",
#         "log_R",
#         "phase"
#     ],
#     "post_processing_kwargs": [
#         {
#             "name": "ConvertMistMags",
#             "conversions": {
#                 "AB": [
#                     "R062",
#                     "Z087",
#                     "Y106",
#                     "J129",
#                     "W146",
#                     "H158",
#                     "F184"
#                 ]
#             }
#         },
#         {
#             "name": "RenameColumns",
#             "old_names": [
#                 "log_L",
#                 "log_Teff",
#                 "log_g",
#                 "[Fe/H]",
#                 "log_R"
#             ],
#             "new_names": [
#                 "logL",
#                 "logTeff",
#                 "logg",
#                 "Fe/H_evolved",
#                 "log_radius"
#             ]
#         }
#     ],
#     "output_location": "outputfiles/default",
#     "output_filename_pattern": "{name_for_output}_l{l_deg:.3f}_b{b_deg:.3f}",
#     "output_file_type": "csv",
#     "overwrite": true
# }
#  74531 - Location or solid_angle_sr are not  defined in the settings! Can not run main() or process_all()

# %%
mod0.init_populations()
# Out:
# ######################### Initialize populations ##########################
#  76361 - read Population files from Huston2025
#
#
# # Population 0;  bulge ----------------------------------------------------
#  76370 - # Initialize Population 0 (bulge) from
#  76374 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/bulge.popjson'
#
#
# # Population 1;  halo -----------------------------------------------------
#  79081 - # Initialize Population 1 (halo) from
#  79084 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/halo.popjson'
#
#
# # Population 2;  nsd ------------------------------------------------------
#  80407 - # Initialize Population 2 (nsd) from
#  80410 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/nsd.popjson'
#
#
# # Population 3;  thick_disk -----------------------------------------------
#  82592 - # Initialize Population 3 (thick_disk) from
#  82595 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thick_disk.popjson'
#
#
# # Population 4;  thin_disk_1 ----------------------------------------------
#  83939 - # Initialize Population 4 (thin_disk_1) from
#  83942 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thin_disk_1.popjson'
#
#
# # Population 5;  thin_disk_2 ----------------------------------------------
#  85205 - # Initialize Population 5 (thin_disk_2) from
#  85208 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thin_disk_2.popjson'
#
#
# # Population 6;  thin_disk_3 ----------------------------------------------
#  86575 - # Initialize Population 6 (thin_disk_3) from
#  86578 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thin_disk_3.popjson'
#
#
# # Population 7;  thin_disk_4 ----------------------------------------------
#  87870 - # Initialize Population 7 (thin_disk_4) from
#  87873 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thin_disk_4.popjson'
#
#
# # Population 8;  thin_disk_5 ----------------------------------------------
#  89150 - # Initialize Population 8 (thin_disk_5) from
#  89153 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thin_disk_5.popjson'
#
#
# # Population 9;  thin_disk_6 ----------------------------------------------
#  90437 - # Initialize Population 9 (thin_disk_6) from
#  90440 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thin_disk_6.popjson'
#
#
# # Population 10;  thin_disk_7 ---------------------------------------------
#  91721 - # Initialize Population 10 (thin_disk_7) from
#  91724 - pop_file = '/System/Volumes/Data/mnt/g2/scratch/mhuston/code/synthpop/synthpop/models/Huston2025/thin_disk_7.popjson'
#  93009 - # All populations are initialized

# %%
systems2, companions2 = mod0.process_location(l_deg=3, b_deg=-1, field_scale=0.003)
# Out:
#  93061 - Execution Date: 2025-11-21 11:52:55
#
#
# ################################ Settings #################################
#
#
# # Copy the following to a config file to redo this model generation: ------
#  93063 - {
#     "l_set": [
#         3
#     ],
#     "l_set_type": "pairs",
#     "b_set": [
#         -1
#     ],
#     "b_set_type": "pairs",
#     "name_for_output": "mod0test",
#     "model_name": "Huston2025",
#     "field_shape": "circle",
#     "field_scale": 0.003,
#     "field_scale_unit": "deg",
#     "random_seed": 609145378,
#     "sun": {
#         "x": -8.178,
#         "y": 0.0,
#         "z": 0.017,
#         "u": 12.9,
#         "v": 245.6,
#         "w": 7.78,
#         "l_apex_deg": 56.24,
#         "b_apex_deg": 22.54
#     },
#     "lsr": {
#         "u_lsr": 1.8,
#         "v_lsr": 233.4,
#         "w_lsr": 0.53
#     },
#     "warp": {
#         "r_warp": 7.72,
#         "amp_warp": 0.06,
#         "amp_warp_pos": null,
#         "amp_warp_neg": null,
#         "alpha_warp": 1.33,
#         "phi_warp_deg": 17.5
#     },
#     "max_distance": 25,
#     "distance_step_size": 0.1,
#     "mass_lims": {
#         "min_mass": 0.08,
#         "max_mass": 100
#     },
#     "N_mc_totmass": 10000,
#     "lost_mass_option": 1,
#     "N_av_mass": 50000,
#     "kinematics_at_the_end": false,
#     "scale_factor": 1,
#     "skip_lowmass_stars": false,
#     "chunk_size": 250000,
#     "star_generator": "StarGenerator",
#     "extinction_map_kwargs": {
#         "name": "maps_from_dustmaps",
#         "dustmap_name": "marshall"
#     },
#     "extinction_law_kwargs": [
#         {
#             "name": "SODC",
#             "R_V": 2.5
#         }
#     ],
#     "evolution_class": {
#         "name": "MIST",
#         "interpolator": "CharonInterpolator"
#     },
#     "ifmr_kwargs": {
#         "name": "PopsycleIfmrs",
#         "ifmr_name": "SukhboldN20"
#     },
#     "multiplicity_kwargs": null,
#     "maglim": [
#         "Bessell_I",
#         99,
#         "keep"
#     ],
#     "chosen_bands": [
#         "Bessell_U",
#         "Bessell_B",
#         "Bessell_V",
#         "Bessell_R",
#         "Bessell_I"
#     ],
#     "obsmag": true,
#     "combine_system_mags": false,
#     "opt_iso_props": [
#         "log_L",
#         "log_Teff",
#         "log_g",
#         "[Fe/H]",
#         "log_R",
#         "phase"
#     ],
#     "post_processing_kwargs": [
#         {
#             "name": "ConvertMistMags",
#             "conversions": {
#                 "AB": [
#                     "R062",
#                     "Z087",
#                     "Y106",
#                     "J129",
#                     "W146",
#                     "H158",
#                     "F184"
#                 ]
#             }
#         },
#         {
#             "name": "RenameColumns",
#             "old_names": [
#                 "log_L",
#                 "log_Teff",
#                 "log_g",
#                 "[Fe/H]",
#                 "log_R"
#             ],
#             "new_names": [
#                 "logL",
#                 "logTeff",
#                 "logg",
#                 "Fe/H_evolved",
#                 "log_radius"
#             ]
#         }
#     ],
#     "output_location": "outputfiles/default",
#     "output_filename_pattern": "{name_for_output}_l{l_deg:.3f}_b{b_deg:.3f}",
#     "output_file_type": "csv",
#     "overwrite": true
# }
#
#
# ############################# Update location #############################
#  93066 - # set location to:
#  93071 - l, b = (3.00 deg, -1.00 deg)
#  93074 - # set field scale to:
#  93077 - field_scale = 3.000e-03 deg
#
#
# ############################# Generate Field ##############################
#
#
# # Population 0;  bulge ----------------------------------------------------
#  105577 - # From density profile (number density)
#  105580 - expected_total_iMass = 6147.2237
#  105583 - expected_total_eMass = 3621.5453
#  105586 - average_iMass_per_star = 0.5739
#  105589 - mass_loss_correction = 0.5891
#  105592 - n_expected_stars = 10711.9506
#  105598 - # Determine velocities when position are generated
#  105865 - # From Generated Field:
#  105868 - generated_stars = 10713
#  105872 - generated_total_iMass = 6211.6652
#  105883 - generated_total_eMass = 3652.3387
#  105886 - det_mass_loss_corr = 0.5880
#  105890 - # Done
#
#
# # Population 1;  halo -----------------------------------------------------
#  106534 - # From density profile (number density)
#  106537 - expected_total_iMass = 11.5904
#  106540 - expected_total_eMass = 6.6049
#  106543 - average_iMass_per_star = 0.5739
#  106546 - mass_loss_correction = 0.5699
#  106550 - n_expected_stars = 20.1970
#  106556 - # Determine velocities when position are generated
#  106645 - # From Generated Field:
#  106649 - generated_stars = 20
#  106652 - generated_total_iMass = 10.5086
#  106662 - generated_total_eMass = 5.8249
#  106666 - det_mass_loss_corr = 0.5543
#  106671 - # Done
#
#
# # Population 2;  nsd ------------------------------------------------------
#  108214 - # From density profile (number density)
#  108217 - expected_total_iMass = 22.7157
#  108220 - expected_total_eMass = 13.3438
#  108223 - average_iMass_per_star = 0.5739
#  108226 - mass_loss_correction = 0.5874
#  108228 - n_expected_stars = 39.5836
#  108234 - # Determine velocities when position are generated
#  108686 - # From Generated Field:
#  108689 - generated_stars = 40
#  108692 - generated_total_iMass = 24.2011
#  108704 - generated_total_eMass = 14.0654
#  108708 - det_mass_loss_corr = 0.5812
#  108712 - # Done
#
#
# # Population 3;  thick_disk -----------------------------------------------
#  109356 - # From density profile (number density)
#  109360 - expected_total_iMass = 121.6180
#  109363 - expected_total_eMass = 70.9397
#  109366 - average_iMass_per_star = 0.5739
#  109368 - mass_loss_correction = 0.5833
#  109372 - n_expected_stars = 211.9276
#  109390 - # Determine velocities when position are generated
#  109503 - # From Generated Field:
#  109507 - generated_stars = 209
#  109510 - generated_total_iMass = 126.8175
#  109539 - generated_total_eMass = 75.8525
#  109543 - det_mass_loss_corr = 0.5981
#  109548 - # Done
#
#
# # Population 4;  thin_disk_1 ----------------------------------------------
#  110222 - # From density profile (number density)
#  110225 - expected_total_iMass = 1.5977
#  110228 - expected_total_eMass = 1.3323
#  110232 - average_iMass_per_star = 0.5739
#  110236 - mass_loss_correction = 0.8339
#  110239 - n_expected_stars = 2.7840
#  110245 - # Determine velocities when position are generated
#  110298 - # From Generated Field:
#  110302 - generated_stars = 2
#  110306 - generated_total_iMass = 0.3997
#  110316 - generated_total_eMass = 0.3997
#  110319 - det_mass_loss_corr = 1.0000
#  110324 - # Done
#
#
# # Population 5;  thin_disk_2 ----------------------------------------------
#  110999 - # From density profile (number density)
#  111002 - expected_total_iMass = 31.5560
#  111005 - expected_total_eMass = 22.4110
#  111009 - average_iMass_per_star = 0.5739
#  111013 - mass_loss_correction = 0.7102
#  111017 - n_expected_stars = 54.9885
#  111023 - # Determine velocities when position are generated
#  111236 - # From Generated Field:
#  111239 - generated_stars = 55
#  111242 - generated_total_iMass = 102.8954
#  111253 - generated_total_eMass = 23.3835
#  111257 - det_mass_loss_corr = 0.2273
#  111262 - # Done
#
#
# # Population 6;  thin_disk_3 ----------------------------------------------
#  111925 - # From density profile (number density)
#  111928 - expected_total_iMass = 78.6661
#  111931 - expected_total_eMass = 53.5512
#  111934 - average_iMass_per_star = 0.5739
#  111957 - mass_loss_correction = 0.6807
#  111961 - n_expected_stars = 137.0810
#  111967 - # Determine velocities when position are generated
#  112131 - # From Generated Field:
#  112134 - generated_stars = 143
#  112137 - generated_total_iMass = 80.5441
#  112150 - generated_total_eMass = 57.8843
#  112154 - det_mass_loss_corr = 0.7187
#  112159 - # Done
#
#
# # Population 7;  thin_disk_4 ----------------------------------------------
#  112788 - # From density profile (number density)
#  112792 - expected_total_iMass = 114.2187
#  112796 - expected_total_eMass = 72.7280
#  112799 - average_iMass_per_star = 0.5739
#  112803 - mass_loss_correction = 0.6367
#  112806 - n_expected_stars = 199.0338
#  112812 - # Determine velocities when position are generated
#  112941 - # From Generated Field:
#  112944 - generated_stars = 174
#  112948 - generated_total_iMass = 65.8747
#  112958 - generated_total_eMass = 51.4181
#  112962 - det_mass_loss_corr = 0.7805
#  112967 - # Done
#
#
# # Population 8;  thin_disk_5 ----------------------------------------------
#  113620 - # From density profile (number density)
#  113624 - expected_total_iMass = 303.2401
#  113627 - expected_total_eMass = 189.5559
#  113631 - average_iMass_per_star = 0.5739
#  113634 - mass_loss_correction = 0.6251
#  113638 - n_expected_stars = 528.4162
#  113665 - # Determine velocities when position are generated
#  113904 - # From Generated Field:
#  113908 - generated_stars = 554
#  113912 - generated_total_iMass = 277.1771
#  113923 - generated_total_eMass = 184.7266
#  113928 - det_mass_loss_corr = 0.6665
#  113933 - # Done
#
#
# # Population 9;  thin_disk_6 ----------------------------------------------
#  114570 - # From density profile (number density)
#  114574 - expected_total_iMass = 392.5198
#  114577 - expected_total_eMass = 242.0205
#  114580 - average_iMass_per_star = 0.5739
#  114583 - mass_loss_correction = 0.6166
#  114586 - n_expected_stars = 683.9922
#  114592 - # Determine velocities when position are generated
#  114790 - # From Generated Field:
#  114793 - generated_stars = 676
#  114796 - generated_total_iMass = 366.8574
#  114825 - generated_total_eMass = 233.4296
#  114829 - det_mass_loss_corr = 0.6363
#  114833 - # Done
#
#
# # Population 10;  thin_disk_7 ---------------------------------------------
#  115510 - # From density profile (number density)
#  115514 - expected_total_iMass = 833.7647
#  115517 - expected_total_eMass = 501.9225
#  115520 - average_iMass_per_star = 0.5739
#  115523 - mass_loss_correction = 0.6020
#  115526 - n_expected_stars = 1452.8910
#  115532 - # Determine velocities when position are generated
#  115826 - # From Generated Field:
#  115829 - generated_stars = 1437
#  115832 - generated_total_iMass = 853.1531
#  115843 - generated_total_eMass = 491.1762
#  115848 - det_mass_loss_corr = 0.5757
#  115854 - # Done
#
#
# ########################### Combine Populations ###########################
#  115861 - Number of star systems generated: 14023 (34 columns)
#  115864 - included_columns = ['iMass', 'age', 'Fe/H_initial', 'n_companions', 'system_idx', 'Mass', 'system_Mass', 'log_R', 'log_Teff', 'log_g', '[Fe/H]', 'Bessell_V', 'phase', 'star_mass', 'log_L', 'Bessell_R', 'Bessell_I', 'Bessell_B', 'Bessell_U', 'x', 'y', 'z', 'Dist', 'l', 'b', 'vr_bc', 'mul', 'mub', 'U', 'V', 'W', 'VR_LSR', 'A_Ks', 'pop']
#
#
# # Save result -------------------------------------------------------------
#  115870 - write result to "outputfiles/default/mod0test_l3.000_b-1.000.csv"
#  116568 - ---------------------------------------------------------------

# %%
systems2
# Out:
#           iMass        age  Fe/H_initial  n_companions  system_idx      Mass  \
# 0      0.375070  10.000000     -0.395424           0.0           0  0.375061
# 1      0.518925  10.000000      0.272654           0.0           1  0.518910
# 2      0.280831  10.000000      0.180992           0.0           2  0.280827
# 3      0.306999  10.000000     -0.384266           0.0           3  0.306993
# 4      0.099918  10.000000      0.329066           0.0           4  0.099918
# ...         ...        ...           ...           ...         ...       ...
# 14018  1.032765   8.006375     -0.419179           0.0       14018  0.506571
# 14019  0.344509   9.666648     -0.635748           0.0       14019  0.344501
# 14020  1.224109   8.598190     -0.410847           0.0       14020  0.527428
# 14021  0.154980   7.368821     -0.139338           0.0       14021  0.154979
# 14022  0.611211   9.588051     -0.571380           0.0       14022  0.611159
#
#        system_Mass  log_radius   logTeff      logg  ...         b      vr_bc  \
# 0         0.375061   -0.448358  3.571163  4.908929  ... -0.999954 -68.978297
# 1         0.518910   -0.309265  3.566182  4.771300  ... -0.998800  20.325580
# 2         0.280827   -0.545980  3.502499  4.958293  ... -0.999757  74.599044
# 3         0.306993   -0.517668  3.562286  4.960573  ... -0.999507  69.888931
# 4         0.099918    0.099918  0.099918  0.099918  ... -0.999758 -28.321076
# ...            ...         ...       ...       ...  ...       ...        ...
# 14018     0.506571         NaN       NaN       NaN  ... -1.002837 -36.362777
# 14019     0.344501   -0.483490  3.576825  4.942271  ... -0.999032 -57.773567
# 14020     0.527428         NaN       NaN       NaN  ... -0.998206 -42.087324
# 14021     0.154979   -0.747524  3.510543  5.122032  ... -1.002207 -23.992511
# 14022     0.611159   -0.222950  3.672244  4.669955  ... -1.001292  10.620811
#
#             mul       mub          U           V          W     VR_LSR  \
# 0     -2.497565  4.114082 -51.423256  188.291672  97.816986 -59.354901
# 1     -4.070211 -2.480293  36.841591  156.575277 -47.558295  29.949595
# 2     -1.549058  0.851404  89.826146  210.829339  27.611962  84.222858
# 3     -3.454101 -1.143486  86.734809  161.014383 -22.832939  79.512952
# 4     -6.925584 -0.503614  -6.412521   68.149663  -4.496590 -18.697728
# ...         ...       ...        ...         ...        ...        ...
# 14018 -3.767065 -0.141470  -1.304489 -184.126742  -7.639786 -26.740180
# 14019 -3.862989 -0.108371 -21.864270 -199.293312  -3.551276 -48.149505
# 14020 -3.463979 -0.120942  -8.389959 -157.095694  -5.442053 -32.462701
# 14021 -3.329265 -0.102327   8.931285 -141.718460  -3.672142 -14.369930
# 14022 -3.653717 -0.113395  45.405494 -176.856630  -5.617240  20.243795
#
#            A_Ks  pop
# 0      0.780097    0
# 1      0.793979    0
# 2      0.916329    0
# 3      0.925803    0
# 4      0.865925    0
# ...         ...  ...
# 14018  0.920000   10
# 14019  1.634000   10
# 14020  1.634000   10
# 14021  0.920000   10
# 14022  0.920000   10
#
# [14023 rows x 34 columns]

# %%
companions2

# %%
np.sum(systems2['Mass']), np.sum(systems2['system_Mass'])
# Out:
# (4790.499496426857, 4790.499496426857)

# %%
plt.stairs(*np.histogram(systems.Bessell_I, bins=np.linspace(10,40,21)), label='with binaries')
plt.stairs(*np.histogram(systems2.Bessell_I, bins=np.linspace(10,40,21)), label='singles')
plt.legend()
#plt.yscale('log')
