# %% [markdown]
# # Validation - Star generation with SpiseaGenerator
#
# Macy Huston

# %%
import sys
import os

import numpy as np
import synthpop
import matplotlib.pyplot as plt
import pandas as pd

import pdb
# Out:
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/pydantic/_internal/_config.py:341: UserWarning: Valid config keys have changed in V2:
# * 'keep_untouched' has been renamed to 'ignored_types'
#   warnings.warn(message, UserWarning)

# %% [markdown]
# ### Generate a few test catalogs

# %%
# Set up model object 
model = synthpop.SynthPop("spisea_gen_test.synthpop_conf",chosen_bands=['2mass-J','2mass-H','2mass-Ks','jwst-F210M'],
                          solid_angle_unit='deg^2', output_file_type='hdf5',
                         l_set=[0,90, 12.17, 39.14], b_set=[0, 0, 5.37, 8.53], 
                         l_set_type="pairs", b_set_type="pairs",
                         #solid_angle=[1e-4,3e-2,6e-3, 6e-2])
                         solid_angle=[1e-3,3e-1,6e-2, 6e-1])
model.init_populations()
# Out:
#  6760 - Execution Date: 05-06-2025 09:58:03
#
#
# ################################ Settings #################################
#  6761 - # reading default parameters from
#  6761 - default_config_file =  /Users/mhuston/Documents/synthpop/synthpop/config_files/_default.synthpop_conf
#  6761 - # read configuration from
#  6762 - config_file = '/Users/mhuston/Documents/synthpop/synthpop/config_files/spisea_gen_test.synthpop_conf'
#
#
# # copy the following to a config file to redo this model generation -------
#  6762 - {
#     "l_set": [
#         0,
#         90,
#         12.17,
#         39.14
#     ],
#     "l_set_type": "pairs",
#     "b_set": [
#         0,
#         0,
#         5.37,
#         8.53
#     ],
#     "b_set_type": "pairs",
#     "name_for_output": "Huston2025_spisea",
#     "model_name": "Huston2025",
#     "solid_angle": [
#         0.001,
#         0.3,
#         0.06,
#         0.6
#     ],
#     "solid_angle_unit": "deg^2",
#     "random_seed": 1939621559,
#     "sun": {
#         "x": -8.178,
#         "y": 0.0,
#         "z": 0.017,
#         "u": 12.9,
#         "v": 245.6,
#         "w": 7.78,
#         "l_apex_deg": 56.24,
#         "b_apex_deg": 22.54
#     },
#     "lsr": {
#         "u_lsr": 1.8,
#         "v_lsr": 233.4,
#         "w_lsr": 0.53
#     },
#     "warp": {
#         "r_warp": 7.72,
#         "amp_warp": 0.06,
#         "amp_warp_pos": null,
#         "amp_warp_neg": null,
#         "alpha_warp": 1.33,
#         "phi_warp_deg": 17.5
#     },
#     "max_distance": 25,
#     "distance_step_size": 0.1,
#     "window_type": {
#         "window_type": "cone"
#     },
#     "mass_lims": {
#         "min_mass": 0.08,
#         "max_mass": 100
#     },
#     "N_mc_totmass": 10000,
#     "lost_mass_option": 1,
#     "N_av_mass": 50000,
#     "kinematics_at_the_end": false,
#     "scale_factor": 1,
#     "skip_lowmass_stars": false,
#     "chunk_size": 250000,
#     "star_generator": "SpiseaGenerator",
#     "extinction_map_kwargs": {
#         "name": "maps_from_dustmaps",
#         "dustmap_name": "marshall"
#     },
#     "extinction_law_kwargs": [
#         {
#             "name": "SODC",
#             "R_V": 2.5
#         }
#     ],
#     "evolution_class": {
#         "name": "SpiseaCluster"
#     },
#     "maglim": [
#         "2mass-Ks",
#         99,
#         "keep"
#     ],
#     "chosen_bands": [
#         "2mass-J",
#         "2mass-H",
#         "2mass-Ks",
#         "jwst-F210M"
#     ],
#     "eff_wavelengths": {
#         "2mass-J": 1.232024441939017,
#         "2mass-H": 1.642309415675878,
#         "2mass-Ks": 2.155751977206318,
#         "jwst-F210M": 2.090820701551254
#     },
#     "obsmag": true,
#     "opt_iso_props": [
#         "log_L",
#         "log_Teff",
#         "log_g",
#         "log_R",
#         "phase"
#     ],
#     "col_names": [
#         "logL",
#         "logTeff",
#         "logg",
#         "log_radius",
#         "phase"
#     ],
#     "post_processing_kwargs": null,
#     "output_location": "outputfiles/default",
#     "output_filename_pattern": "{name_for_output}_l{l_deg:.3f}_b{b_deg:.3f}",
#     "output_file_type": "hdf5",
#     "overwrite": true
# }
#
#
# ########################## initialize population ##########################
#  6763 - read Population files from Huston2025
#
#
# # Population 0;  bulge ----------------------------------------------------
#  6764 - # Initialize Population 0 (bulge) from
#  6764 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/bulge.popjson'
#  7756 - Setting lost_mass_option to 3 for SpiseaGenerator.
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /Users/mhuston/NotBacked/spisea_data/cdbs/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))
#
#
# # Population 1;  halo -----------------------------------------------------
#  8851 - # Initialize Population 1 (halo) from
#  8852 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/halo.popjson'
#  8854 - Setting lost_mass_option to 3 for SpiseaGenerator.
#
#
# # Population 2;  nsd ------------------------------------------------------
#  8855 - # Initialize Population 2 (nsd) from
#  8855 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/nsd.popjson'
#  9219 - Setting lost_mass_option to 3 for SpiseaGenerator.
#
#
# # Population 3;  thick_disk -----------------------------------------------
#  9220 - # Initialize Population 3 (thick_disk) from
#  9220 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thick_disk.popjson'
#  9222 - Setting lost_mass_option to 3 for SpiseaGenerator.
#
#
# # Population 4;  thin_disk_1 ----------------------------------------------
#  9223 - # Initialize Population 4 (thin_disk_1) from
#  9223 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thin_disk_1.popjson'
#  9226 - Setting lost_mass_option to 3 for SpiseaGenerator.
#
#
# # Population 5;  thin_disk_2 ----------------------------------------------
#  9226 - # Initialize Population 5 (thin_disk_2) from
#  9227 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thin_disk_2.popjson'
#  9228 - Setting lost_mass_option to 3 for SpiseaGenerator.
#
#
# # Population 6;  thin_disk_3 ----------------------------------------------
#  9229 - # Initialize Population 6 (thin_disk_3) from
#  9229 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thin_disk_3.popjson'
#  9230 - Setting lost_mass_option to 3 for SpiseaGenerator.
#
#
# # Population 7;  thin_disk_4 ----------------------------------------------
#  9231 - # Initialize Population 7 (thin_disk_4) from
#  9231 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thin_disk_4.popjson'
#  9233 - Setting lost_mass_option to 3 for SpiseaGenerator.
#
#
# # Population 8;  thin_disk_5 ----------------------------------------------
#  9234 - # Initialize Population 8 (thin_disk_5) from
#  9234 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thin_disk_5.popjson'
#  9236 - Setting lost_mass_option to 3 for SpiseaGenerator.
#
#
# # Population 9;  thin_disk_6 ----------------------------------------------
#  9236 - # Initialize Population 9 (thin_disk_6) from
#  9237 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thin_disk_6.popjson'
#  9239 - Setting lost_mass_option to 3 for SpiseaGenerator.
#
#
# # Population 10;  thin_disk_7 ---------------------------------------------
#  9240 - # Initialize Population 10 (thin_disk_7) from
#  9240 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thin_disk_7.popjson'
#  9242 - Setting lost_mass_option to 3 for SpiseaGenerator.
#  9242 - # all population are initialized

# %%
model.process_location(1,1,0.001)
# Out:
# ############################# update location #############################
#  9245 - # set location to:
#  9245 - l, b = (1.00 deg, 1.00 deg)
#  9246 - # set solid_angle to:
#  9246 - solid_angle = 1.000e-03 deg^2
#
#
# ############################# Generate Field ##############################
#
#
# # Population 0;  bulge ----------------------------------------------------
#  11087 - # From density profile (number density)
#  11088 - expected_total_iMass = 236452.8818
#  11088 - expected_total_eMass = 236452.8818
#  11088 - average_iMass_per_star = 0.5739
#  11088 - mass_loss_correction = 1.0000
#  11089 - n_expected_stars = 412035.0414
#  11089 - # Determine velocities when position are generated
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-1
stars
# Missing photometry for 1 filter - recomputing these columns: ['jwst,F210M']
# Loading stellar spectra
# Changing to T=  2300 for met=0.50 T=  2212 logg=5.10
# Changing to met=0.50 for met=0.50 T=  2212 logg=5.10
# Changing to T=  2300 for met=0.50 T=  2222 logg=5.09
# Changing to met=0.50 for met=0.50 T=  2222 logg=5.09
# Changing to T=  2300 for met=0.50 T=  2245 logg=5.09
# Changing to met=0.50 for met=0.50 T=  2245 logg=5.09
# Changing to T=  2300 for met=0.50 T=  2271 logg=5.08
# Changing to met=0.50 for met=0.50 T=  2271 logg=5.08
# Changing to T=  2300 for met=0.50 T=  2296 logg=5.07
# Changing to met=0.50 for met=0.50 T=  2296 logg=5.07
# Changing to met=0.50 for met=0.50 T=  5008 logg=4.48
# Changing to met=0.50 for met=0.50 T=  5020 logg=4.48
# Changing to met=0.50 for met=0.50 T=  5032 logg=4.48
# Changing to met=0.50 for met=0.50 T=  5043 logg=4.47
# Changing to met=0.50 for met=0.50 T=  5054 logg=4.47
# Changing to met=0.50 for met=0.50 T=  5066 logg=4.47
# Changing to met=0.50 for met=0.50 T=  5077 logg=4.47
# Changing to met=0.50 for met=0.50 T=  5088 logg=4.46
# Changing to met=0.50 for met=0.50 T=  5100 logg=4.46
# Changing to met=0.50 for met=0.50 T=  5115 logg=4.45
# Changing to met=0.50 for met=0.50 T=  5129 logg=4.45
# Changing to met=0.50 for met=0.50 T=  5143 logg=4.45
# Changing to met=0.50 for met=0.50 T=  5157 logg=4.44
# Changing to met=0.50 for met=0.50 T=  5171 logg=4.44
# Changing to met=0.50 for met=0.50 T=  5181 logg=4.43
# Changing to met=0.50 for met=0.50 T=  5189 logg=4.43
# Changing to met=0.50 for met=0.50 T=  5197 logg=4.43
# Changing to met=0.50 for met=0.50 T=  5205 logg=4.42
# Changing to met=0.50 for met=0.50 T=  5213 logg=4.42
# Changing to met=0.50 for met=0.50 T=  5221 logg=4.42
# Changing to met=0.50 for met=0.50 T=  5229 logg=4.41
# Changing to met=0.50 for met=0.50 T=  5236 logg=4.41
# Changing to met=0.50 for met=0.50 T=  5244 logg=4.41
# Changing to met=0.50 for met=0.50 T=  5252 logg=4.40
# Changing to met=0.50 for met=0.50 T=  5260 logg=4.40
# Changing to met=0.50 for met=0.50 T=  5268 logg=4.39
# Changing to met=0.50 for met=0.50 T=  5275 logg=4.39
# Changing to met=0.50 for met=0.50 T=  5282 logg=4.39
# Changing to met=0.50 for met=0.50 T=  5290 logg=4.38
# Changing to met=0.50 for met=0.50 T=  5297 logg=4.38
# Changing to met=0.50 for met=0.50 T=  5303 logg=4.37
# Changing to met=0.50 for met=0.50 T=  5310 logg=4.37
# Changing to met=0.50 for met=0.50 T=  5316 logg=4.36
# Changing to met=0.50 for met=0.50 T=  5322 logg=4.36
# Changing to met=0.50 for met=0.50 T=  5329 logg=4.36
# Changing to met=0.50 for met=0.50 T=  5335 logg=4.35
# Changing to met=0.50 for met=0.50 T=  5341 logg=4.35
# Changing to met=0.50 for met=0.50 T=  5347 logg=4.34
# Changing to met=0.50 for met=0.50 T=  5353 logg=4.34
# Changing to met=0.50 for met=0.50 T=  5358 logg=4.33
# Changing to met=0.50 for met=0.50 T=  5364 logg=4.33
# Changing to met=0.50 for met=0.50 T=  5370 logg=4.32
# Changing to met=0.50 for met=0.50 T=  5375 logg=4.32
# Changing to met=0.50 for met=0.50 T=  5381 logg=4.31
# Changing to met=0.50 for met=0.50 T=  5386 logg=4.31
# Changing to met=0.50 for met=0.50 T=  5391 logg=4.30
# Changing to met=0.50 for met=0.50 T=  5396 logg=4.30
# Changing to met=0.50 for met=0.50 T=  5401 logg=4.29
# Changing to met=0.50 for met=0.50 T=  5406 logg=4.29
# Changing to met=0.50 for met=0.50 T=  5410 logg=4.28
# Changing to met=0.50 for met=0.50 T=  5414 logg=4.27
# Changing to met=0.50 for met=0.50 T=  5418 logg=4.27
# Changing to met=0.50 for met=0.50 T=  5422 logg=4.26
# Changing to met=0.50 for met=0.50 T=  5425 logg=4.25
# Changing to met=0.50 for met=0.50 T=  5428 logg=4.25
# Changing to met=0.50 for met=0.50 T=  5431 logg=4.24
# Changing to met=0.50 for met=0.50 T=  5433 logg=4.24
# Changing to met=0.50 for met=0.50 T=  5435 logg=4.23
# Changing to met=0.50 for met=0.50 T=  5436 logg=4.22
# Changing to met=0.50 for met=0.50 T=  5438 logg=4.22
# Changing to met=0.50 for met=0.50 T=  5438 logg=4.21
# Changing to met=0.50 for met=0.50 T=  5439 logg=4.20
# Changing to met=0.50 for met=0.50 T=  5439 logg=4.20
# Changing to met=0.50 for met=0.50 T=  5439 logg=4.19
# Changing to met=0.50 for met=0.50 T=  5439 logg=4.18
# Changing to met=0.50 for met=0.50 T=  5438 logg=4.18
# Changing to met=0.50 for met=0.50 T=  5437 logg=4.17
# Changing to met=0.50 for met=0.50 T=  5436 logg=4.16
# Changing to met=0.50 for met=0.50 T=  5434 logg=4.16
# Changing to met=0.50 for met=0.50 T=  5432 logg=4.15
# Changing to met=0.50 for met=0.50 T=  5429 logg=4.14
# Changing to met=0.50 for met=0.50 T=  5427 logg=4.14
# Changing to met=0.50 for met=0.50 T=  5423 logg=4.13
# Changing to met=0.50 for met=0.50 T=  5420 logg=4.12
# Changing to met=0.50 for met=0.50 T=  5416 logg=4.12
# Changing to met=0.50 for met=0.50 T=  5412 logg=4.11
# Changing to met=0.50 for met=0.50 T=  5408 logg=4.11
# Changing to met=0.50 for met=0.50 T=  5403 logg=4.10
# Changing to met=0.50 for met=0.50 T=  5397 logg=4.09
# Changing to met=0.50 for met=0.50 T=  5392 logg=4.09
# Changing to met=0.50 for met=0.50 T=  5372 logg=4.07
# Changing to met=0.50 for met=0.50 T=  5348 logg=4.05
# Changing to met=0.50 for met=0.50 T=  5322 logg=4.04
# Changing to met=0.50 for met=0.50 T=  5292 logg=4.02
# Changing to met=0.50 for met=0.50 T=  5260 logg=4.00
# Changing to met=0.50 for met=0.50 T=  5227 logg=3.99
# Changing to met=0.50 for met=0.50 T=  5191 logg=3.98
# Changing to met=0.50 for met=0.50 T=  5154 logg=3.96
# Changing to met=0.50 for met=0.50 T=  5116 logg=3.95
# Changing to met=0.50 for met=0.50 T=  5077 logg=3.94
# Changing to met=0.50 for met=0.50 T=  5037 logg=3.93
# Making photometry for isochrone: log(t) = 10.00  AKs = 0.00  dist = 10
#      Starting at:  2025-06-05 10:02:05.685844   Usually takes ~5 minutes
# Starting filter: jwst,F210M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  2212 K  m_jwst_F210M = 9.92
# M =   0.777 Msun  T =  4435 K  m_jwst_F210M = 4.29
# M =   1.069 Msun  T =  5429 K  m_jwst_F210M = 2.56
# M =   1.123 Msun  T =  3861 K  m_jwst_F210M = -2.83
# M =   1.124 Msun  T =  4272 K  m_jwst_F210M = -1.67
# M =   1.130 Msun  T =  3771 K  m_jwst_F210M = -3.51
# M =   1.130 Msun  T =  3018 K  m_jwst_F210M = -6.00
# M =   1.130 Msun  T = 42876 K  m_jwst_F210M = 0.43
# M =   1.130 Msun  T = 92545 K  m_jwst_F210M = 4.44
# M =   1.131 Msun  T = 22285 K  m_jwst_F210M = 10.55
#       Time taken: 6.68 seconds
# Found 47106 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-1.7543483357110188 for 1 stars
# Found 19 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-1.4990758306077128 for 16 stars
# Found 20 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-1.249198357391113 for 165 stars
# Found 136 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-1.0061603087048185 for 1203 stars
# Found 1177 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-0.7543483357110189 for 4889 stars
# Found 4505 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-0.4990758306077128 for 10547 stars
# Found 9373 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-0.24919835739111287 for 14546 stars
# Found 13195 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-0.006160308704818447 for 26662 stars
# Found 32754 stars out of mass range
# Found 32606 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=0.24565166428898116 for 41984 stars
# Found 62409 stars out of mass range
# Found 63722 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=0.5009241693922871 for 14494 stars
# Found 13002 stars out of mass range
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
#  256348 - # From Generated Field:
#  256349 - generated_stars = 526389
#  256354 - generated_total_iMass = 370583.5735
#  256389 - generated_total_eMass = 236918.5444
#  256398 - det_mass_loss_corr = 0.6393
#  256793 - # Done
#
#
# # Population 1;  halo -----------------------------------------------------
#  257250 - # From density profile (number density)
#  257251 - expected_total_iMass = 28693.2977
#  257251 - expected_total_eMass = 286.2415
#  257251 - average_iMass_per_star = 0.5739
#  257251 - mass_loss_correction = 1.0000
#  257252 - n_expected_stars = 50000.0000
#  257252 - # Determine velocities when position are generated
# Starting SPISEA cluster generation for bin log_age=10.15 [M/H]=-4.0061603087048185 for 1 stars
# Missing photometry for 1 filter - recomputing these columns: ['jwst,F210M']
# Loading stellar spectra
# Changing to met=-4.00 for met=-4.01 T=  3961 logg=5.42
# Changing to met=-4.00 for met=-4.01 T=  3967 logg=5.42
# Changing to met=-4.00 for met=-4.01 T=  3984 logg=5.41
# Changing to met=-4.00 for met=-4.01 T=  4000 logg=5.39
# Changing to met=-4.00 for met=-4.01 T=  4016 logg=5.38
# Changing to met=-4.00 for met=-4.01 T=  4032 logg=5.37
# Changing to met=-4.00 for met=-4.01 T=  4049 logg=5.36
# Changing to met=-4.00 for met=-4.01 T=  4065 logg=5.35
# Changing to met=-4.00 for met=-4.01 T=  4082 logg=5.34
# Changing to met=-4.00 for met=-4.01 T=  4100 logg=5.32
# Changing to met=-4.00 for met=-4.01 T=  4117 logg=5.31
# Changing to met=-4.00 for met=-4.01 T=  4134 logg=5.30
# Changing to met=-4.00 for met=-4.01 T=  4152 logg=5.29
# Changing to met=-4.00 for met=-4.01 T=  4171 logg=5.27
# Changing to met=-4.00 for met=-4.01 T=  4188 logg=5.26
# Changing to met=-4.00 for met=-4.01 T=  4207 logg=5.25
# Changing to met=-4.00 for met=-4.01 T=  4226 logg=5.23
# Changing to met=-4.00 for met=-4.01 T=  4244 logg=5.22
# Changing to met=-4.00 for met=-4.01 T=  4267 logg=5.20
# Changing to met=-4.00 for met=-4.01 T=  4289 logg=5.18
# Changing to met=-4.00 for met=-4.01 T=  4311 logg=5.17
# Changing to met=-4.00 for met=-4.01 T=  4334 logg=5.15
# Changing to met=-4.00 for met=-4.01 T=  4357 logg=5.13
# Changing to met=-4.00 for met=-4.01 T=  4373 logg=5.11
# Changing to met=-4.00 for met=-4.01 T=  4380 logg=5.10
# Changing to met=-4.00 for met=-4.01 T=  4387 logg=5.10
# Changing to met=-4.00 for met=-4.01 T=  4393 logg=5.09
# Changing to met=-4.00 for met=-4.01 T=  4400 logg=5.08
# Changing to met=-4.00 for met=-4.01 T=  4406 logg=5.07
# Changing to met=-4.00 for met=-4.01 T=  4412 logg=5.06
# Changing to met=-4.00 for met=-4.01 T=  4416 logg=5.06
# Changing to met=-4.00 for met=-4.01 T=  4420 logg=5.05
# Changing to met=-4.00 for met=-4.01 T=  4424 logg=5.05
# Changing to met=-4.00 for met=-4.01 T=  4428 logg=5.04
# Changing to met=-4.00 for met=-4.01 T=  4432 logg=5.04
# Changing to met=-4.00 for met=-4.01 T=  4437 logg=5.03
# Changing to met=-4.00 for met=-4.01 T=  4441 logg=5.03
# Changing to met=-4.00 for met=-4.01 T=  4446 logg=5.02
# Changing to met=-4.00 for met=-4.01 T=  4457 logg=5.02
# Changing to met=-4.00 for met=-4.01 T=  4463 logg=5.01
# Changing to met=-4.00 for met=-4.01 T=  4468 logg=5.01
# Changing to met=-4.00 for met=-4.01 T=  4475 logg=5.01
# Changing to met=-4.00 for met=-4.01 T=  4483 logg=5.01
# Changing to met=-4.00 for met=-4.01 T=  4489 logg=5.00
# Changing to met=-4.00 for met=-4.01 T=  4496 logg=5.00
# Changing to met=-4.00 for met=-4.01 T=  4502 logg=5.00
# Changing to met=-4.00 for met=-4.01 T=  4508 logg=5.00
# Changing to met=-4.00 for met=-4.01 T=  4515 logg=4.99
# Changing to met=-4.00 for met=-4.01 T=  4522 logg=4.99
# Changing to met=-4.00 for met=-4.01 T=  4525 logg=4.99
# Changing to met=-4.00 for met=-4.01 T=  4528 logg=4.99
# Changing to met=-4.00 for met=-4.01 T=  4530 logg=4.99
# Changing to met=-4.00 for met=-4.01 T=  4533 logg=4.99
# Changing to met=-4.00 for met=-4.01 T=  4536 logg=4.99
# Changing to met=-4.00 for met=-4.01 T=  4539 logg=4.99
# Changing to met=-4.00 for met=-4.01 T=  4543 logg=4.99
# Changing to met=-4.00 for met=-4.01 T=  4547 logg=4.98
# Changing to met=-4.00 for met=-4.01 T=  4551 logg=4.98
# Changing to met=-4.00 for met=-4.01 T=  4554 logg=4.98
# Changing to met=-4.00 for met=-4.01 T=  4557 logg=4.98
# Changing to met=-4.00 for met=-4.01 T=  4560 logg=4.98
# Changing to met=-4.00 for met=-4.01 T=  4563 logg=4.98
# Changing to met=-4.00 for met=-4.01 T=  4566 logg=4.98
# Changing to met=-4.00 for met=-4.01 T=  4569 logg=4.97
# Changing to met=-4.00 for met=-4.01 T=  4575 logg=4.97
# Changing to met=-4.00 for met=-4.01 T=  4581 logg=4.97
# Changing to met=-4.00 for met=-4.01 T=  4587 logg=4.97
# Changing to met=-4.00 for met=-4.01 T=  4600 logg=4.96
# Changing to met=-4.00 for met=-4.01 T=  4617 logg=4.95
# Changing to met=-4.00 for met=-4.01 T=  4633 logg=4.95
# Changing to met=-4.00 for met=-4.01 T=  4651 logg=4.94
# Changing to met=-4.00 for met=-4.01 T=  4668 logg=4.93
# Changing to met=-4.00 for met=-4.01 T=  4685 logg=4.92
# Changing to met=-4.00 for met=-4.01 T=  4703 logg=4.92
# Changing to met=-4.00 for met=-4.01 T=  4720 logg=4.91
# Changing to met=-4.00 for met=-4.01 T=  4745 logg=4.90
# Changing to met=-4.00 for met=-4.01 T=  4774 logg=4.89
# Changing to met=-4.00 for met=-4.01 T=  4804 logg=4.89
# Changing to met=-4.00 for met=-4.01 T=  4834 logg=4.88
# Changing to met=-4.00 for met=-4.01 T=  4864 logg=4.87
# Changing to met=-4.00 for met=-4.01 T=  4896 logg=4.86
# Changing to met=-4.00 for met=-4.01 T=  4927 logg=4.85
# Changing to met=-4.00 for met=-4.01 T=  4962 logg=4.85
# Changing to met=-2.50 for met=-4.01 T=  5003 logg=4.84
# Changing to met=-2.50 for met=-4.01 T=  5044 logg=4.83
# Changing to met=-2.50 for met=-4.01 T=  5086 logg=4.82
# Changing to met=-2.50 for met=-4.01 T=  5128 logg=4.81
# Changing to met=-2.50 for met=-4.01 T=  5172 logg=4.80
# Changing to met=-2.50 for met=-4.01 T=  5217 logg=4.80
# Changing to met=-2.50 for met=-4.01 T=  5262 logg=4.79
# Changing to met=-2.50 for met=-4.01 T=  5310 logg=4.78
# Changing to met=-2.50 for met=-4.01 T=  5359 logg=4.77
# Changing to met=-2.50 for met=-4.01 T=  5408 logg=4.76
# Changing to met=-2.50 for met=-4.01 T=  5458 logg=4.75
# Changing to met=-2.50 for met=-4.01 T=  5509 logg=4.74
# Changing to met=-2.50 for met=-4.01 T=  5561 logg=4.72
# Changing to met=-2.50 for met=-4.01 T=  5612 logg=4.71
# Changing to met=-2.50 for met=-4.01 T=  5637 logg=4.71
# Changing to met=-2.50 for met=-4.01 T=  5662 logg=4.70
# Changing to met=-2.50 for met=-4.01 T=  5687 logg=4.70
# Changing to met=-2.50 for met=-4.01 T=  5712 logg=4.69
# Changing to met=-2.50 for met=-4.01 T=  5737 logg=4.69
# Changing to met=-2.50 for met=-4.01 T=  5762 logg=4.68
# Changing to met=-2.50 for met=-4.01 T=  5787 logg=4.68
# Changing to met=-2.50 for met=-4.01 T=  5812 logg=4.67
# Changing to met=-2.50 for met=-4.01 T=  5837 logg=4.66
# Changing to met=-2.50 for met=-4.01 T=  5862 logg=4.66
# Changing to met=-2.50 for met=-4.01 T=  5887 logg=4.65
# Changing to met=-2.50 for met=-4.01 T=  5912 logg=4.65
# Changing to met=-2.50 for met=-4.01 T=  5937 logg=4.64
# Changing to met=-2.50 for met=-4.01 T=  5961 logg=4.63
# Changing to met=-2.50 for met=-4.01 T=  5986 logg=4.63
# Changing to met=-2.50 for met=-4.01 T=  6011 logg=4.62
# Changing to met=-2.50 for met=-4.01 T=  6035 logg=4.62
# Changing to met=-2.50 for met=-4.01 T=  6060 logg=4.61
# Changing to met=-2.50 for met=-4.01 T=  6084 logg=4.60
# Changing to met=-2.50 for met=-4.01 T=  6109 logg=4.60
# Changing to met=-2.50 for met=-4.01 T=  6133 logg=4.59
# Changing to met=-2.50 for met=-4.01 T=  6157 logg=4.59
# Changing to met=-2.50 for met=-4.01 T=  6181 logg=4.58
# Changing to met=-2.50 for met=-4.01 T=  6205 logg=4.57
# Changing to met=-2.50 for met=-4.01 T=  6228 logg=4.57
# Changing to met=-2.50 for met=-4.01 T=  6252 logg=4.56
# Changing to met=-2.50 for met=-4.01 T=  6275 logg=4.55
# Changing to met=-2.50 for met=-4.01 T=  6299 logg=4.55
# Changing to met=-2.50 for met=-4.01 T=  6322 logg=4.54
# Changing to met=-2.50 for met=-4.01 T=  6345 logg=4.53
# Changing to met=-2.50 for met=-4.01 T=  6367 logg=4.53
# Changing to met=-2.50 for met=-4.01 T=  6390 logg=4.52
# Changing to met=-2.50 for met=-4.01 T=  6412 logg=4.51
# Changing to met=-2.50 for met=-4.01 T=  6434 logg=4.51
# Changing to met=-2.50 for met=-4.01 T=  6455 logg=4.50
# Changing to met=-2.50 for met=-4.01 T=  6477 logg=4.49
# Changing to met=-2.50 for met=-4.01 T=  6498 logg=4.48
# Changing to met=-2.50 for met=-4.01 T=  6519 logg=4.48
# Changing to met=-2.50 for met=-4.01 T=  6539 logg=4.47
# Changing to met=-2.50 for met=-4.01 T=  6559 logg=4.46
# Changing to met=-2.50 for met=-4.01 T=  6579 logg=4.46
# Changing to met=-2.50 for met=-4.01 T=  6599 logg=4.45
# Changing to met=-2.50 for met=-4.01 T=  6618 logg=4.44
# Changing to met=-2.50 for met=-4.01 T=  6636 logg=4.43
# Changing to met=-2.50 for met=-4.01 T=  6654 logg=4.43
# Changing to met=-2.50 for met=-4.01 T=  6672 logg=4.42
# Changing to met=-2.50 for met=-4.01 T=  6690 logg=4.41
# Changing to met=-2.50 for met=-4.01 T=  6707 logg=4.40
# Changing to met=-2.50 for met=-4.01 T=  6723 logg=4.39
# Changing to met=-2.50 for met=-4.01 T=  6739 logg=4.39
# Changing to met=-2.50 for met=-4.01 T=  6755 logg=4.38
# Changing to met=-2.50 for met=-4.01 T=  6770 logg=4.37
# Changing to met=-2.50 for met=-4.01 T=  6785 logg=4.36
# Changing to met=-2.50 for met=-4.01 T=  6799 logg=4.35
# Changing to met=-2.50 for met=-4.01 T=  6813 logg=4.34
# Changing to met=-2.50 for met=-4.01 T=  6826 logg=4.34
# Changing to met=-2.50 for met=-4.01 T=  6839 logg=4.33
# Changing to met=-2.50 for met=-4.01 T=  6851 logg=4.32
# Changing to met=-2.50 for met=-4.01 T=  6863 logg=4.31
# Changing to met=-2.50 for met=-4.01 T=  6874 logg=4.30
# Changing to met=-2.50 for met=-4.01 T=  6885 logg=4.29
# Changing to met=-2.50 for met=-4.01 T=  6895 logg=4.28
# Changing to met=-2.50 for met=-4.01 T=  6905 logg=4.27
# Changing to met=-2.50 for met=-4.01 T=  6914 logg=4.26
# Changing to met=-2.50 for met=-4.01 T=  6922 logg=4.25
# Changing to met=-2.50 for met=-4.01 T=  6930 logg=4.24
# Changing to met=-2.50 for met=-4.01 T=  6938 logg=4.23
# Changing to met=-2.50 for met=-4.01 T=  6945 logg=4.22
# Changing to met=-2.50 for met=-4.01 T=  6951 logg=4.22
# Changing to met=-2.50 for met=-4.01 T=  6958 logg=4.20
# Changing to met=-2.50 for met=-4.01 T=  6963 logg=4.19
# Changing to met=-2.50 for met=-4.01 T=  6968 logg=4.18
# Changing to met=-2.50 for met=-4.01 T=  6973 logg=4.17
# Changing to met=-2.50 for met=-4.01 T=  6977 logg=4.16
# Changing to met=-2.50 for met=-4.01 T=  6980 logg=4.15
# Changing to met=-2.50 for met=-4.01 T=  6982 logg=4.14
# Changing to met=-2.50 for met=-4.01 T=  6984 logg=4.13
# Changing to met=-2.50 for met=-4.01 T=  6984 logg=4.12
# Changing to met=-2.50 for met=-4.01 T=  6984 logg=4.11
# Changing to met=-2.50 for met=-4.01 T=  6983 logg=4.10
# Changing to met=-2.50 for met=-4.01 T=  6981 logg=4.09
# Changing to met=-2.50 for met=-4.01 T=  6977 logg=4.08
# Changing to met=-2.50 for met=-4.01 T=  6973 logg=4.06
# Changing to met=-2.50 for met=-4.01 T=  6968 logg=4.05
# Changing to met=-2.50 for met=-4.01 T=  6961 logg=4.04
# Changing to met=-2.50 for met=-4.01 T=  6954 logg=4.03
# Changing to met=-2.50 for met=-4.01 T=  6945 logg=4.02
# Changing to met=-2.50 for met=-4.01 T=  6935 logg=4.01
# Changing to met=-2.50 for met=-4.01 T=  6925 logg=3.99
# Changing to met=-2.50 for met=-4.01 T=  6913 logg=3.98
# Changing to met=-2.50 for met=-4.01 T=  6900 logg=3.97
# Changing to met=-2.50 for met=-4.01 T=  6887 logg=3.96
# Changing to met=-2.50 for met=-4.01 T=  6872 logg=3.94
# Changing to met=-2.50 for met=-4.01 T=  6857 logg=3.93
# Changing to met=-2.50 for met=-4.01 T=  6841 logg=3.92
# Changing to met=-2.50 for met=-4.01 T=  6824 logg=3.90
# Changing to met=-2.50 for met=-4.01 T=  6806 logg=3.89
# Changing to met=-2.50 for met=-4.01 T=  6787 logg=3.88
# Changing to met=-2.50 for met=-4.01 T=  6768 logg=3.87
# Changing to met=-2.50 for met=-4.01 T=  6748 logg=3.85
# Changing to met=-2.50 for met=-4.01 T=  6728 logg=3.84
# Changing to met=-2.50 for met=-4.01 T=  6698 logg=3.82
# Changing to met=-2.50 for met=-4.01 T=  6668 logg=3.80
# Changing to met=-2.50 for met=-4.01 T=  6637 logg=3.78
# Changing to met=-2.50 for met=-4.01 T=  6606 logg=3.77
# Changing to met=-2.50 for met=-4.01 T=  6574 logg=3.75
# Changing to met=-2.50 for met=-4.01 T=  6543 logg=3.73
# Changing to met=-2.50 for met=-4.01 T=  6511 logg=3.71
# Changing to met=-2.50 for met=-4.01 T=  6479 logg=3.69
# Changing to met=-2.50 for met=-4.01 T=  6448 logg=3.67
# Changing to met=-2.50 for met=-4.01 T=  6416 logg=3.65
# Changing to met=-2.50 for met=-4.01 T=  6385 logg=3.63
# Changing to met=-2.50 for met=-4.01 T=  6354 logg=3.62
# Changing to met=-2.50 for met=-4.01 T=  6324 logg=3.60
# Changing to met=-2.50 for met=-4.01 T=  6294 logg=3.58
# Changing to met=-2.50 for met=-4.01 T=  6264 logg=3.56
# Changing to met=-2.50 for met=-4.01 T=  6235 logg=3.54
# Changing to met=-2.50 for met=-4.01 T=  6207 logg=3.52
# Changing to met=-2.50 for met=-4.01 T=  6179 logg=3.50
# Changing to met=-2.50 for met=-4.01 T=  6151 logg=3.49
# Changing to met=-2.50 for met=-4.01 T=  6124 logg=3.47
# Changing to met=-2.50 for met=-4.01 T=  6097 logg=3.45
# Changing to met=-2.50 for met=-4.01 T=  6071 logg=3.43
# Changing to met=-2.50 for met=-4.01 T=  6044 logg=3.41
# Changing to met=-2.50 for met=-4.01 T=  6018 logg=3.39
# Changing to met=-2.50 for met=-4.01 T=  5993 logg=3.37
# Changing to met=-2.50 for met=-4.01 T=  5967 logg=3.36
# Changing to met=-2.50 for met=-4.01 T=  5942 logg=3.34
# Changing to met=-2.50 for met=-4.01 T=  5918 logg=3.32
# Changing to met=-2.50 for met=-4.01 T=  5893 logg=3.30
# Changing to met=-2.50 for met=-4.01 T=  5869 logg=3.28
# Changing to met=-2.50 for met=-4.01 T=  5845 logg=3.26
# Changing to met=-2.50 for met=-4.01 T=  5822 logg=3.24
# Changing to met=-2.50 for met=-4.01 T=  5799 logg=3.23
# Changing to met=-2.50 for met=-4.01 T=  5777 logg=3.21
# Changing to met=-2.50 for met=-4.01 T=  5756 logg=3.19
# Changing to met=-2.50 for met=-4.01 T=  5737 logg=3.17
# Changing to met=-2.50 for met=-4.01 T=  5719 logg=3.15
# Changing to met=-2.50 for met=-4.01 T=  5703 logg=3.13
# Changing to met=-2.50 for met=-4.01 T=  5688 logg=3.11
# Changing to met=-2.50 for met=-4.01 T=  5674 logg=3.09
# Changing to met=-2.50 for met=-4.01 T=  5662 logg=3.07
# Changing to met=-2.50 for met=-4.01 T=  5651 logg=3.05
# Changing to met=-2.50 for met=-4.01 T=  5640 logg=3.04
# Changing to met=-2.50 for met=-4.01 T=  5630 logg=3.02
# Changing to met=-2.50 for met=-4.01 T=  5621 logg=3.00
# Changing to met=-2.50 for met=-4.01 T=  5612 logg=2.98
# Changing to met=-2.50 for met=-4.01 T=  5603 logg=2.96
# Changing to met=-2.50 for met=-4.01 T=  5595 logg=2.94
# Changing to met=-2.50 for met=-4.01 T=  5586 logg=2.93
# Changing to met=-2.50 for met=-4.01 T=  5578 logg=2.91
# Changing to met=-2.50 for met=-4.01 T=  5570 logg=2.89
# Changing to met=-2.50 for met=-4.01 T=  5563 logg=2.87
# Changing to met=-2.50 for met=-4.01 T=  5555 logg=2.85
# Changing to met=-2.50 for met=-4.01 T=  5547 logg=2.83
# Changing to met=-2.50 for met=-4.01 T=  5540 logg=2.81
# Changing to met=-2.50 for met=-4.01 T=  5532 logg=2.80
# Changing to met=-2.50 for met=-4.01 T=  5525 logg=2.78
# Changing to met=-2.50 for met=-4.01 T=  5517 logg=2.76
# Changing to met=-2.50 for met=-4.01 T=  5510 logg=2.74
# Changing to met=-2.50 for met=-4.01 T=  5502 logg=2.72
# Changing to met=-2.50 for met=-4.01 T=  5495 logg=2.70
# Changing to met=-2.50 for met=-4.01 T=  5488 logg=2.69
# Changing to met=-2.50 for met=-4.01 T=  5480 logg=2.67
# Changing to met=-2.50 for met=-4.01 T=  5473 logg=2.65
# Changing to met=-2.50 for met=-4.01 T=  5465 logg=2.63
# Changing to met=-2.50 for met=-4.01 T=  5458 logg=2.61
# Changing to met=-2.50 for met=-4.01 T=  5451 logg=2.59
# Changing to met=-2.50 for met=-4.01 T=  5443 logg=2.57
# Changing to met=-2.50 for met=-4.01 T=  5436 logg=2.56
# Changing to met=-2.50 for met=-4.01 T=  5428 logg=2.54
# Changing to met=-2.50 for met=-4.01 T=  5421 logg=2.52
# Changing to met=-2.50 for met=-4.01 T=  5413 logg=2.50
# Changing to met=-2.50 for met=-4.01 T=  5406 logg=2.48
# Changing to met=-2.50 for met=-4.01 T=  5398 logg=2.46
# Changing to met=-2.50 for met=-4.01 T=  5390 logg=2.44
# Changing to met=-2.50 for met=-4.01 T=  5383 logg=2.42
# Changing to met=-2.50 for met=-4.01 T=  5375 logg=2.41
# Changing to met=-2.50 for met=-4.01 T=  5367 logg=2.39
# Changing to met=-2.50 for met=-4.01 T=  5360 logg=2.37
# Changing to met=-2.50 for met=-4.01 T=  5352 logg=2.35
# Changing to met=-2.50 for met=-4.01 T=  5344 logg=2.33
# Changing to met=-2.50 for met=-4.01 T=  5336 logg=2.31
# Changing to met=-2.50 for met=-4.01 T=  5328 logg=2.29
# Changing to met=-2.50 for met=-4.01 T=  5320 logg=2.27
# Changing to met=-2.50 for met=-4.01 T=  5312 logg=2.25
# Changing to met=-2.50 for met=-4.01 T=  5304 logg=2.24
# Changing to met=-2.50 for met=-4.01 T=  5296 logg=2.22
# Changing to met=-2.50 for met=-4.01 T=  5288 logg=2.20
# Changing to met=-2.50 for met=-4.01 T=  5280 logg=2.18
# Changing to met=-2.50 for met=-4.01 T=  5272 logg=2.16
# Changing to met=-2.50 for met=-4.01 T=  5264 logg=2.14
# Changing to met=-2.50 for met=-4.01 T=  5256 logg=2.12
# Changing to met=-2.50 for met=-4.01 T=  5248 logg=2.10
# Changing to met=-2.50 for met=-4.01 T=  5240 logg=2.08
# Changing to met=-2.50 for met=-4.01 T=  5232 logg=2.06
# Changing to met=-2.50 for met=-4.01 T=  5224 logg=2.05
# Changing to met=-2.50 for met=-4.01 T=  5215 logg=2.03
# Changing to met=-2.50 for met=-4.01 T=  5207 logg=2.01
# Changing to met=-2.50 for met=-4.01 T=  5199 logg=1.99
# Changing to met=-2.50 for met=-4.01 T=  5190 logg=1.97
# Changing to met=-2.50 for met=-4.01 T=  5182 logg=1.95
# Changing to met=-2.50 for met=-4.01 T=  5174 logg=1.93
# Changing to met=-2.50 for met=-4.01 T=  5165 logg=1.91
# Changing to met=-2.50 for met=-4.01 T=  5157 logg=1.89
# Changing to met=-2.50 for met=-4.01 T=  5149 logg=1.87
# Changing to met=-2.50 for met=-4.01 T=  5140 logg=1.85
# Changing to met=-2.50 for met=-4.01 T=  5132 logg=1.83
# Changing to met=-2.50 for met=-4.01 T=  5124 logg=1.82
# Changing to met=-2.50 for met=-4.01 T=  5116 logg=1.80
# Changing to met=-2.50 for met=-4.01 T=  5109 logg=1.78
# Changing to met=-2.50 for met=-4.01 T=  5101 logg=1.76
# Changing to met=-2.50 for met=-4.01 T=  5092 logg=1.74
# Changing to met=-2.50 for met=-4.01 T=  5084 logg=1.72
# Changing to met=-2.50 for met=-4.01 T=  5075 logg=1.70
# Changing to met=-2.50 for met=-4.01 T=  5067 logg=1.68
# Changing to met=-2.50 for met=-4.01 T=  5058 logg=1.66
# Changing to met=-2.50 for met=-4.01 T=  5050 logg=1.64
# Changing to met=-2.50 for met=-4.01 T=  5041 logg=1.62
# Changing to met=-2.50 for met=-4.01 T=  5033 logg=1.60
# Changing to met=-2.50 for met=-4.01 T=  5024 logg=1.59
# Changing to met=-2.50 for met=-4.01 T=  5016 logg=1.57
# Changing to met=-2.50 for met=-4.01 T=  5008 logg=1.55
# Changing to met=-4.00 for met=-4.01 T=  4999 logg=1.53
# Changing to met=-4.00 for met=-4.01 T=  4991 logg=1.51
# Changing to met=-4.00 for met=-4.01 T=  4982 logg=1.49
# Changing to met=-4.00 for met=-4.01 T=  4974 logg=1.47
# Changing to met=-4.00 for met=-4.01 T=  4966 logg=1.45
# Changing to met=-4.00 for met=-4.01 T=  4958 logg=1.43
# Changing to met=-4.00 for met=-4.01 T=  4950 logg=1.41
# Changing to met=-4.00 for met=-4.01 T=  4942 logg=1.39
# Changing to met=-4.00 for met=-4.01 T=  4933 logg=1.37
# Changing to met=-4.00 for met=-4.01 T=  4925 logg=1.35
# Changing to met=-4.00 for met=-4.01 T=  4917 logg=1.33
# Changing to met=-4.00 for met=-4.01 T=  4909 logg=1.31
# Changing to met=-4.00 for met=-4.01 T=  4901 logg=1.30
# Changing to met=-4.00 for met=-4.01 T=  4893 logg=1.28
# Changing to met=-4.00 for met=-4.01 T=  4885 logg=1.26
# Changing to met=-4.00 for met=-4.01 T=  4877 logg=1.24
# Changing to met=-4.00 for met=-4.01 T=  4869 logg=1.22
# Changing to met=-4.00 for met=-4.01 T=  4861 logg=1.20
# Changing to met=-4.00 for met=-4.01 T=  4854 logg=1.18
# Changing to met=-4.00 for met=-4.01 T=  4846 logg=1.16
# Changing to met=-4.00 for met=-4.01 T=  4839 logg=1.14
# Changing to met=-4.00 for met=-4.01 T=  4832 logg=1.12
# Changing to met=-4.00 for met=-4.01 T=  4825 logg=1.10
# Changing to met=-4.00 for met=-4.01 T=  4818 logg=1.08
# Changing to met=-4.00 for met=-4.01 T=  4811 logg=1.06
# Changing to met=-4.00 for met=-4.01 T=  4805 logg=1.05
# Changing to met=-4.00 for met=-4.01 T=  4800 logg=1.03
# Changing to met=-4.00 for met=-4.01 T=  4795 logg=1.01
# Changing to met=-4.00 for met=-4.01 T=  4790 logg=0.99
# Changing to met=-4.00 for met=-4.01 T=  4793 logg=0.99
# Changing to met=-4.00 for met=-4.01 T=  4859 logg=1.11
# Changing to met=-4.00 for met=-4.01 T=  4924 logg=1.23
# Changing to met=-4.00 for met=-4.01 T=  4990 logg=1.35
# Changing to met=-2.50 for met=-4.01 T=  5048 logg=1.47
# Changing to met=-2.50 for met=-4.01 T=  5012 logg=1.41
# Changing to met=-4.00 for met=-4.01 T=  4959 logg=1.28
# Changing to met=-4.00 for met=-4.01 T=  4899 logg=1.16
# Changing to met=-4.00 for met=-4.01 T=  4882 logg=1.12
# Changing to met=-4.00 for met=-4.01 T=  4945 logg=1.25
# Changing to met=-4.00 for met=-4.01 T=  4953 logg=1.27
# Changing to met=-4.00 for met=-4.01 T=  4911 logg=1.18
# Changing to met=-4.00 for met=-4.01 T=  4974 logg=1.30
# Changing to met=-4.00 for met=-4.01 T=  4979 logg=1.32
# Changing to met=-4.00 for met=-4.01 T=  4956 logg=1.27
# Changing to met=-2.50 for met=-4.01 T=  5021 logg=1.39
# Changing to met=-4.00 for met=-4.01 T=  4989 logg=1.33
# Changing to met=-2.50 for met=-4.01 T=  5028 logg=1.40
# Changing to met=-2.50 for met=-4.01 T=  5040 logg=1.43
# Changing to met=-2.50 for met=-4.01 T=  5066 logg=1.46
# Changing to met=-2.50 for met=-4.01 T=  5077 logg=1.49
# Changing to met=-2.50 for met=-4.01 T=  5138 logg=1.57
# Changing to met=-2.50 for met=-4.01 T=  5220 logg=1.62
# Changing to met=-2.50 for met=-4.01 T=  5417 logg=1.70
# Changing to met=-2.50 for met=-4.01 T=  5744 logg=1.80
# Changing to met=-2.50 for met=-4.01 T=  6067 logg=1.92
# Making photometry for isochrone: log(t) = 10.15  AKs = 0.00  dist = 10
#      Starting at:  2025-06-05 10:02:22.249578   Usually takes ~5 minutes
# Starting filter: jwst,F210M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3961 K  m_jwst_F210M = 9.89
# M =   0.618 Msun  T =  5712 K  m_jwst_F210M = 4.53
# M =   0.777 Msun  T =  6637 K  m_jwst_F210M = 1.85
# M =   0.785 Msun  T =  5165 K  m_jwst_F210M = -2.47
#       Time taken: 2.37 seconds
# Found 15 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.15 [M/H]=-3.4990758306077128 for 94 stars
# Missing photometry for 1 filter - recomputing these columns: ['jwst,F210M']
# Loading stellar spectra
# Changing to met=-2.50 for met=-3.50 T=  5033 logg=4.82
# Changing to met=-2.50 for met=-3.50 T=  5075 logg=4.81
# Changing to met=-2.50 for met=-3.50 T=  5117 logg=4.80
# Changing to met=-2.50 for met=-3.50 T=  5160 logg=4.80
# Changing to met=-2.50 for met=-3.50 T=  5204 logg=4.79
# Changing to met=-2.50 for met=-3.50 T=  5250 logg=4.78
# Changing to met=-2.50 for met=-3.50 T=  5297 logg=4.77
# Changing to met=-2.50 for met=-3.50 T=  5345 logg=4.76
# Changing to met=-2.50 for met=-3.50 T=  5394 logg=4.75
# Changing to met=-2.50 for met=-3.50 T=  5443 logg=4.74
# Changing to met=-2.50 for met=-3.50 T=  5493 logg=4.73
# Changing to met=-2.50 for met=-3.50 T=  5544 logg=4.72
# Changing to met=-2.50 for met=-3.50 T=  5596 logg=4.71
# Changing to met=-2.50 for met=-3.50 T=  5621 logg=4.71
# Changing to met=-2.50 for met=-3.50 T=  5645 logg=4.70
# Changing to met=-2.50 for met=-3.50 T=  5670 logg=4.70
# Changing to met=-2.50 for met=-3.50 T=  5695 logg=4.69
# Changing to met=-2.50 for met=-3.50 T=  5720 logg=4.69
# Changing to met=-2.50 for met=-3.50 T=  5745 logg=4.68
# Changing to met=-2.50 for met=-3.50 T=  5770 logg=4.68
# Changing to met=-2.50 for met=-3.50 T=  5795 logg=4.67
# Changing to met=-2.50 for met=-3.50 T=  5820 logg=4.67
# Changing to met=-2.50 for met=-3.50 T=  5844 logg=4.66
# Changing to met=-2.50 for met=-3.50 T=  5869 logg=4.66
# Changing to met=-2.50 for met=-3.50 T=  5894 logg=4.65
# Changing to met=-2.50 for met=-3.50 T=  5919 logg=4.65
# Changing to met=-2.50 for met=-3.50 T=  5944 logg=4.64
# Changing to met=-2.50 for met=-3.50 T=  5968 logg=4.64
# Changing to met=-2.50 for met=-3.50 T=  5993 logg=4.63
# Changing to met=-2.50 for met=-3.50 T=  6017 logg=4.62
# Changing to met=-2.50 for met=-3.50 T=  6042 logg=4.62
# Changing to met=-2.50 for met=-3.50 T=  6066 logg=4.61
# Changing to met=-2.50 for met=-3.50 T=  6091 logg=4.61
# Changing to met=-2.50 for met=-3.50 T=  6115 logg=4.60
# Changing to met=-2.50 for met=-3.50 T=  6139 logg=4.60
# Changing to met=-2.50 for met=-3.50 T=  6163 logg=4.59
# Changing to met=-2.50 for met=-3.50 T=  6187 logg=4.58
# Changing to met=-2.50 for met=-3.50 T=  6211 logg=4.58
# Changing to met=-2.50 for met=-3.50 T=  6234 logg=4.57
# Changing to met=-2.50 for met=-3.50 T=  6258 logg=4.57
# Changing to met=-2.50 for met=-3.50 T=  6281 logg=4.56
# Changing to met=-2.50 for met=-3.50 T=  6304 logg=4.56
# Changing to met=-2.50 for met=-3.50 T=  6327 logg=4.55
# Changing to met=-2.50 for met=-3.50 T=  6350 logg=4.54
# Changing to met=-2.50 for met=-3.50 T=  6373 logg=4.54
# Changing to met=-2.50 for met=-3.50 T=  6395 logg=4.53
# Changing to met=-2.50 for met=-3.50 T=  6417 logg=4.52
# Changing to met=-2.50 for met=-3.50 T=  6439 logg=4.52
# Changing to met=-2.50 for met=-3.50 T=  6460 logg=4.51
# Changing to met=-2.50 for met=-3.50 T=  6482 logg=4.51
# Changing to met=-2.50 for met=-3.50 T=  6503 logg=4.50
# Changing to met=-2.50 for met=-3.50 T=  6523 logg=4.49
# Changing to met=-2.50 for met=-3.50 T=  6544 logg=4.49
# Changing to met=-2.50 for met=-3.50 T=  6564 logg=4.48
# Changing to met=-2.50 for met=-3.50 T=  6584 logg=4.47
# Changing to met=-2.50 for met=-3.50 T=  6603 logg=4.47
# Changing to met=-2.50 for met=-3.50 T=  6622 logg=4.46
# Changing to met=-2.50 for met=-3.50 T=  6641 logg=4.45
# Changing to met=-2.50 for met=-3.50 T=  6659 logg=4.44
# Changing to met=-2.50 for met=-3.50 T=  6677 logg=4.44
# Changing to met=-2.50 for met=-3.50 T=  6695 logg=4.43
# Changing to met=-2.50 for met=-3.50 T=  6712 logg=4.42
# Changing to met=-2.50 for met=-3.50 T=  6729 logg=4.42
# Changing to met=-2.50 for met=-3.50 T=  6745 logg=4.41
# Changing to met=-2.50 for met=-3.50 T=  6761 logg=4.40
# Changing to met=-2.50 for met=-3.50 T=  6776 logg=4.39
# Changing to met=-2.50 for met=-3.50 T=  6792 logg=4.39
# Changing to met=-2.50 for met=-3.50 T=  6806 logg=4.38
# Changing to met=-2.50 for met=-3.50 T=  6821 logg=4.37
# Changing to met=-2.50 for met=-3.50 T=  6835 logg=4.36
# Changing to met=-2.50 for met=-3.50 T=  6848 logg=4.35
# Changing to met=-2.50 for met=-3.50 T=  6861 logg=4.35
# Changing to met=-2.50 for met=-3.50 T=  6874 logg=4.34
# Changing to met=-2.50 for met=-3.50 T=  6886 logg=4.33
# Changing to met=-2.50 for met=-3.50 T=  6898 logg=4.32
# Changing to met=-2.50 for met=-3.50 T=  6909 logg=4.31
# Changing to met=-2.50 for met=-3.50 T=  6920 logg=4.30
# Changing to met=-2.50 for met=-3.50 T=  6930 logg=4.30
# Changing to met=-2.50 for met=-3.50 T=  6940 logg=4.29
# Changing to met=-2.50 for met=-3.50 T=  6950 logg=4.28
# Changing to met=-2.50 for met=-3.50 T=  6959 logg=4.27
# Changing to met=-2.50 for met=-3.50 T=  6968 logg=4.26
# Changing to met=-2.50 for met=-3.50 T=  6976 logg=4.25
# Changing to met=-2.50 for met=-3.50 T=  6984 logg=4.24
# Changing to met=-2.50 for met=-3.50 T=  6991 logg=4.23
# Changing to met=-2.50 for met=-3.50 T=  6997 logg=4.22
# Changing to met=-2.50 for met=-3.50 T=  7003 logg=4.21
# Changing to met=-2.50 for met=-3.50 T=  7008 logg=4.21
# Changing to met=-2.50 for met=-3.50 T=  7012 logg=4.20
# Changing to met=-2.50 for met=-3.50 T=  7015 logg=4.19
# Changing to met=-2.50 for met=-3.50 T=  7018 logg=4.18
# Changing to met=-2.50 for met=-3.50 T=  7020 logg=4.17
# Changing to met=-2.50 for met=-3.50 T=  7021 logg=4.16
# Changing to met=-2.50 for met=-3.50 T=  7022 logg=4.15
# Changing to met=-2.50 for met=-3.50 T=  7021 logg=4.13
# Changing to met=-2.50 for met=-3.50 T=  7019 logg=4.12
# Changing to met=-2.50 for met=-3.50 T=  7017 logg=4.11
# Changing to met=-2.50 for met=-3.50 T=  7013 logg=4.10
# Changing to met=-2.50 for met=-3.50 T=  7008 logg=4.09
# Changing to met=-2.50 for met=-3.50 T=  7003 logg=4.08
# Changing to met=-2.50 for met=-3.50 T=  6996 logg=4.07
# Changing to met=-2.50 for met=-3.50 T=  6989 logg=4.06
# Changing to met=-2.50 for met=-3.50 T=  6980 logg=4.05
# Changing to met=-2.50 for met=-3.50 T=  6971 logg=4.04
# Changing to met=-2.50 for met=-3.50 T=  6961 logg=4.03
# Changing to met=-2.50 for met=-3.50 T=  6949 logg=4.01
# Changing to met=-2.50 for met=-3.50 T=  6937 logg=4.00
# Changing to met=-2.50 for met=-3.50 T=  6925 logg=3.99
# Changing to met=-2.50 for met=-3.50 T=  6911 logg=3.98
# Changing to met=-2.50 for met=-3.50 T=  6897 logg=3.97
# ...
# Changing to met=-2.00 for met=-2.01 T= 58089 logg=7.52
# Changing to T= 50000 for met=-2.01 T= 57172 logg=7.53
# Changing to logg=5.00 for met=-2.01 T= 57172 logg=7.53
# Changing to met=-2.00 for met=-2.01 T= 57172 logg=7.53
# Changing to T= 50000 for met=-2.01 T= 56261 logg=7.54
# Changing to logg=5.00 for met=-2.01 T= 56261 logg=7.54
# Changing to met=-2.00 for met=-2.01 T= 56261 logg=7.54
# Changing to T= 50000 for met=-2.01 T= 55358 logg=7.55
# Changing to logg=5.00 for met=-2.01 T= 55358 logg=7.55
# Changing to met=-2.00 for met=-2.01 T= 55358 logg=7.55
# Changing to T= 50000 for met=-2.01 T= 54463 logg=7.56
# Changing to logg=5.00 for met=-2.01 T= 54463 logg=7.56
# Changing to met=-2.00 for met=-2.01 T= 54463 logg=7.56
# Changing to T= 50000 for met=-2.01 T= 53576 logg=7.57
# Changing to logg=5.00 for met=-2.01 T= 53576 logg=7.57
# Changing to met=-2.00 for met=-2.01 T= 53576 logg=7.57
# Changing to T= 50000 for met=-2.01 T= 52697 logg=7.58
# Changing to logg=5.00 for met=-2.01 T= 52697 logg=7.58
# Changing to met=-2.00 for met=-2.01 T= 52697 logg=7.58
# Changing to T= 50000 for met=-2.01 T= 51828 logg=7.59
# Changing to logg=5.00 for met=-2.01 T= 51828 logg=7.59
# Changing to met=-2.00 for met=-2.01 T= 51828 logg=7.59
# Changing to T= 50000 for met=-2.01 T= 50969 logg=7.59
# Changing to logg=5.00 for met=-2.01 T= 50969 logg=7.59
# Changing to met=-2.00 for met=-2.01 T= 50969 logg=7.59
# Changing to T= 50000 for met=-2.01 T= 50120 logg=7.60
# Changing to logg=5.00 for met=-2.01 T= 50120 logg=7.60
# Changing to met=-2.00 for met=-2.01 T= 50120 logg=7.60
# Changing to logg=5.00 for met=-2.01 T= 49281 logg=7.61
# Changing to met=-2.00 for met=-2.01 T= 49281 logg=7.61
# Changing to logg=5.00 for met=-2.01 T= 48452 logg=7.62
# Changing to met=-2.00 for met=-2.01 T= 48452 logg=7.62
# Changing to logg=5.00 for met=-2.01 T= 47634 logg=7.62
# Changing to met=-2.00 for met=-2.01 T= 47634 logg=7.62
# Changing to logg=5.00 for met=-2.01 T= 46827 logg=7.63
# Changing to met=-2.00 for met=-2.01 T= 46827 logg=7.63
# Changing to logg=5.00 for met=-2.01 T= 46031 logg=7.64
# Changing to met=-2.00 for met=-2.01 T= 46031 logg=7.64
# Changing to logg=5.00 for met=-2.01 T= 45246 logg=7.64
# Changing to met=-2.00 for met=-2.01 T= 45246 logg=7.64
# Changing to logg=5.00 for met=-2.01 T= 44472 logg=7.65
# Changing to met=-2.00 for met=-2.01 T= 44472 logg=7.65
# Changing to logg=5.00 for met=-2.01 T= 43709 logg=7.66
# Changing to met=-2.00 for met=-2.01 T= 43709 logg=7.66
# Changing to logg=5.00 for met=-2.01 T= 42956 logg=7.66
# Changing to met=-2.00 for met=-2.01 T= 42956 logg=7.66
# Changing to logg=5.00 for met=-2.01 T= 42215 logg=7.67
# Changing to met=-2.00 for met=-2.01 T= 42215 logg=7.67
# Changing to logg=5.00 for met=-2.01 T= 41485 logg=7.67
# Changing to met=-2.00 for met=-2.01 T= 41485 logg=7.67
# Changing to logg=5.00 for met=-2.01 T= 40766 logg=7.68
# Changing to met=-2.00 for met=-2.01 T= 40766 logg=7.68
# Changing to logg=5.00 for met=-2.01 T= 40058 logg=7.68
# Changing to met=-2.00 for met=-2.01 T= 40058 logg=7.68
# Changing to logg=5.00 for met=-2.01 T= 39360 logg=7.69
# Changing to met=-2.00 for met=-2.01 T= 39360 logg=7.69
# Changing to logg=5.00 for met=-2.01 T= 38673 logg=7.69
# Changing to met=-2.00 for met=-2.01 T= 38673 logg=7.69
# Changing to logg=5.00 for met=-2.01 T= 37997 logg=7.70
# Changing to met=-2.00 for met=-2.01 T= 37997 logg=7.70
# Changing to logg=5.00 for met=-2.01 T= 37332 logg=7.70
# Changing to met=-2.00 for met=-2.01 T= 37332 logg=7.70
# Changing to logg=5.00 for met=-2.01 T= 36677 logg=7.71
# Changing to met=-2.00 for met=-2.01 T= 36677 logg=7.71
# Changing to logg=5.00 for met=-2.01 T= 36032 logg=7.71
# Changing to met=-2.00 for met=-2.01 T= 36032 logg=7.71
# Changing to logg=5.00 for met=-2.01 T= 35397 logg=7.72
# Changing to met=-2.00 for met=-2.01 T= 35397 logg=7.72
# Changing to logg=5.00 for met=-2.01 T= 34773 logg=7.72
# Changing to met=-2.00 for met=-2.01 T= 34773 logg=7.72
# Changing to logg=5.00 for met=-2.01 T= 34158 logg=7.73
# Changing to met=-2.00 for met=-2.01 T= 34158 logg=7.73
# Changing to logg=5.00 for met=-2.01 T= 33554 logg=7.73
# Changing to met=-2.00 for met=-2.01 T= 33554 logg=7.73
# Changing to logg=5.00 for met=-2.01 T= 32959 logg=7.73
# Changing to met=-2.00 for met=-2.01 T= 32959 logg=7.73
# Changing to logg=5.00 for met=-2.01 T= 32374 logg=7.74
# Changing to met=-2.00 for met=-2.01 T= 32374 logg=7.74
# Changing to logg=5.00 for met=-2.01 T= 31799 logg=7.74
# Changing to met=-2.00 for met=-2.01 T= 31799 logg=7.74
# Changing to logg=5.00 for met=-2.01 T= 31233 logg=7.75
# Changing to met=-2.00 for met=-2.01 T= 31233 logg=7.75
# Changing to logg=5.00 for met=-2.01 T= 30676 logg=7.75
# Changing to met=-2.00 for met=-2.01 T= 30676 logg=7.75
# Changing to logg=5.00 for met=-2.01 T= 30129 logg=7.75
# Changing to met=-2.00 for met=-2.01 T= 30129 logg=7.75
# Changing to logg=5.00 for met=-2.01 T= 29591 logg=7.76
# Changing to met=-2.00 for met=-2.01 T= 29591 logg=7.76
# Changing to logg=5.00 for met=-2.01 T= 29061 logg=7.76
# Changing to met=-2.00 for met=-2.01 T= 29061 logg=7.76
# Changing to logg=5.00 for met=-2.01 T= 28541 logg=7.76
# Changing to met=-2.00 for met=-2.01 T= 28541 logg=7.76
# Changing to logg=5.00 for met=-2.01 T= 28030 logg=7.77
# Changing to met=-2.00 for met=-2.01 T= 28030 logg=7.77
# Changing to logg=5.00 for met=-2.01 T= 27528 logg=7.77
# Changing to met=-2.00 for met=-2.01 T= 27528 logg=7.77
# Changing to logg=5.00 for met=-2.01 T= 27034 logg=7.77
# Changing to met=-2.00 for met=-2.01 T= 27034 logg=7.77
# Changing to logg=5.00 for met=-2.01 T= 26549 logg=7.78
# Changing to met=-2.00 for met=-2.01 T= 26549 logg=7.78
# Changing to logg=5.00 for met=-2.01 T= 26072 logg=7.78
# Changing to met=-2.00 for met=-2.01 T= 26072 logg=7.78
# Changing to logg=5.00 for met=-2.01 T= 25603 logg=7.78
# Changing to met=-2.00 for met=-2.01 T= 25603 logg=7.78
# Changing to logg=5.00 for met=-2.01 T= 25143 logg=7.79
# Changing to met=-2.00 for met=-2.01 T= 25143 logg=7.79
# Changing to logg=5.00 for met=-2.01 T= 24691 logg=7.79
# Changing to met=-2.00 for met=-2.01 T= 24691 logg=7.79
# Changing to logg=5.00 for met=-2.01 T= 24246 logg=7.79
# Changing to met=-2.00 for met=-2.01 T= 24246 logg=7.79
# Changing to logg=5.00 for met=-2.01 T= 23809 logg=7.80
# Changing to met=-2.00 for met=-2.01 T= 23809 logg=7.80
# Changing to logg=5.00 for met=-2.01 T= 23381 logg=7.80
# Changing to met=-2.00 for met=-2.01 T= 23381 logg=7.80
# Changing to logg=5.00 for met=-2.01 T= 22959 logg=7.80
# Changing to met=-2.00 for met=-2.01 T= 22959 logg=7.80
# Making photometry for isochrone: log(t) = 10.15  AKs = 0.00  dist = 10
#      Starting at:  2025-06-05 10:03:28.466283   Usually takes ~5 minutes
# Starting filter: jwst,F210M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3486 K  m_jwst_F210M = 9.43
# M =   0.607 Msun  T =  5536 K  m_jwst_F210M = 4.56
# M =   0.753 Msun  T =  6447 K  m_jwst_F210M = 2.39
# M =   0.766 Msun  T =  4861 K  m_jwst_F210M = -2.77
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pysynphot/observation.py:127, in validate_overlap(comp1, comp2, force)
#     126 try:
# --> 127     comp1=comp1.taper()
#     128 except AttributeError:
#
# AttributeError: 'CompositeSourceSpectrum' object has no attribute 'taper'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model.process_location(1,1,0.001)
#
# File ~/Documents/synthpop/synthpop/synthpop_main.py:564, in SynthPop.process_location(self, l_deg, b_deg, solid_angle, solid_angle_unit, save_data)
#     562 # Step 2: Generate all the fields for each population
#     563 ti = time.time()
# --> 564 field_df, distributions = self.generate_fields()
#     565 t1 = time.time() - ti
#     567 # Step 3: Save the results
#
# File ~/Documents/synthpop/synthpop/synthpop_main.py:366, in SynthPop.generate_fields(self)
#     362 distributions = {}
#     364 for population in self.populations:
#     365     # for each population, generate the field
# --> 366     population_df, pop_distributions = population.generate_field()
#     368     # collect distribution under the population name
#     369     # be careful if two populations share the same name
#     370     distributions[population.name] = pop_distributions
#
# File ~/Documents/synthpop/synthpop/population.py:848, in Population.generate_field(self)
#     843     final_expected_loop=True
#     844     gen_stars_chunk = np.copy(gen_missing_stars)
#     846 position, r_inner, proper_motions, velocities, vr_lsr, \
#     847 (m_initial, age, met, ref_mag, s_props, final_phase_flag,
# --> 848     inside_grid, not_evolved) = self.generator.generate_stars(radii,
#     849     gen_stars_chunk, mass_limit, self.do_kinematics, props_list)
#     851 initial_parameters = np.column_stack([m_initial, age, met])
#     853 # extract magnitudes and convert to observed magnitudes if needed
#
# File ~/Documents/synthpop/synthpop/spisea_generator.py:170, in SpiseaGenerator.generate_stars(self, radii, missing_stars, mass_limit, do_kinematics, props, avg_mass_per_star)
#     166     velocities = np.column_stack([u, v, w, ])
#     168 # generate star at the positions
#     169 return position, r_inner, proper_motions, velocities, vr_lsr, \
# --> 170     self.generate_star_at_location(
#     171     position[:, 0:3], props, min_mass, self.max_mass, avg_mass_per_star=avg_mass_per_star)
#
# File ~/Documents/synthpop/synthpop/spisea_generator.py:236, in SpiseaGenerator.generate_star_at_location(self, position, props, min_mass, max_mass, avg_mass_per_star)
#     234 # Loop until we have enough stars
#     235 while cluster_stars_needed > 0:
# --> 236     isochrone = spisea_synthetic.IsochronePhot(logAge=bin2d[0], AKs=0,
#     237                         distance=10, metallicity=bin2d[1],
#     238                         evo_model=self.spisea_evo_model, atm_func=self.spisea_atm_func,
#     239                         wd_atm_func=self.spisea_wd_atm_func, iso_dir=self.spisea_dir,
#     240                         min_mass=min_mass, max_mass=max_mass,
#     241                         filters=self.spisea_filters)
#     242     cluster=spisea_synthetic.ResolvedCluster(isochrone, self.spisea_imf, generate_mass, ifmr=self.spisea_ifmr)
#     243     clusters.append(cluster.star_systems.to_pandas())
#
# File ~/Documents/spisea/spisea/synthetic.py:1065, in IsochronePhot.__init__(self, logAge, AKs, distance, metallicity, evo_model, atm_func, wd_atm_func, wave_range, red_law, mass_sampling, iso_dir, min_mass, max_mass, rebin, recomp, filters)
#    1062         # Save the final spectrum to our spec_list for later use.
#    1063         self.spec_list.append(star)
# -> 1065     self.make_photometry(rebin=rebin, vega=vega, comp_filters=comp_filters)
#    1067 return
#
# File ~/Documents/spisea/spisea/synthetic.py:1109, in IsochronePhot.make_photometry(self, rebin, vega, comp_filters)
#    1107 for ss in range(npoints):
#    1108     star = self.spec_list[ss]  # These are already extincted, observed spectra.
# -> 1109     star_mag = mag_in_filter(star, filt)
#    1111     self.points[col_name][ss] = star_mag
#    1113     if (self.verbose and (ss % 100) == 0):
#
# File ~/Documents/spisea/spisea/synthetic.py:1756, in mag_in_filter(star, filt)
#    1751 def mag_in_filter(star, filt):
#    1752     """
#    1753     Assumes that extinction is already resampled to same wavelengths
#    1754     as filter, and has been applied.
#    1755     """
# -> 1756     star_in_filter = obs.Observation(star, filt, binset=filt.wave, force='taper')
#    1757     #star_flux = star_in_filter.binflux.sum()
#    1758     diff = np.diff(star_in_filter.binwave)
#
# File ~/anaconda3/lib/python3.11/site-packages/pysynphot/observation.py:215, in Observation.__init__(self, spec, band, binset, force)
#     213 self.bandpass = band
#     214 self.warnings={}
# --> 215 self.validate_overlap(force)
#     216 self.binset = binset
#     218 keep=self.warnings
#
# File ~/anaconda3/lib/python3.11/site-packages/pysynphot/observation.py:250, in Observation.validate_overlap(self, force)
#     237 """Validate that spectrum and bandpass overlap.
#     238 Warnings are stored in ``self.warnings``.
#     239
#    (...)
#     246
#     247 """
#     249 #Wrap the function for convenience
# --> 250 self.spectrum, self.bandpass, warn = validate_overlap(self.spectrum,
#     251                                                       self.bandpass, force)
#     252 self.warnings.update(warn)
#
# File ~/anaconda3/lib/python3.11/site-packages/pysynphot/observation.py:129, in validate_overlap(comp1, comp2, force)
#     127         comp1=comp1.taper()
#     128     except AttributeError:
# --> 129         comp1=comp1.tabulate().taper()
#     130         warnings['PartialOverlap']=force
#     132 elif force.lower().startswith('extrap'):
#     133     #default behavior works, but check the overlap so we can set the warning
#
# File ~/anaconda3/lib/python3.11/site-packages/pysynphot/spectrum.py:938, in CompositeSourceSpectrum.tabulate(self)
#     921 def tabulate(self):
#     922     """Return a simplified version of the spectrum.
#     923
#     924     Composite spectrum can be overly complicated when it
#    (...)
#     936
#     937     """
# --> 938     sp = ArraySourceSpectrum(wave=self.wave,
#     939                              flux=self.flux,
#     940                              waveunits=self.waveunits,
#     941                              fluxunits=self.fluxunits,
#     942                              name='%s (tabulated)' % self.name)
#     943     return sp
#
# File ~/anaconda3/lib/python3.11/site-packages/pysynphot/spectrum.py:363, in SourceSpectrum._getWaveProp(self)
#     362 def _getWaveProp(self):
# --> 363     wave, flux = self.getArrays()
#     364     return wave
#
# File ~/anaconda3/lib/python3.11/site-packages/pysynphot/spectrum.py:352, in SourceSpectrum.getArrays(self)
#     349 else:
#     350     area = None
# --> 352 wave = self.GetWaveSet()
#     353 flux = self(wave)
#     355 flux = units.Photlam().Convert(
#     356     wave, flux, self.fluxunits.name, area=area)
#
# File ~/anaconda3/lib/python3.11/site-packages/pysynphot/spectrum.py:919, in CompositeSourceSpectrum.GetWaveSet(self)
#     917 waveset1 = self.component1.GetWaveSet()
#     918 waveset2 = self.component2.GetWaveSet()
# --> 919 return MergeWaveSets(waveset1, waveset2)
#
# File ~/anaconda3/lib/python3.11/site-packages/pysynphot/spectrum.py:82, in MergeWaveSets(waveset1, waveset2)
#      80     MergedWaveSet = None
#      81 else:
# ---> 82     MergedWaveSet = N.union1d(waveset1, waveset2)
#      84     # The merged wave sets may sometimes contain numbers which are nearly
#      85     # equal but differ at levels as small as 1e-14. Having values this
#      86     # close together can cause problems down the line so here we test
#    (...)
#      90     # If small differences are present we make a copy of the union'ed array
#      91     # with the lower of the close together pairs removed.
#      92     delta = MergedWaveSet[1:] - MergedWaveSet[:-1]
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/lib/arraysetops.py:932, in union1d(ar1, ar2)
#     898 @array_function_dispatch(_union1d_dispatcher)
#     899 def union1d(ar1, ar2):
#     900     """
#     901     Find the union of two arrays.
#     902
#    (...)
#     930     array([1, 2, 3, 4, 6])
#     931     """
# --> 932     return unique(np.concatenate((ar1, ar2), axis=None))
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/lib/arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/lib/arraysetops.py:336, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     334     aux = ar[perm]
#     335 else:
# --> 336     ar.sort()
#     337     aux = ar
#     338 mask = np.empty(aux.shape, dtype=np.bool_)
#
# KeyboardInterrupt:

# %%
# Only re-run if needed - catalog generation
if True:
    for i,loc in enumerate(model.get_iter_loc()):
        if i==0:
        # run synthpop for the given location and solid angle
            model.process_location(*loc, model.parms.solid_angle[i], model.parms.solid_angle_unit,save_data=True)
# Out:
# ############################# update location #############################
#  36848 - # set location to:
#  36849 - l, b = (0.00 deg, 0.00 deg)
#  36850 - # set solid_angle to:
#  36850 - solid_angle = 1.000e-03 deg^2
#
#
# ############################# Generate Field ##############################
#
#
# # Population 0;  bulge ----------------------------------------------------
#  38719 - # From density profile (number density)
#  38719 - expected_total_iMass = 397391.0585
#  38720 - expected_total_eMass = 397391.0585
#  38720 - average_iMass_per_star = 0.5739
#  38720 - mass_loss_correction = 1.0000
#  38720 - n_expected_stars = 692480.6330
#  38721 - # Determine velocities when position are generated
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-1.7543483357110188 for 3 stars
# Found 14 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-1.4990758306077128 for 61 stars
# Found 65 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-1.249198357391113 for
stars
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# Found 341966 stars out of mass range
# Found 344088 stars out of mass range
# Found 342936 stars out of mass range
# Found 344030 stars out of mass range
# Found 342153 stars out of mass range
# Found 341677 stars out of mass range
# Found 341029 stars out of mass range
# Found 341632 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=0.5009241693922871 for 289888 stars
# Found 207015 stars out of mass range
# Found 206164 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-1.7543483357110188 for 1 stars
# Found 21 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-1.4990758306077128 for 64 stars
# Found 55 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-1.249198357391113 for 851 stars
# Found 826 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-1.0061603087048185 for 6626 stars
# Found 6220 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-0.7543483357110189 for 26895 stars
# Found 24389 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-0.4990758306077128 for 58475 stars
# Found 53473 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-0.24919835739111287 for 80373 stars
# Found 73362 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-0.006160308704818447 for 146535 stars
# Found 181485 stars out of mass range
# Found 182241 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=0.24565166428898116 for 232295 stars
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# Found 341044 stars out of mass range
# Found 340737 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=0.5009241693922871 for 79592 stars
# Found 72154 stars out of mass range
#  60242 - # From Generated Field:
#  60242 - generated_stars = 2923691
#  60267 - generated_total_iMass = 2061981.2432
#  60442 - generated_total_eMass = 1316384.5750
#  60492 - det_mass_loss_corr = 0.6384
#  62766 - # Done
#
#
# # Population 3;  thick_disk -----------------------------------------------
#  63239 - # From density profile (number density)
#  63240 - expected_total_iMass = 28693.2977
#  63241 - expected_total_eMass = 3196.5543
#  63241 - average_iMass_per_star = 0.5739
#  63241 - mass_loss_correction = 1.0000
#  63241 - n_expected_stars = 50000.0000
#  63242 - # Determine velocities when position are generated
# Starting SPISEA cluster generation for bin log_age=10.1 [M/H]=-2.0061603087048185 for 6 stars
# Found 33 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.1 [M/H]=-1.7543483357110188 for 122 stars
# Found 128 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.1 [M/H]=-1.4990758306077128 for 1079 stars
# Found 937 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.1 [M/H]=-1.249198357391113 for 5017 stars
# Found 4539 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.1 [M/H]=-1.0061603087048185 for 12438 stars
# Found 11260 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.1 [M/H]=-0.7543483357110189 for 15843 stars
# Found 14420 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.1 [M/H]=-0.4990758306077128 for 10695 stars
# Found 9838 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.1 [M/H]=-0.24919835739111287 for 3686 stars
# Found 3386 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.1 [M/H]=-0.006160308704818447 for 659 stars
# Found 776 stars out of mass range
# Found 819 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.1 [M/H]=0.24565166428898116 for 69 stars
# Found 86 stars out of mass range
# Found 111 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.1 [M/H]=0.5009241693922871 for 4 stars
# Found 13 stars out of mass range
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
#  64573 - # From Generated Field:
#  64574 - generated_stars = 9310
#  64574 - generated_total_iMass = 4943.3739
#  64579 - generated_total_eMass = 3204.2125
#  64580 - det_mass_loss_corr = 0.6482
#  64584 - # Done
#
#
# # Population 4;  thin_disk_1 ----------------------------------------------
# Starting SPISEA cluster generation for bin log_age=10.1 [M/H]=-0.7543483357110189 for 1 stars
# Found 5 stars out of mass range
#  65019 - # From density profile (number density)
#  65020 - expected_total_iMass = 28693.2977
#  65020 - expected_total_eMass = 5810.1915
#  65020 - average_iMass_per_star = 0.5739
#  65021 - mass_loss_correction = 1.0000
#  65021 - n_expected_stars = 50000.0000
#  65021 - # Determine velocities when position are generated
# Starting SPISEA cluster generation for bin log_age=5.01 [M/H]=-0.24919835739111287 for 2 stars
# Found 18 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=5.01 [M/H]=-0.006160308704818447 for 22 stars
# Found 21 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=5.01 [M/H]=0.24565166428898116 for 4 stars
# Found 16 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=5.05 [M/H]=-0.24919835739111287 for 1 stars
# Found 20 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=5.05 [M/H]=-0.006160308704818447 for 5 stars
# Found 9 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=5.05 [M/H]=0.24565166428898116 for 1 stars
# Found 14 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=5.1 [M/H]=-0.006160308704818447 for 4 stars
# Found 16 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=5.1 [M/H]=0.24565166428898116 for 1 stars
# Found 13 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=5.15 [M/H]=-0.006160308704818447 for 5 stars
# Found 14 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=5.2 [M/H]=-0.24919835739111287 for 2 stars
# Found 13 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=5
stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.85 [M/H]=-0.7543483357110189 for 418 stars
# Found 437 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.85 [M/H]=-0.4990758306077128 for 1725 stars
# Found 1552 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.85 [M/H]=-0.24919835739111287 for 1833 stars
# Found 1688 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.85 [M/H]=-0.006160308704818447 for 505 stars
# Found 592 stars out of mass range
# Found 570 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.85 [M/H]=0.24565166428898116 for 32 stars
# Found 29 stars out of mass range
# Found 65 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.9 [M/H]=-1.249198357391113 for 1 stars
# Found 17 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.9 [M/H]=-1.0061603087048185 for 56 stars
# Found 59 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.9 [M/H]=-0.7543483357110189 for 784 stars
# Found 726 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.9 [M/H]=-0.4990758306077128 for 3182 stars
# Found 3016 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.9 [M/H]=-0.24919835739111287 for 3410 stars
# Found 3118 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.9 [M/H]=-0.006160308704818447 for 866 stars
# Found 1032 stars out of mass range
# Found 1018 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.9 [M/H]=0.24565166428898116 for 52 stars
# Found 126 stars out of mass range
# Found 82 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.9 [M/H]=0.5009241693922871 for 1 stars
# Found 3 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.95 [M/H]=-1.249198357391113 for 2 stars
# Found 16 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.95 [M/H]=-1.0061603087048185 for 51 stars
# Found 39 stars out of mass range
# Found 50 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.95 [M/H]=-0.7543483357110189 for 923 stars
# Found 746 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.95 [M/H]=-0.4990758306077128 for 3502 stars
# Found 3126 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.95 [M/H]=-0.24919835739111287 for 3626 stars
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
#  80949 - # From Generated Field:
#  80949 - generated_stars = 77011
#  80950 - generated_total_iMass = 42525.2243
#  80958 - generated_total_eMass = 27905.6800
#  80959 - det_mass_loss_corr = 0.6562
#  80982 - # Done
# Found 3039 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.95 [M/H]=-0.006160308704818447 for 960 stars
# Found 1128 stars out of mass range
# Found 1148 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.95 [M/H]=0.24565166428898116 for 48 stars
# Found 107 stars out of mass range
# Found 81 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=9.95 [M/H]=0.5009241693922871 for 1 stars
# Found 10 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-1.249198357391113 for 1 stars
# Found 12 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-1.0061603087048185 for 30 stars
# Found 24 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-0.7543483357110189 for 442 stars
# Found 422 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-0.4990758306077128 for 1986 stars
# Found 1826 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-0.24919835739111287 for 2075 stars
# Found 1768 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=-0.006160308704818447 for 508 stars
# Found 533 stars out of mass range
# Found 639 stars out of mass range
# Starting SPISEA cluster generation for bin log_age=10.0 [M/H]=0.24565166428898116 for 23 stars
# Found 52 stars out of mass range
# Found 33 stars out of mass range
# Found 32 stars out of mass range
# ########################### Combine Populations ###########################
#  81052 - Number of stars generated: 4028345 (28 columns)
#  81053 - included_columns = ['pop', 'iMass', 'age', 'Fe/H_initial', 'Mass', 'In_Final_Phase', 'Dist', 'l', 'b', 'vr_bc', 'mul', 'mub', 'x', 'y', 'z', 'U', 'V', 'W', 'VR_LSR', 'A_Ks', 'logL', 'logTeff', 'logg', 'log_radius', 'phase', '2mass-J', '2mass-H', '2mass-Ks']
#
#
# # Save result -------------------------------------------------------------
#  84208 - write result to "outputfiles/default/Huston2025_spisea_l0.000_b0.000.h5"
#  84485 - ---------------------------------------------------------------

# %%
# Catalog load
data0 = pd.read_hdf("outputfiles/default/Huston2025_spisea_l0.000_b0.000.h5")
data1 = pd.read_hdf("outputfiles/default/Huston2025_spisea_l90.000_b0.000.h5")
data2 = pd.read_hdf("outputfiles/default/Huston2025_spisea_l12.170_b5.370.h5")
data3 = pd.read_hdf("outputfiles/default/Huston2025_spisea_l39.140_b8.530.h5")
catalogs = [data0,data1,data2,data3]

# %%
data0
# Out:
#           pop     iMass   age  Fe/H_initial      Mass  In_Final_Phase  \
# 0         0.0  0.165037  10.0         -1.75  0.165035             0.0
# 1         0.0  0.577478  10.0         -1.50  0.577423             0.0
# 2         0.0  0.199050  10.0         -1.50  0.199046             0.0
# 3         0.0  0.126929  10.0         -1.50  0.126927             0.0
# 4         0.0  1.956425  10.0         -1.50  0.607250             1.0
# ...       ...       ...   ...           ...       ...             ...
# 4028340  10.0  1.640026  10.0          0.25  0.572763             1.0
# 4028341  10.0  0.302436  10.0          0.25  0.302430             0.0
# 4028342  10.0  0.728686  10.0          0.25  0.728629             0.0
# 4028343  10.0  0.382794  10.0          0.25  0.382787             0.0
# 4028344  10.0  0.544021  10.0          0.25  0.544004             0.0
#
#               Dist           l         b       vr_bc  ...     VR_LSR  \
# 0         4.143283  359.996296  0.015659  -76.769537  ... -67.521041
# 1         4.250496    0.009075 -0.004333  -67.853785  ... -58.604612
# 2         4.259367    0.007492 -0.012272  -52.070280  ... -42.822450
# 3         4.547927  359.990476 -0.014325 -102.672403  ... -93.428914
# 4         4.687393    0.006759  0.010156 -106.608642  ... -97.358274
# ...            ...         ...       ...         ...  ...        ...
# 4028340  24.926426  359.997649  0.011542  -12.753550  ...  -3.505222
# 4028341  24.932456  359.996635 -0.015529  -22.847630  ... -13.602805
# 4028342  24.900324  359.989143 -0.002646  -41.226230  ... -31.981662
# 4028343  24.914381  359.985561 -0.006123  -17.697976  ...  -8.454688
# 4028344  24.925460    0.010742 -0.001528   21.426045  ...  30.675960
#
#              A_Ks      logL   logTeff      logg  log_radius  phase    2mass-J  \
# 0        2.266830 -2.213528  3.587110  5.166922   -0.757312    0.0  29.755179
# 1        2.221838 -0.761327  3.705228  4.734214   -0.267447    0.0  26.357607
# 2        2.222715 -2.045981  3.591841  5.102889   -0.683001    0.0  29.251568
# 3        1.781607 -2.534569  3.560345  5.261708   -0.864303    0.0  28.975091
# 4        2.523125       NaN       NaN       NaN         NaN  101.0        NaN
# ...           ...       ...       ...       ...         ...    ...        ...
# 4028340  2.910000       NaN       NaN       NaN         NaN  101.0        NaN
# 4028341  2.656000 -2.062715  3.494461  4.916068   -0.496608    0.0  34.336076
# 4028342  2.656000 -0.779271  3.641966  4.599723   -0.149896    0.0  31.512600
# 4028343  2.656000 -1.785819  3.527814  4.870763   -0.424865    0.0  33.704014
# 4028344  2.772000 -1.328139  3.573413  4.748201   -0.287225    0.0  33.098083
#
#            2mass-H   2mass-Ks
# 0        25.372427  23.294354
# 1        22.158029  20.207269
# 2        24.921747  22.864684
# 3        25.384111  23.714992
# 4              NaN        NaN
# ...            ...        ...
# 4028340        NaN        NaN
# 4028341  29.262510  26.774613
# 4028342  26.378711  24.037342
# 4028343  28.602800  26.142311
# 4028344  27.747904  25.223524
#
# [4028345 rows x 28 columns]

# %% [markdown]
# ## Let's look at stellar density

# %%
# Set up histogram bins, and points for density function plotting.
dist_bins = np.arange(0.0,25.01, 0.5)
dist_binc = dist_bins[:-1] + np.diff(dist_bins)/2
dist_func_pts = np.arange(0.0,25.0001, 0.05)
ccycle = ['#377eb8', '#ff7f00', '#4daf4a', '#f781bf', '#a65628', '#984ea3', '#999999', '#e41a1c', '#dede00']

# %%
# Generic plotting code we can use for any population
def plot_pop_dens(pops, poplabel=None, ylim=None, legend=True):
    # Cycle through sight lines
    for sl in range(len(model.parms.l_set)):
        sum_catalog = np.zeros(len(dist_binc))
        sum_func = np.zeros(len(dist_func_pts))
        # Cycle through populations
        for pop in pops:
            # Bin catalog data - sum mass and divide by volume
            data_sl = catalogs[sl]
            l,b = model.parms.l_set[sl], model.parms.b_set[sl]
            cone_rads = np.sqrt(model.parms.solid_angle[sl]/np.pi) *np.pi/180
            cone_vol = np.pi * (cone_rads*dist_bins)**2 * dist_bins / 3
            cone_chunks = np.diff(cone_vol)
            binned_dists = pd.cut(data_sl.Dist, dist_bins)
            if model.populations[pop].population_density.density_unit=='number':
                sum_catalog += np.histogram(data_sl.where(data_sl['pop']==pop).Dist, bins=dist_bins)[0]
            else:
                sum_catalog += data_sl.where(data_sl['pop']==pop).groupby(binned_dists, observed=False).Mass.sum()
            # Get density function from model object
            r,phi,z = model.populations[pop].coord_trans.dlb_to_rphiz(dist_func_pts, l,b)
            sum_func += model.populations[pop].population_density.density(r,phi,z)
        sl_lab = '('+str(l)+', '+str(b)+')'
        # Plot the summed data
        plt.step(dist_binc, sum_catalog/cone_chunks, where='mid', c=ccycle[sl])
        plt.plot(dist_func_pts, sum_func, 
                     c=ccycle[sl], linewidth=5, alpha=0.25, label=sl_lab)
    # Plot labeling/formatting
    plt.yscale('log')
    print(model.populations[pop].population_density.density_unit)
    if model.populations[pop].population_density.density_unit=='number':
        plt.ylabel(r'Stellar Density [*/kpc$^3$]')
    else:
        plt.ylabel(r'Stellar Density [M$_\odot$/kpc$^3$]')
    plt.xlabel('Distance [kpc]')
    plt.xlim(0,25); plt.ylim(ylim)
    if legend: plt.legend()
    plt.title(poplabel, loc='left')
    plt.tight_layout()
    plt.savefig('validation_figures/spisea_'+poplabel.replace(' ','_')+'.pdf')

# %%
plot_pop_dens([0], poplabel='bulge', ylim=(1e4,3e10), legend=True)
# Out:
# mass

# %%
plot_pop_dens([1],poplabel='halo',ylim=(1e3,2e7), legend=False)
# Out:
# mass

# %%
plot_pop_dens([2],poplabel='nsd',ylim=(1e3,2e12), legend=False)
# Out:
# mass

# %%
plot_pop_dens([3], ylim=(1e4,1e8), poplabel='thick disk', legend=False)
# Out:
# mass

# %%
plot_pop_dens([4,5,6,7,8,9,10], ylim=(1e4,5e8), poplabel='thin disk', legend=False)
# Out:
# mass

# %% [markdown]
# ## Next: kinematics

# %%
kine_func_pts = np.arange(0.0,22.1501, 0.05)

# %%
def plot_kinematics_distr(sl, pop,ds=1):
    l,b = model.parms.l_set[sl], model.parms.b_set[sl]
    data = catalogs[sl][::ds]
    x,y,z = model.populations[pop].coord_trans.dlb_to_xyz(kine_func_pts, l,b)
    r,phi_rad,z2 = model.populations[pop].coord_trans.dlb_to_rphiz(kine_func_pts, l,b)
    
#     u1,v1,w1 = model.populations[pop].kinematics.mean_galactic_uvw(x,y,z)
#     u1p = u1 + model.populations[pop].kinematics.sigma_u * np.exp((r-model.populations[pop].kinematics.sun.r)*model.populations[pop].kinematics.disp_grad/2)
#     v1p,w1p = v1 + model.populations[pop].kinematics.sigma_v, w1 + model.populations[pop].kinematics.sigma_w
#     u1m = u1 - model.populations[pop].kinematics.sigma_u * np.exp((r-model.populations[pop].kinematics.sun.r)*model.populations[pop].kinematics.disp_grad/2)
#     v1m,w1m = v1 - model.populations[pop].kinematics.sigma_v, w1 - model.populations[pop].kinematics.sigma_w
    
#     u,v,w = u1 * np.cos(phi_rad) + v1 * np.sin(phi_rad), -u1 * np.sin(phi_rad) + v1 * np.cos(phi_rad), w1
#     u_p,v_p,w_p = u1p * np.cos(phi_rad) + v1p * np.sin(phi_rad), -u1p * np.sin(phi_rad) + v1p * np.cos(phi_rad), w1p
#     u_m,v_m,w_m = u1m * np.cos(phi_rad) + v1m * np.sin(phi_rad), -u1m * np.sin(phi_rad) + v1m * np.cos(phi_rad), w1m
    
    plt.subplots(nrows=1,ncols=3,figsize=(15,5))
    plt.subplot(131)
    plt.plot(data.where(data['pop']==pop).Dist, np.abs(data.where(data['pop']==pop)['V']), marker='.', markersize=0.2, linestyle='none', c='k')
    # plt.plot(kine_func_pts, np.abs(v), c='c', label='Function mean')
    # plt.plot(kine_func_pts, np.abs(v_p), c='c', linestyle='--', label=r'Function $\pm$ 1-sigma')
    # plt.plot(kine_func_pts, np.abs(v_m), c='c', linestyle='--')
    plt.ylabel('|V| (km/s)'); plt.xlabel('Distance (kpc)')
    plt.ylim(0,400)
    plt.xlim(0,25)
    
    plt.subplot(132)
    plt.plot(data.where(data['pop']==pop).Dist, data.where(data['pop']==pop)['U'], marker='.', markersize=0.2, linestyle='none', c='k')
    # plt.plot(kine_func_pts, u, c='c', label='Function mean')
    # plt.plot(kine_func_pts, u_p, c='c', linestyle='--', label=r'Function $\pm$ 1-sigma')
    # plt.plot(kine_func_pts, u_m, c='c', linestyle='--')
    plt.ylabel('U (km/s)'); plt.xlabel('Distance (kpc)')
    plt.ylim(-250,250)
    plt.xlim(0,25)
    
    plt.subplot(133)
    plt.plot(data.where(data['pop']==pop).Dist, data.where(data['pop']==pop)['W'], marker='.', markersize=0.2, linestyle='none', c='k')
    # plt.plot(kine_func_pts, w, c='c', label='Function mean')
    # plt.plot(kine_func_pts, w_p, c='c', linestyle='--', label=r'Function $\pm$ 1$\sigma$')
    # plt.plot(kine_func_pts, w_m, c='c', linestyle='--')
    plt.ylabel('W (km/s)'); plt.xlabel('Distance (kpc)')
    plt.legend()
    plt.ylim(-110,110)
    plt.xlim(0,25)
    
    plt.tight_layout()
    plt.savefig('validation_figures/kinematics_sl'+str(sl)+'_pop'+str(pop)+'_ds'+str(ds)+'.pdf')

# %%
plot_kinematics_distr(0,6,ds=2)
# Out:
# /var/folders/_z/fn__fgrs2wqgsmbvw8bvrr0r0000gn/T/ipykernel_27965/3132407858.py:42: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
