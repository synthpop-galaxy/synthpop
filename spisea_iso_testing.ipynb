# %%
from spisea import synthetic, evolution
from spisea import atmospheres, reddening
import numpy as np
import pandas as pd
# Out:
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /Users/mhuston/NotBacked/spisea_data/cdbs/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))

# %%
import pdb

# %%
# Define isochrone input parameters
logAge = np.log10(5*10**6.) # Age in log(years)
dist = 4000 # distance in parsec
AKs = 0.0 # extinction in Ks-band mags
metallicity = 0 # Metallicity in [M/H]
evo_model = evolution.MISTv1()
atm_func = atmospheres.get_merged_atmosphere
red_law = reddening.RedLawHosek18b()

# %%
# Specify filters for synthetic photometry. Here we
# use  the HST WFC3-IR F127M, F139M, and F153M filters
filt_list = ['wfc3,ir,f127m', 'wfc3,ir,f139m',
'wfc3,ir,f153m', 'wfc3,uvis2,f814w', '2mass,H']

# Specify the directory we want the output isochrone
# table saved in
iso_dir = '/Users/mhuston/Documents/synthpop/synthpop/data/isochrones/spisea/'

# Make IsochronePhot object
my_iso = synthetic.Isochrone(logAge, AKs, dist,
                          metallicity=0,
                          evo_model=evo_model,
                          atm_func=atm_func,
                          red_law=red_law)
                          #filters=filt_list,
                          #iso_dir=iso_dir, recomp=True)
# Out:
# Changing to logg=4.00 for T= 31490 logg=3.99
# Changing to logg=4.00 for T= 31687 logg=3.98
# Changing to logg=4.00 for T= 31875 logg=3.97
# Changing to logg=4.00 for T= 32138 logg=3.96
# Changing to logg=4.00 for T= 32375 logg=3.94
# Changing to logg=4.00 for T= 32571 logg=3.93
# Changing to logg=4.00 for T= 32752 logg=3.91
# Changing to logg=4.00 for T= 32915 logg=3.90
# Changing to logg=4.00 for T= 33091 logg=3.88
# Changing to logg=4.00 for T= 33258 logg=3.86
# Changing to logg=4.00 for T= 33403 logg=3.84
# Changing to logg=4.00 for T= 33524 logg=3.82
# Changing to logg=4.00 for T= 33562 logg=3.81
# Changing to logg=4.00 for T= 33597 logg=3.81
# Changing to logg=4.00 for T= 33627 logg=3.80
# Changing to logg=4.00 for T= 33654 logg=3.79
# Changing to logg=4.00 for T= 33676 logg=3.78
# Changing to logg=4.00 for T= 33690 logg=3.77
# Changing to logg=4.00 for T= 33683 logg=3.75
# Changing to logg=4.00 for T= 33642 logg=3.72
# Changing to logg=4.00 for T= 33576 logg=3.70
# Changing to logg=4.00 for T= 33508 logg=3.68
# Changing to logg=4.00 for T= 33427 logg=3.67
# Changing to logg=4.00 for T= 33330 logg=3.65
# Changing to logg=4.00 for T= 33218 logg=3.63
# Changing to logg=4.00 for T= 33105 logg=3.61
# Changing to logg=4.00 for T= 32986 logg=3.60
# Changing to logg=4.00 for T= 32863 logg=3.58
# Changing to logg=4.00 for T= 32732 logg=3.57
# Changing to logg=4.00 for T= 32596 logg=3.55
# Changing to logg=4.00 for T= 32460 logg=3.54
# Changing to logg=4.00 for T= 32301 logg=3.52
# Changing to logg=4.00 for T= 32069 logg=3.50
# Changing to logg=4.00 for T= 31830 logg=3.48
# Changing to logg=4.00 for T= 31584 logg=3.46
# Changing to logg=4.00 for T= 31331 logg=3.44
# Changing to logg=4.00 for T= 31072 logg=3.41
# Changing to logg=3.50 for T= 30797 logg=3.39
# Changing to logg=3.50 for T= 30353 logg=3.35
# Changing to logg=3.50 for T= 29909 logg=3.31
# Changing to logg=3.50 for T= 29462 logg=3.27
# Changing to logg=3.50 for T= 29103 logg=3.24
# Changing to logg=3.50 for T= 28843 logg=3.21
# Changing to logg=3.50 for T= 28582 logg=3.19
# Changing to logg=3.50 for T= 28322 logg=3.17
# Changing to logg=3.50 for T= 28061 logg=3.15
# Changing to logg=3.50 for T= 27801 logg=3.13
# Changing to logg=3.50 for T= 27542 logg=3.11
# Changing to logg=3.50 for T= 27283 logg=3.09
# Changing to logg=3.50 for T= 27028 logg=3.06
# Changing to logg=3.50 for T= 26776 logg=3.04
# Changing to logg=3.50 for T= 26530 logg=3.02
# Changing to logg=3.50 for T= 26304 logg=3.00
# Changing to logg=3.50 for T= 26182 logg=2.98
# Changing to logg=3.50 for T= 26226 logg=2.98
# Changing to logg=3.50 for T= 26411 logg=2.99
# Changing to logg=3.50 for T= 26636 logg=3.00
# Changing to logg=3.50 for T= 26871 logg=3.01
# Changing to logg=3.50 for T= 27110 logg=3.03
# Changing to logg=3.50 for T= 27350 logg=3.04
# Changing to logg=3.50 for T= 27588 logg=3.05
# Changing to logg=3.50 for T= 27823 logg=3.07
# Changing to logg=3.50 for T= 28053 logg=3.08
# Changing to logg=3.50 for T= 28278 logg=3.09
# Changing to logg=3.50 for T= 28499 logg=3.10
# Changing to logg=3.50 for T= 28715 logg=3.11
# Changing to logg=3.50 for T= 28930 logg=3.12
# Changing to logg=3.50 for T= 29140 logg=3.13
# Changing to logg=3.50 for T= 29350 logg=3.14
# Changing to logg=3.50 for T= 29555 logg=3.15
# Changing to logg=3.50 for T= 29759 logg=3.16
# Changing to logg=3.50 for T= 29951 logg=3.17
# Changing to logg=3.50 for T= 30115 logg=3.18
# Changing to logg=3.50 for T= 30204 logg=3.19
# Changing to logg=3.50 for T= 30141 logg=3.18
# Changing to logg=3.50 for T= 29947 logg=3.17
# Changing to logg=3.50 for T= 29682 logg=3.16
# Changing to logg=3.50 for T= 29399 logg=3.15
# Changing to logg=3.50 for T= 29110 logg=3.13
# Changing to logg=3.50 for T= 28819 logg=3.11
# Changing to logg=3.50 for T= 28530 logg=3.10
# Changing to logg=3.50 for T= 28239 logg=3.08
# Changing to logg=3.50 for T= 27948 logg=3.06
# Changing to logg=3.50 for T= 27666 logg=3.04
# Changing to logg=3.50 for T= 27385 logg=3.02
# Changing to logg=3.50 for T= 27106 logg=3.00
# Changing to logg=3.50 for T= 26831 logg=2.98
# Changing to logg=3.50 for T= 26560 logg=2.96
# Changing to logg=3.50 for T= 26291 logg=2.94
# Changing to logg=3.50 for T= 26026 logg=2.92
# Changing to logg=3.00 for T= 25762 logg=2.90
# Changing to logg=3.00 for T= 25501 logg=2.88
# Changing to logg=3.00 for T= 25243 logg=2.86
# Changing to logg=3.00 for T= 24986 logg=2.84
# Changing to logg=3.00 for T= 24733 logg=2.82
# Changing to logg=3.00 for T= 24482 logg=2.80
# Changing to logg=3.00 for T= 24229 logg=2.78
# Changing to logg=3.00 for T= 23980 logg=2.77
# Changing to logg=3.00 for T= 23734 logg=2.75
# Changing to logg=3.00 for T= 23491 logg=2.73
# Changing to logg=3.00 for T= 23250 logg=2.71
# Changing to logg=3.00 for T= 23011 logg=2.69
# Changing to logg=3.00 for T= 22775 logg=2.67
# Changing to logg=3.00 for T= 22542 logg=2.65
# Changing to logg=3.00 for T= 22311 logg=2.63
# Changing to logg=3.00 for T= 22082 logg=2.61
# Changing to logg=3.00 for T= 21856 logg=2.59
# Changing to logg=3.00 for T= 21632 logg=2.57
# Changing to logg=3.00 for T= 21412 logg=2.55
# Changing to logg=3.00 for T= 21196 logg=2.53
# Changing to logg=3.00 for T= 20985 logg=2.52
# Changing to logg=3.00 for T= 20777 logg=2.50
# Changing to logg=3.00 for T= 20569 logg=2.48
# Changing to logg=3.00 for T= 20413 logg=2.47
# Changing to logg=3.00 for T= 20258 logg=2.46
# Changing to logg=3.00 for T= 20103 logg=2.44
# Changing to logg=3.00 for T= 19948 logg=2.43
# Changing to logg=3.00 for T= 19794 logg=2.42
# Changing to logg=3.00 for T= 19642 logg=2.40
# Changing to logg=3.00 for T= 19490 logg=2.39
# Changing to logg=3.00 for T= 19339 logg=2.38
# Changing to logg=3.00 for T= 19189 logg=2.36
# Changing to logg=3.00 for T= 19040 logg=2.35
# Changing to logg=2.50 for T= 18892 logg=2.34
# Changing to logg=2.50 for T= 18745 logg=2.32
# Changing to logg=2.50 for T= 18599 logg=2.31
# Changing to logg=2.50 for T= 18455 logg=2.29
# Changing to logg=2.50 for T= 18311 logg=2.28
# Changing to logg=2.50 for T= 18168 logg=2.27
# Changing to logg=2.50 for T= 18027 logg=2.25
# Changing to logg=2.50 for T= 17886 logg=2.24
# Changing to logg=2.50 for T= 17747 logg=2.23
# Changing to logg=2.50 for T= 17608 logg=2.21
# Changing to logg=2.50 for T= 17471 logg=2.20
# Changing to logg=2.50 for T= 17335 logg=2.19
# Changing to logg=2.50 for T= 17199 logg=2.17
# Changing to logg=2.50 for T= 17065 logg=2.16
# Changing to logg=2.50 for T= 16931 logg=2.14
# Changing to logg=2.50 for T= 16799 logg=2.13
# Changing to logg=2.50 for T= 16668 logg=2.12
# Changing to logg=2.50 for T= 16537 logg=2.10
# Changing to logg=2.50 for T= 16408 logg=2.09
# Changing to logg=2.50 for T= 16280 logg=2.08
# Changing to logg=2.50 for T= 16152 logg=2.06
# Changing to logg=2.50 for T= 16026 logg=2.05
# Changing to logg=2.50 for T= 15900 logg=2.03
# Changing to logg=2.50 for T= 15776 logg=2.02
# Changing to logg=2.50 for T= 15652 logg=2.01
# Changing to logg=2.50 for T= 15530 logg=1.99
# Changing to logg=2.50 for T= 15408 logg=1.98
# Changing to logg=2.50 for T= 15287 logg=1.96
# Changing to logg=2.50 for T= 15168 logg=1.95
# Changing to logg=2.50 for T= 15049 logg=1.94
# Changing to logg=2.50 for T= 14931 logg=1.92
# Changing to logg=2.50 for T= 14814 logg=1.91
# Changing to logg=2.50 for T= 14698 logg=1.90
# Changing to logg=2.50 for T= 14582 logg=1.88
# Changing to logg=2.50 for T= 14468 logg=1.87
# Changing to logg=2.50 for T= 14354 logg=1.85
# Changing to logg=2.50 for T= 14242 logg=1.84
# Changing to logg=2.50 for T= 14130 logg=1.83
# Changing to logg=2.50 for T= 14019 logg=1.81
# Changing to logg=2.50 for T= 13909 logg=1.80
# Changing to logg=2.50 for T= 13800 logg=1.79
# Changing to logg=2.50 for T= 13691 logg=1.77
# Changing to logg=2.50 for T= 13584 logg=1.76
# Changing to logg=2.50 for T= 13477 logg=1.74
# Changing to logg=2.50 for T= 13371 logg=1.73
# Changing to logg=2.50 for T= 13266 logg=1.72
# Changing to logg=2.50 for T= 13162 logg=1.70
# Changing to logg=2.50 for T= 13058 logg=1.69
# Changing to logg=2.50 for T= 12955 logg=1.67
# Changing to logg=2.50 for T= 12854 logg=1.66
# Changing to logg=2.50 for T= 12753 logg=1.65
# Changing to logg=2.50 for T= 12652 logg=1.63
# Changing to logg=2.50 for T= 12553 logg=1.62
# Changing to logg=2.50 for T= 12454 logg=1.61
# Changing to logg=2.50 for T= 12356 logg=1.59
# Changing to logg=2.50 for T= 12259 logg=1.58
# Changing to logg=2.50 for T= 12162 logg=1.56
# Changing to logg=2.50 for T= 12067 logg=1.55
# Changing to logg=2.50 for T= 11972 logg=1.54
# Changing to logg=2.50 for T= 11878 logg=1.52
# Changing to logg=2.50 for T= 11784 logg=1.51
# Changing to logg=2.00 for T= 11691 logg=1.49
# Changing to logg=2.00 for T= 11600 logg=1.48
# Changing to logg=2.00 for T= 11508 logg=1.47
# Changing to logg=2.00 for T= 11418 logg=1.45
# Changing to logg=2.00 for T= 11328 logg=1.44
# Changing to logg=2.00 for T= 11239 logg=1.43
# Changing to logg=2.00 for T= 11150 logg=1.41
# Changing to logg=2.00 for T= 11063 logg=1.40
# Changing to logg=2.00 for T= 10976 logg=1.38
# Changing to logg=2.00 for T= 10889 logg=1.37
# Changing to logg=2.00 for T= 10803 logg=1.36
# Changing to logg=2.00 for T= 10718 logg=1.34
# Changing to logg=2.00 for T= 10634 logg=1.33
# Changing to logg=2.00 for T= 10550 logg=1.31
# Changing to logg=2.00 for T= 10467 logg=1.30
# Changing to logg=2.00 for T= 10385 logg=1.29
# Changing to logg=2.00 for T= 10303 logg=1.27
# Changing to logg=2.00 for T= 10222 logg=1.26
# Changing to logg=2.00 for T= 10142 logg=1.24
# Changing to logg=2.00 for T= 10062 logg=1.23
# Changing to logg=2.00 for T=  9983 logg=1.22
# Changing to logg=2.00 for T=  9904 logg=1.20
# Changing to logg=2.00 for T=  9826 logg=1.19
# Changing to logg=2.00 for T=  9749 logg=1.17
# Changing to logg=2.00 for T=  9672 logg=1.16
# Changing to logg=2.00 for T=  9596 logg=1.15
# Changing to logg=2.00 for T=  9520 logg=1.13
# Changing to logg=2.00 for T=  9445 logg=1.12
# Changing to logg=2.00 for T=  9371 logg=1.10
# Changing to logg=2.00 for T=  9297 logg=1.09
# Changing to logg=2.00 for T=  9224 logg=1.08
# Changing to logg=2.00 for T=  9151 logg=1.06
# Changing to logg=2.00 for T=  9079 logg=1.05
# Changing to logg=2.00 for T=  9008 logg=1.04
# Changing to logg=1.50 for T=  8937 logg=1.02
# Changing to logg=1.50 for T=  8866 logg=1.01
# Changing to logg=1.50 for T=  8797 logg=0.99
# Changing to logg=1.50 for T=  8727 logg=0.98
# Changing to logg=1.50 for T=  8659 logg=0.97
# Changing to logg=1.50 for T=  8590 logg=0.95
# Changing to logg=1.50 for T=  8523 logg=0.94
# Changing to logg=1.50 for T=  8456 logg=0.92
# Changing to logg=1.50 for T=  8389 logg=0.91
# Changing to logg=1.50 for T=  8323 logg=0.90
# Changing to logg=1.50 for T=  8257 logg=0.88
# Changing to logg=1.00 for T=  8192 logg=0.87
# Changing to logg=1.00 for T=  8128 logg=0.85
# Changing to logg=1.00 for T=  8064 logg=0.84
# Changing to logg=1.00 for T=  8000 logg=0.83
# Changing to logg=1.00 for T=  7937 logg=0.81
# Changing to logg=1.00 for T=  7874 logg=0.80
# Changing to logg=1.00 for T=  7812 logg=0.78
# Changing to logg=1.00 for T=  7751 logg=0.77
# Changing to logg=1.00 for T=  7689 logg=0.76
# Changing to logg=1.00 for T=  7629 logg=0.74
# Changing to logg=1.00 for T=  7568 logg=0.73
# Changing to logg=1.00 for T=  7509 logg=0.71
# Changing to logg=0.50 for T=  6666 logg=0.50
# Changing to logg=0.50 for T=  6613 logg=0.49
# Changing to logg=0.50 for T=  6561 logg=0.47
# Changing to logg=0.50 for T=  6509 logg=0.46
# Changing to logg=0.50 for T=  6457 logg=0.44
# Changing to logg=0.50 for T=  6406 logg=0.43
# Changing to logg=0.50 for T=  6355 logg=0.41
# Changing to logg=0.50 for T=  6307 logg=0.39
# Changing to logg=0.50 for T=  6257 logg=0.38
# Changing to logg=0.50 for T=  6231 logg=0.37
# Changing to logg=0.50 for T=  6206 logg=0.36
# Changing to logg=0.50 for T=  6181 logg=0.36
# Changing to logg=0.50 for T=  6156 logg=0.35
# Changing to logg=0.50 for T=  6131 logg=0.34
# Changing to logg=0.50 for T=  6107 logg=0.33
# Changing to logg=0.50 for T=  6082 logg=0.33
# Changing to logg=0.50 for T=  6057 logg=0.32
# Changing to logg=0.50 for T=  6033 logg=0.31
# Changing to logg=0.50 for T=  6009 logg=0.31
# Changing to logg=1.00 for T=  7532 logg=0.60
# Changing to logg=1.00 for T=  7575 logg=0.61
# Changing to logg=1.00 for T=  7658 logg=0.63
# Changing to logg=1.00 for T=  7753 logg=0.65
# Changing to logg=1.00 for T=  7814 logg=0.66
# Changing to logg=1.00 for T=  7899 logg=0.68
# Changing to logg=1.00 for T=  7983 logg=0.70
# Changing to logg=1.00 for T=  8067 logg=0.71
# Changing to logg=1.00 for T=  8159 logg=0.73
# Changing to logg=1.50 for T=  8262 logg=0.75
# Changing to logg=1.50 for T=  8321 logg=0.76
# Changing to logg=1.50 for T=  8400 logg=0.78
# Changing to logg=1.50 for T=  8499 logg=0.80
# Changing to logg=1.50 for T=  8593 logg=0.81
# Changing to logg=1.50 for T=  8689 logg=0.83
# Changing to logg=1.50 for T=  8772 logg=0.85
# Changing to logg=1.50 for T=  8913 logg=0.87
# Changing to logg=1.50 for T=  8969 logg=0.88
# Changing to logg=2.00 for T=  9058 logg=0.90
# Changing to logg=2.00 for T=  9190 logg=0.92
# Changing to logg=2.00 for T=  9265 logg=0.93
# Changing to logg=2.00 for T=  9398 logg=0.96
# Changing to logg=2.00 for T=  9500 logg=0.97
# Changing to logg=2.00 for T=  9626 logg=1.00
# Changing to logg=2.00 for T=  9764 logg=1.02
# Changing to logg=2.00 for T=  9876 logg=1.04
# Changing to logg=2.00 for T=  9980 logg=1.06
# Changing to logg=2.00 for T= 10096 logg=1.08
# Changing to logg=2.00 for T= 10242 logg=1.10
# Changing to logg=2.00 for T= 10368 logg=1.12
# Changing to logg=2.00 for T= 10495 logg=1.14
# Changing to logg=2.00 for T= 10626 logg=1.16
# Changing to logg=2.00 for T= 10771 logg=1.19
# Changing to logg=2.00 for T= 10898 logg=1.21
# Changing to logg=2.00 for T= 11024 logg=1.23
# Changing to logg=2.00 for T= 10997 logg=1.22
# Changing to logg=2.00 for T= 11089 logg=1.24
# Changing to logg=2.00 for T= 11189 logg=1.25
# Changing to logg=2.00 for T= 11376 logg=1.28
# Changing to logg=2.00 for T= 11480 logg=1.29
# Changing to logg=2.00 for T= 11641 logg=1.31
# Changing to logg=2.00 for T= 11697 logg=1.32
# Changing to logg=2.50 for T= 11855 logg=1.34
# Changing to logg=2.50 for T= 12035 logg=1.37
# Changing to logg=2.50 for T= 12212 logg=1.39
# Changing to logg=2.50 for T= 12366 logg=1.41
# Changing to logg=2.50 for T= 12553 logg=1.43
# Changing to logg=2.50 for T= 12767 logg=1.46
# Changing to logg=2.50 for T= 12988 logg=1.49
# Changing to logg=2.50 for T= 13198 logg=1.51
# Changing to logg=2.50 for T= 13425 logg=1.54
# Changing to logg=2.50 for T= 13659 logg=1.56
# Changing to logg=2.50 for T= 13896 logg=1.59
# Changing to logg=2.50 for T= 14133 logg=1.62
# Changing to logg=2.50 for T= 14378 logg=1.64
# Changing to logg=2.50 for T= 14642 logg=1.67
# Changing to logg=2.50 for T= 14925 logg=1.70
# Changing to logg=2.50 for T= 15110 logg=1.71
# Changing to logg=2.50 for T= 14985 logg=1.69
# Changing to logg=2.50 for T= 14862 logg=1.67
# Changing to logg=2.50 for T= 14741 logg=1.64
# Changing to logg=2.50 for T= 14645 logg=1.62
# Changing to logg=2.50 for T= 14527 logg=1.60
# Changing to logg=2.50 for T= 14821 logg=1.63
# Changing to logg=2.50 for T= 15356 logg=1.68
# Changing to logg=2.50 for T= 15587 logg=1.70
# Changing to logg=2.50 for T= 15629 logg=1.70
# Changing to logg=2.50 for T= 15623 logg=1.70
# Changing to logg=2.50 for T= 15620 logg=1.70
# Changing to logg=2.50 for T= 15616 logg=1.70
# Changing to logg=2.50 for T= 15612 logg=1.70
# Changing to logg=2.50 for T= 15607 logg=1.70
# Changing to logg=2.50 for T= 15601 logg=1.70
# Changing to logg=2.50 for T= 15594 logg=1.70
# Changing to logg=2.50 for T= 15566 logg=1.69
# Changing to logg=2.50 for T= 15527 logg=1.69
# Changing to logg=2.50 for T= 15489 logg=1.68
# Changing to logg=2.50 for T= 15464 logg=1.68
# Changing to logg=2.50 for T= 15447 logg=1.68
# Changing to logg=2.50 for T= 15439 logg=1.68
# Changing to logg=2.50 for T= 15430 logg=1.68
# Changing to logg=2.50 for T= 15420 logg=1.68
# Changing to logg=2.50 for T= 15407 logg=1.67
# Changing to logg=2.50 for T= 15393 logg=1.67
# Changing to logg=2.50 for T= 15379 logg=1.67
# Changing to logg=2.50 for T= 15364 logg=1.67
# Changing to logg=2.50 for T= 15349 logg=1.66
# Changing to logg=2.50 for T= 15334 logg=1.66
# Changing to logg=2.50 for T= 15320 logg=1.66
# Changing to logg=2.50 for T= 15307 logg=1.65
# Changing to logg=2.50 for T= 15295 logg=1.65
# Changing to logg=2.50 for T= 15287 logg=1.65
# Changing to logg=2.50 for T= 15282 logg=1.64
# Changing to logg=2.50 for T= 15279 logg=1.64
# Changing to logg=2.50 for T= 15277 logg=1.64
# Changing to logg=2.50 for T= 15311 logg=1.64
# Changing to logg=2.50 for T= 15333 logg=1.64
# Changing to logg=2.50 for T= 15320 logg=1.63
# Changing to logg=2.50 for T= 15307 logg=1.62
# Changing to logg=2.50 for T= 15303 logg=1.62
# Changing to logg=2.50 for T= 15307 logg=1.62
# Changing to logg=2.50 for T= 15317 logg=1.61
# Changing to logg=2.50 for T= 15333 logg=1.61
# Changing to logg=2.50 for T= 15349 logg=1.62
# Changing to logg=2.50 for T= 15366 logg=1.62
# Changing to logg=2.50 for T= 15385 logg=1.62
# Changing to logg=2.50 for T= 15401 logg=1.62
# Changing to logg=2.50 for T= 15404 logg=1.62
# Changing to logg=2.50 for T= 15416 logg=1.62
# Changing to logg=2.50 for T= 15429 logg=1.62
# Changing to logg=2.50 for T= 15446 logg=1.62
# Changing to logg=2.50 for T= 15458 logg=1.62
# Changing to logg=2.50 for T= 15464 logg=1.62
# Changing to logg=2.50 for T= 15475 logg=1.63
# Changing to logg=2.50 for T= 15482 logg=1.63
# Changing to logg=2.50 for T= 15487 logg=1.63
# Changing to logg=2.50 for T= 15495 logg=1.63
# Changing to logg=2.50 for T= 15509 logg=1.63
# Changing to logg=2.50 for T= 15507 logg=1.63
# Changing to logg=2.50 for T= 15518 logg=1.63
# Changing to logg=2.50 for T= 15520 logg=1.63
# Changing to logg=2.50 for T= 15532 logg=1.63
# Changing to logg=2.50 for T= 15538 logg=1.63
# Changing to logg=2.50 for T= 15541 logg=1.63
# Changing to logg=2.50 for T= 15550 logg=1.63
# Changing to logg=2.50 for T= 15554 logg=1.63
# Changing to logg=2.50 for T= 15544 logg=1.63
# Changing to logg=2.50 for T= 15539 logg=1.63
# Changing to logg=2.50 for T= 15536 logg=1.63
# Changing to logg=2.50 for T= 15531 logg=1.63
# Changing to logg=2.50 for T= 15524 logg=1.63
# Changing to logg=2.50 for T= 15517 logg=1.63
# Changing to logg=2.50 for T= 15512 logg=1.62
# Changing to logg=2.50 for T= 15508 logg=1.62
# Changing to logg=2.50 for T= 15503 logg=1.62
# Changing to logg=2.50 for T= 15498 logg=1.62
# Changing to logg=2.50 for T= 15494 logg=1.62
# Changing to logg=2.50 for T= 15497 logg=1.62
# Changing to logg=2.50 for T= 15503 logg=1.62
# Changing to logg=2.50 for T= 15509 logg=1.63
# Changing to logg=2.50 for T= 15515 logg=1.63
# Changing to logg=2.50 for T= 15521 logg=1.63
# Changing to logg=2.50 for T= 15527 logg=1.63
# Changing to logg=2.50 for T= 15534 logg=1.63
# Changing to logg=2.50 for T= 15541 logg=1.63
# Changing to logg=2.50 for T= 15547 logg=1.63
# Changing to logg=2.50 for T= 15554 logg=1.63
# Changing to logg=2.50 for T= 15561 logg=1.63
# Changing to logg=2.50 for T= 15568 logg=1.63
# Changing to logg=2.50 for T= 15575 logg=1.63
# Changing to logg=2.50 for T= 15582 logg=1.63
# Changing to logg=2.50 for T= 15589 logg=1.64
# Changing to logg=2.50 for T= 15596 logg=1.64
# Changing to logg=2.50 for T= 15603 logg=1.64
# Changing to logg=2.50 for T= 15609 logg=1.64
# Changing to logg=2.50 for T= 15616 logg=1.64
# Changing to logg=2.50 for T= 15622 logg=1.64
# Changing to logg=2.50 for T= 15628 logg=1.64
# Changing to logg=2.50 for T= 15635 logg=1.64
# Changing to logg=2.50 for T= 15641 logg=1.64
# Changing to logg=2.50 for T= 15647 logg=1.64
# Changing to logg=2.50 for T= 15653 logg=1.64
# Changing to logg=2.50 for T= 15658 logg=1.64
# Changing to logg=2.50 for T= 15664 logg=1.64
# Changing to logg=2.50 for T= 15670 logg=1.64
# Changing to logg=2.50 for T= 15675 logg=1.65
# Changing to logg=2.50 for T= 15680 logg=1.65
# Changing to logg=2.50 for T= 15686 logg=1.65
# Changing to logg=2.50 for T= 15691 logg=1.65
# Isochrone generation took 13.031028 s.

# %%
import synthpop as sp
# Out:
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/pydantic/_internal/_config.py:341: UserWarning: Valid config keys have changed in V2:
# * 'keep_untouched' has been renamed to 'ignored_types'
#   warnings.warn(message, UserWarning)

# %%
spmod = sp.SynthPop(name_for_output='test', default_config='huston2025_defaults.synthpop_conf')
spmod.init_populations()
# Out:
#  74417 - Execution Date: 21-05-2025 12:08:18
#
#
# ################################ Settings #################################
#  74418 - # reading default parameters from
#  74419 - default_config_file =  /Users/mhuston/Documents/synthpop/synthpop/config_files/huston2025_defaults.synthpop_conf
#
#
# # copy the following to a config file to redo this model generation -------
#  74421 - {
#     "l_set": null,
#     "l_set_type": null,
#     "b_set": null,
#     "b_set_type": null,
#     "random_seed": 474492400,
#     "name_for_output": "test",
#     "model_name": "Huston2025",
#     "solid_angle": null,
#     "solid_angle_unit": "deg^2",
#     "sun": {
#         "x": -8.178,
#         "y": 0.0,
#         "z": 0.017,
#         "u": 12.9,
#         "v": 245.6,
#         "w": 7.78,
#         "l_apex_deg": 56.24,
#         "b_apex_deg": 22.54
#     },
#     "lsr": {
#         "u_lsr": 1.8,
#         "v_lsr": 233.4,
#         "w_lsr": 0.53
#     },
#     "warp": {
#         "r_warp": 7.72,
#         "amp_warp": 0.06,
#         "amp_warp_pos": null,
#         "amp_warp_neg": null,
#         "alpha_warp": 1.33,
#         "phi_warp_deg": 17.5
#     },
#     "extinction_map_kwargs": {
#         "name": "Surot",
#         "project_3d": true,
#         "dist_2d": 8.15
#     },
#     "extinction_law_kwargs": [
#         {
#             "name": "SODC",
#             "R_V": 2.5
#         }
#     ],
#     "max_distance": 25,
#     "distance_step_size": 0.1,
#     "window_type": {
#         "window_type": "cone"
#     },
#     "mass_lims": {
#         "min_mass": 0.08,
#         "max_mass": 100
#     },
#     "N_mc_totmass": 10000,
#     "lost_mass_option": 1,
#     "N_av_mass": 50000,
#     "kinematics_at_the_end": false,
#     "scale_factor": 1,
#     "skip_lowmass_stars": false,
#     "chunk_size": 250000,
#     "evolution_class": {
#         "name": "MIST",
#         "interpolator": "CharonInterpolator"
#     },
#     "maglim": [
#         "W146",
#         23.975533,
#         "remove"
#     ],
#     "chosen_bands": [
#         "R062",
#         "Z087",
#         "Y106",
#         "J129",
#         "W146",
#         "H158",
#         "F184",
#         "Bessell_U",
#         "Bessell_B",
#         "Bessell_V",
#         "Bessell_R",
#         "Bessell_I",
#         "VISTA_J",
#         "VISTA_H",
#         "VISTA_Ks"
#     ],
#     "eff_wavelengths": {
#         "R062": 0.615778,
#         "Z087": 0.86339,
#         "Y106": 1.045809,
#         "J129": 1.2747,
#         "W146": 1.30138,
#         "H158": 1.558247,
#         "F184": 1.830067,
#         "Bessell_U": 0.365988,
#         "Bessell_B": 0.438074,
#         "Bessell_V": 0.544543,
#         "Bessell_R": 0.641147,
#         "Bessell_I": 0.798209,
#         "VISTA_J": 1.255579,
#         "VISTA_H": 1.649872,
#         "VISTA_Ks": 2.15779
#     },
#     "obsmag": true,
#     "opt_iso_props": [
#         "log_L",
#         "log_Teff",
#         "log_g",
#         "[Fe/H]",
#         "log_R",
#         "phase"
#     ],
#     "col_names": [
#         "logL",
#         "logTeff",
#         "logg",
#         "Fe/H_evolved",
#         "log_radius",
#         "phase"
#     ],
#     "post_processing_kwargs": [
#         {
#             "name": "ProcessDarkCompactObjects",
#             "remove": false
#         },
#         {
#             "name": "ConvertMistMags",
#             "conversions": {
#                 "AB": [
#                     "R062",
#                     "Z087",
#                     "Y106",
#                     "J129",
#                     "W146",
#                     "H158",
#                     "F184"
#                 ]
#             }
#         }
#     ],
#     "output_location": "outputfiles/default",
#     "output_filename_pattern": "{name_for_output}_l{l_deg:.3f}_b{b_deg:.3f}",
#     "output_file_type": "csv",
#     "overwrite": true
# }
#  74421 - Location or solid_angle_sr are not  defined in the settings! Can not run main() or process_all()
#
#
# ########################## initialize population ##########################
#  74428 - read Population files from Huston2025
#
#
# # Population 0;  bulge ----------------------------------------------------
#  74434 - # Initialize Population 0 (bulge) from
#  74435 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/bulge.popjson'
#
#
# # Population 1;  halo -----------------------------------------------------
#  94320 - # Initialize Population 1 (halo) from
#  94320 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/halo.popjson'
#
#
# # Population 2;  nsd ------------------------------------------------------
#  94969 - # Initialize Population 2 (nsd) from
#  94969 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/nsd.popjson'
#
#
# # Population 3;  thick_disk -----------------------------------------------
#  95956 - # Initialize Population 3 (thick_disk) from
#  95957 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thick_disk.popjson'
#
#
# # Population 4;  thin_disk_1 ----------------------------------------------
#  96592 - # Initialize Population 4 (thin_disk_1) from
#  96592 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thin_disk_1.popjson'
#
#
# # Population 5;  thin_disk_2 ----------------------------------------------
#  97243 - # Initialize Population 5 (thin_disk_2) from
#  97243 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thin_disk_2.popjson'
#
#
# # Population 6;  thin_disk_3 ----------------------------------------------
#  97915 - # Initialize Population 6 (thin_disk_3) from
#  97915 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thin_disk_3.popjson'
#
#
# # Population 7;  thin_disk_4 ----------------------------------------------
#  98576 - # Initialize Population 7 (thin_disk_4) from
#  98576 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thin_disk_4.popjson'
#
#
# # Population 8;  thin_disk_5 ----------------------------------------------
#  99237 - # Initialize Population 8 (thin_disk_5) from
#  99238 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thin_disk_5.popjson'
#
#
# # Population 9;  thin_disk_6 ----------------------------------------------
#  99898 - # Initialize Population 9 (thin_disk_6) from
#  99899 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thin_disk_6.popjson'
#
#
# # Population 10;  thin_disk_7 ---------------------------------------------
#  100562 - # Initialize Population 10 (thin_disk_7) from
#  100563 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/thin_disk_7.popjson'
#  101249 - # all population are initialized

# %%
mist_isos = spmod.populations[0].evolution.isochrones
mist_isos
# Out:
#            log_R       H158  log_Teff  phase       W146       R062       F184  \
# 0       0.043787   3.985190  3.617011   -1.0   4.320230   6.120077   3.810673
# 1       0.050254   3.945770  3.618039   -1.0   4.280550   6.073921   3.771948
# 2       0.059829   3.887368  3.619556   -1.0   4.221797   6.005664   3.714574
# 3       0.069304   3.829506  3.621062   -1.0   4.163620   5.938120   3.657734
# 4       0.078680   3.772214  3.622555   -1.0   4.106044   5.871332   3.601455
# ...          ...        ...       ...    ...        ...        ...        ...
# 108718 -1.806255  10.635622  4.402490    6.0  10.581017  10.033175  10.717831
# 108719 -1.809295  10.697798  4.387132    6.0  10.646828  10.112968  10.779277
# 108720 -1.812237  10.756705  4.371789    6.0  10.709302  10.189516  10.837441
# 108721 -1.815091  10.812930  4.356480    6.0  10.769053  10.263439  10.892908
# 108722 -1.817854  10.866999  4.341226    6.0  10.826623  10.335249  10.946223
#
#         star_mass       Z087  log10_isochrone_age_yr  ...     log_g  \
# 0        0.100000   5.111601                     5.0  ...  3.350571
# 1        0.102885   5.069485                     5.0  ...  3.347798
# 2        0.107147   5.007198                     5.0  ...  3.343658
# 3        0.111379   4.945580                     5.0  ...  3.339612
# 4        0.115581   4.884656                     5.0  ...  3.335660
# ...           ...        ...                     ...  ...       ...
# 108718   0.532726  10.320126                    10.3  ...  7.777159
# 108719   0.532730  10.392982                    10.3  ...  7.783242
# 108720   0.532735  10.462471                    10.3  ...  7.789130
# 108721   0.532741  10.529238                    10.3  ...  7.794844
# 108722   0.532749  10.593838                    10.3  ...  7.800376
#
#              Y106  Bessell_V  Bessell_B  Bessell_I  Bessell_R  Bessell_U  \
# 0        4.760768   6.645812   7.805105   5.284892   5.949971   8.279037
# 1        4.720180   6.596900   7.749505   5.241930   5.904354   8.213431
# 2        4.660136   6.524569   7.667323   5.178397   5.836895   8.116573
# 3        4.600729   6.452992   7.585987   5.115542   5.770147   8.020796
# 4        4.541980   6.382214   7.505559   5.053394   5.704152   7.926188
# ...           ...        ...        ...        ...        ...        ...
# 108718  10.515989   9.953986   9.804964  10.218862  10.075529   8.799999
# 108719  10.584676  10.035246   9.898314  10.293137  10.154106   8.913713
# 108720  10.650011  10.113359   9.988331  10.364065  10.229397   9.024037
# 108721  10.712618  10.188924  10.075726  10.432288  10.302034   9.131856
# 108722  10.773043  10.262406  10.161068  10.498350  10.372540   9.237886
#
#           VISTA_J    VISTA_H   VISTA_Ks
# 0        4.411981   3.908688   3.727125
# 1        4.372238   3.869333   3.689235
# 2        4.313419   3.811020   3.633105
# 3        4.255189   3.753243   3.577507
# 4        4.197572   3.696033   3.522462
# ...           ...        ...        ...
# 108718  10.582170  10.652210  10.754732
# 108719  10.647722  10.713973  10.814684
# 108720  10.709810  10.772529  10.871462
# 108721  10.769149  10.828431  10.925624
# 108722  10.826392  10.882181  10.977690
#
# [1494453 rows x 25 columns]

# %%
mist_isos.keys()
# Out:
# Index(['log_R', 'H158', 'log_Teff', 'phase', 'W146', 'R062', 'F184',
#        'star_mass', 'Z087', 'log10_isochrone_age_yr', '[Fe/H]_init', 'log_L',
#        'J129', '[Fe/H]', 'initial_mass', 'log_g', 'Y106', 'Bessell_V',
#        'Bessell_B', 'Bessell_I', 'Bessell_R', 'Bessell_U', 'VISTA_J',
#        'VISTA_H', 'VISTA_Ks'],
#       dtype='object')

# %%
mist_isos['[Fe/H]_init']
# Out:
# 0        -4.0
# 1        -4.0
# 2        -4.0
# 3        -4.0
# 4        -4.0
#          ...
# 108718    0.5
# 108719    0.5
# 108720    0.5
# 108721    0.5
# 108722    0.5
# Name: [Fe/H]_init, Length: 1494453, dtype: float64

# %%
mp = my_iso.to_pandas()

# %%
mp['hey']=0

# %%
mp
# Out:
#                 L          Teff             R       mass      logg   isWR  \
# 0    8.256006e+24   2985.198018  3.819688e+08   0.100000  3.958886  False
# 1    8.526563e+24   2993.484850  3.860309e+08   0.103064  3.960489  False
# 2    8.891345e+24   3004.293175  3.913707e+08   0.107025  3.962506  False
# 3    9.271538e+24   3015.199385  3.967647e+08   0.110986  3.964567  False
# 4    9.667792e+24   3026.175172  4.022210e+08   0.114948  3.966658  False
# ..            ...           ...           ...        ...       ...    ...
# 717  3.117322e+32  15669.518361  8.518611e+10  45.592367  1.644968   True
# 718  3.116954e+32  15674.955709  8.512198e+10  45.592370  1.645622   True
# 719  3.116585e+32  15680.311462  8.505882e+10  45.592371  1.646267   True
# 720  3.116214e+32  15685.591800  8.499650e+10  45.592373  1.646903   True
# 721  3.115839e+32  15690.801923  8.493495e+10  45.592374  1.647532   True
#
#      mass_current  phase  m_hst_f127m  m_hst_f139m  m_hst_f153m  hey
# 0        0.100000   -1.0    19.785653    19.850611    19.577463    0
# 1        0.103064   -1.0    19.753485    19.815144    19.542276    0
# 2        0.107025   -1.0    19.712841    19.769432    19.496898    0
# 3        0.110986   -1.0    19.673942    19.724227    19.451990    0
# 4        0.114948   -1.0    19.635134    19.679220    19.407285    0
# ..            ...    ...          ...          ...          ...  ...
# 717     24.148543    9.0     4.624312     4.653397     4.655826    0
# 718     24.148540    9.0     4.625490     4.654585     4.657024    0
# 719     24.148537    9.0     4.626652     4.655756     4.658205    0
# 720     24.148534    9.0     4.627801     4.656913     4.659371    0
# 721     24.148532    9.0     4.628936     4.658058     4.660525    0
#
# [722 rows x 12 columns]

# %%
spisea_filts = {
    '2mass':['J','H','Ks'],
    'ctio_osiris':['H','K'],
    'decam':['u','g','r','i','z','Y'],
    'gaia':{'dr2_rev':['G','Gbp','Grp']},
    'hawki':['J','H','Ks'],
    # Add any more hubble??
    'wfc3':{'uvis1':['f200lp', 'f218w', 'f225w', 'f275w', 'f280n', 'f300x',
                     'f336w', 'f343n', 'f350lp', 'f373n', 'f390m', 'f390w',
                     'f395n', 'f410m', 'f438w', 'f467m', 'f469n', 'f475w',
                     'f475x', 'f487n', 'f502n', 'f547m', 'f555w', 'f600lp',
                     'f606w', 'f621m', 'f625w', 'f631n', 'f645n', 'f656n',
                     'f657n', 'f658n', 'f665n', 'f673n', 'f680n', 'f689m',
                     'f763m', 'f775w', 'f814w', 'f845m', 'f850lp', 'f953n',
                     'fq232n', 'fq243n', 'fq378n', 'fq387n', 'fq422m', 'fq436n',
                     'fq437n', 'fq492n', 'fq508n', 'fq575n', 'fq619n', 'fq634n',
                     'fq672n', 'fq674n', 'fq727n', 'fq750n', 'fq889n', 'fq906n', 
                     'fq924n', 'fq937n'],
            'uvis2':['f200lp', 'f218w', 'f225w', 'f275w', 'f280n', 'f300x',
                     'f336w', 'f343n', 'f350lp', 'f373n', 'f390m', 'f390w',
                     'f395n', 'f410m', 'f438w', 'f467m', 'f469n', 'f475w',
                     'f475x', 'f487n', 'f502n', 'f547m', 'f555w', 'f600lp',
                     'f606w', 'f621m', 'f625w', 'f631n', 'f645n', 'f656n',
                     'f657n', 'f658n', 'f665n', 'f673n', 'f680n', 'f689m',
                     'f763m', 'f775w', 'f814w', 'f845m', 'f850lp', 'f953n',
                     'fq232n', 'fq243n', 'fq378n', 'fq387n', 'fq422m', 'fq436n',
                     'fq437n', 'fq492n', 'fq508n', 'fq575n', 'fq619n', 'fq634n',
                     'fq672n', 'fq674n', 'fq727n', 'fq750n', 'fq889n', 'fq906n', 
                     'fq924n', 'fq937n'],
            'ir':['f098m', 'f105w', 'f110w', 'f125w', 'f126n', 'f127m',
                  'f128n', 'f130n', 'f132n', 'f139m', 'f140w', 'f153m',
                  'f160w', 'f164n', 'f167n']},
    'acs':{'hrc':['f220w', 'f250w', 'f330w', 'f344n', 'f435w', 'f475w', 'f502n',
                  'f550m', 'f555w', 'f606w', 'f625w', 'f658n', 'f660n', 'f775w',
                  'f814w', 'f850lp', 'f892n', 'pol_uv', 'pol_v'],
           'sbc':['f115lp', 'f125lp', 'f140lp', 'f150lp', 'f165lp', 'f122m'],
           'wfc1':['f435w', 'f475w', 'f502n', 'f550m', 'f555w', 'f606w', 'f625w', 
                   'f658n', 'f660n', 'f775w', 'f814w', 'f850lp', 'f892n', 
                   'pol_uv', 'pol_v'],
           'wfc2':['f435w', 'f475w', 'f502n', 'f550m', 'f555w', 'f606w', 'f625w', 
                   'f658n', 'f660n', 'f775w', 'f814w', 'f850lp', 'f892n', 
                   'pol_uv', 'pol_v']},
    'ubv':['U','B','V','R','I'],
    'jg': ['J','H','K'],
    'jwst':['F070W', 'F090W', 'F115W', 'F140M', 'F150W', 'F150W2', 'F162M', 
            'F164N', 'F182M', 'F187N', 'F200W', 'F210M', 'F212N', 'F250M', 
            'F277W', 'F300M', 'F322W2', 'F323N', 'F335M', 'F356W', 'F360M', 
            'F405N', 'F410M', 'F430M', 'F444W', 'F460M', 'F466N', 'F470N', 
            'F480M'],
    'nirc1':['H', 'K'],
    'nirc2':['J','H','K','Kp','Ks','Kcont','Lp','Ms','Brgamma','FeII'],
    'naco':['J','H','Ks'],
    'ps1':['g','r','i','z','y'],
    'roman':{'wfi':['F062','F087','F106','F129','F158','W146','F184','F213']},
    'ukirt':['J','H','K'],
    'rubin':['u','g','r','i','z','y'],
    'vista':['Z','Y','J','H','K'],
    'ztf':['g','r','i']
}

# %%
for x in spisea_filts:
    print(x)
# Out:
# 2mass
# ctio_osiris
# decam
# gaia
# hawki
# wfc3
# acs
# ubv
# jg
# jwst
# nirc1
# nirc2
# naco
# ps1
# roman
# ukirt
# rubin
# vista
# ztf

# %%
import synthpop as sp
# Out:
# /Users/mhuston/anaconda3/lib/python3.11/site-packages/pydantic/_internal/_config.py:341: UserWarning: Valid config keys have changed in V2:
# * 'keep_untouched' has been renamed to 'ignored_types'
#   warnings.warn(message, UserWarning)

# %%
simod = sp.SynthPop(name_for_output='spisea_test', default_config='huston2025_defaults.synthpop_conf',
                    evolution_class={"name":"SpiseaIso", "interpolator":"CharonInterpolator"}, extinction_map_kwargs={'map_name':'NoExtinction'},
            opt_iso_props=["log_L", "log_Teff", "log_g", "log_R", "phase"],
            col_names=["logL", "logTeff", "logg" ,"log_radius","phase"],
                   chosen_bands=['2mass-J','2mass-H'], maglim=['2mass-J',99,'keep'],
                   eff_wavelengths={'json_file':'AAA_effective_wavelengths_spisea.json'},
                   post_processing_kwargs=[{"name": "ProcessDarkCompactObjects", "remove": False}])
simod.init_populations()
# Out:
# ################################ Settings #################################
#  109006 - # reading default parameters from
#  109007 - default_config_file =  /Users/mhuston/Documents/synthpop/synthpop/config_files/huston2025_defaults.synthpop_conf
#
#
# # copy the following to a config file to redo this model generation -------
#  109010 - {
#     "l_set": null,
#     "l_set_type": null,
#     "b_set": null,
#     "b_set_type": null,
#     "random_seed": 1402392417,
#     "name_for_output": "spisea_test",
#     "model_name": "Huston2025",
#     "solid_angle": null,
#     "solid_angle_unit": "deg^2",
#     "sun": {
#         "x": -8.178,
#         "y": 0.0,
#         "z": 0.017,
#         "u": 12.9,
#         "v": 245.6,
#         "w": 7.78,
#         "l_apex_deg": 56.24,
#         "b_apex_deg": 22.54
#     },
#     "lsr": {
#         "u_lsr": 1.8,
#         "v_lsr": 233.4,
#         "w_lsr": 0.53
#     },
#     "warp": {
#         "r_warp": 7.72,
#         "amp_warp": 0.06,
#         "amp_warp_pos": null,
#         "amp_warp_neg": null,
#         "alpha_warp": 1.33,
#         "phi_warp_deg": 17.5
#     },
#     "extinction_map_kwargs": {
#         "map_name": "NoExtinction"
#     },
#     "extinction_law_kwargs": [
#         {
#             "name": "SODC",
#             "R_V": 2.5
#         }
#     ],
#     "max_distance": 25,
#     "distance_step_size": 0.1,
#     "window_type": {
#         "window_type": "cone"
#     },
#     "mass_lims": {
#         "min_mass": 0.08,
#         "max_mass": 100
#     },
#     "N_mc_totmass": 10000,
#     "lost_mass_option": 1,
#     "N_av_mass": 50000,
#     "kinematics_at_the_end": false,
#     "scale_factor": 1,
#     "skip_lowmass_stars": false,
#     "chunk_size": 250000,
#     "evolution_class": {
#         "name": "SpiseaIso",
#         "interpolator": "CharonInterpolator"
#     },
#     "maglim": [
#         "2mass-J",
#         99,
#         "keep"
#     ],
#     "chosen_bands": [
#         "2mass-J",
#         "2mass-H"
#     ],
#     "eff_wavelengths": {
#         "json_file": "AAA_effective_wavelengths_spisea.json"
#     },
#     "obsmag": true,
#     "opt_iso_props": [
#         "log_L",
#         "log_Teff",
#         "log_g",
#         "log_R",
#         "phase"
#     ],
#     "col_names": [
#         "logL",
#         "logTeff",
#         "logg",
#         "log_radius",
#         "phase"
#     ],
#     "post_processing_kwargs": [
#         {
#             "name": "ProcessDarkCompactObjects",
#             "remove": false
#         }
#     ],
#     "output_location": "outputfiles/default",
#     "output_filename_pattern": "{name_for_output}_l{l_deg:.3f}_b{b_deg:.3f}",
#     "output_file_type": "csv",
#     "overwrite": true
# }
#  109011 - Location or solid_angle_sr are not  defined in the settings! Can not run main() or process_all()
#
#
# ########################## initialize population ##########################
#  109013 - read Population files from Huston2025
#
#
# # Population 0;  bulge ----------------------------------------------------
#  109017 - # Initialize Population 0 (bulge) from
#  109017 - pop_file = '/Users/mhuston/Documents/synthpop/synthpop/models/Huston2025/bulge.popjson'
# Requested metallicity 1.3999999999999997e-06 is out of bounds.
# [-4.00616031 -3.49907583 -3.00616031 -2.49907583 -2.00616031 -1.75434834
#  -1.49907583 -1.24919836 -1.00616031 -0.75434834 -0.49907583 -0.24919836
#  -0.00616031  0.24565166  0.50092417]
# -4.0061603087048185
# Changing to met=-4.00 for met=-4.01 T=  4159 logg=3.35
# Changing to met=-4.00 for met=-4.01 T=  4173 logg=3.35
# Changing to met=-4.00 for met=-4.01 T=  4187 logg=3.34
# Changing to met=-4.00 for met=-4.01 T=  4201 logg=3.34
# Changing to met=-4.00 for met=-4.01 T=  4216 logg=3.33
# Changing to met=-4.00 for met=-4.01 T=  4230 logg=3.33
# Changing to met=-4.00 for met=-4.01 T=  4244 logg=3.33
# Changing to met=-4.00 for met=-4.01 T=  4258 logg=3.32
# Changing to met=-4.00 for met=-4.01 T=  4272 logg=3.32
# Changing to met=-4.00 for met=-4.01 T=  4286 logg=3.32
# Changing to met=-4.00 for met=-4.01 T=  4299 logg=3.32
# Changing to met=-4.00 for met=-4.01 T=  4316 logg=3.31
# Changing to met=-4.00 for met=-4.01 T=  4335 logg=3.31
# Changing to met=-4.00 for met=-4.01 T=  4354 logg=3.31
# Changing to met=-4.00 for met=-4.01 T=  4375 logg=3.30
# Changing to met=-4.00 for met=-4.01 T=  4396 logg=3.30
# Changing to met=-4.00 for met=-4.01 T=  4416 logg=3.29
# Changing to met=-4.00 for met=-4.01 T=  4437 logg=3.29
# Changing to met=-4.00 for met=-4.01 T=  4460 logg=3.29
# Changing to met=-4.00 for met=-4.01 T=  4485 logg=3.28
# Changing to met=-4.00 for met=-4.01 T=  4512 logg=3.28
# Changing to met=-4.00 for met=-4.01 T=  4539 logg=3.27
# Changing to met=-4.00 for met=-4.01 T=  4566 logg=3.27
# Changing to met=-4.00 for met=-4.01 T=  4590 logg=3.26
# Changing to met=-4.00 for met=-4.01 T=  4614 logg=3.25
# Changing to met=-4.00 for met=-4.01 T=  4637 logg=3.25
# Changing to met=-4.00 for met=-4.01 T=  4660 logg=3.24
# Changing to met=-4.00 for met=-4.01 T=  4706 logg=3.23
# Changing to met=-4.00 for met=-4.01 T=  4736 logg=3.23
# Changing to met=-4.00 for met=-4.01 T=  4792 logg=3.22
# Changing to met=-4.00 for met=-4.01 T=  4830 logg=3.22
# Changing to met=-4.00 for met=-4.01 T=  4854 logg=3.21
# Changing to met=-4.00 for met=-4.01 T=  4879 logg=3.21
# Changing to met=-4.00 for met=-4.01 T=  4899 logg=3.21
# Changing to met=-4.00 for met=-4.01 T=  4944 logg=3.20
# Changing to met=-4.00 for met=-4.01 T=  4994 logg=3.20
# ---------------------------------------------------------------------------
# ParameterOutOfBounds                      Traceback (most recent call last)
# File ~/Documents/spisea/spisea/atmospheres.py:687, in get_atlas_phoenix_atmosphere(metallicity, temperature, gravity)
#     686 try:
# --> 687     sp = pysynphot.Icat('merged_atlas_phoenix', temperature, metallicity, gravity)
#     688 except:
#     689     # Check atmosphere catalog bounds
#
# File ~/anaconda3/lib/python3.11/site-packages/pysynphot/catalog.py:117, in Icat.__init__(self, catdir, Teff, metallicity, log_g)
#     115 list0,list1 = self._breakList(indices, 0, Teff)
# --> 117 list2,list3 = self._breakList(list0, 1, metallicity)
#     118 list4,list5 = self._breakList(list1, 1, metallicity)
#
# File ~/anaconda3/lib/python3.11/site-packages/pysynphot/catalog.py:181, in Icat._breakList(self, inList, index, parameter)
#     180     s = s % (self.parameter_names[index], minAllowed, parameter)
# --> 181     raise exceptions.ParameterOutOfBounds(s)
#     183 upper = upperArray.min()
#
# ParameterOutOfBounds: Parameter 'metallicity' exceeds data. Min allowed=-2.500000, entered=-4.006160.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 8
#       1 simod = sp.SynthPop(name_for_output='spisea_test', default_config='huston2025_defaults.synthpop_conf',
#       2                     evolution_class={"name":"SpiseaIso", "interpolator":"CharonInterpolator"}, extinction_map_kwargs={'map_name':'NoExtinction'},
#       3             opt_iso_props=["log_L", "log_Teff", "log_g", "log_R", "phase"],
#    (...)
#       6                    eff_wavelengths={'json_file':'AAA_effective_wavelengths_spisea.json'},
#       7                    post_processing_kwargs=[{"name": "ProcessDarkCompactObjects", "remove": False}])
# ----> 8 simod.init_populations()
#
# File ~/Documents/synthpop/synthpop/synthpop_main.py:217, in SynthPop.init_populations(self, forced)
#     212 # initialize the populations
#     213 self.population_params = {pop_id: sp_utils.PopParams.parse_jsonfile(population_file)
#     214     for pop_id, population_file in enumerate(self.population_files)
#     215     }
# --> 217 self.populations = [
#     218     Population(pop_params, pop_id, self.parms)
#     219     for pop_id, pop_params in self.population_params.items()
#     220     ]
#     221 logger.info("# all population are initialized")
#     222 self.populations_are_initialized = True
#
# File ~/Documents/synthpop/synthpop/synthpop_main.py:218, in <listcomp>(.0)
#     212 # initialize the populations
#     213 self.population_params = {pop_id: sp_utils.PopParams.parse_jsonfile(population_file)
#     214     for pop_id, population_file in enumerate(self.population_files)
#     215     }
#     217 self.populations = [
# --> 218     Population(pop_params, pop_id, self.parms)
#     219     for pop_id, pop_params in self.population_params.items()
#     220     ]
#     221 logger.info("# all population are initialized")
#     222 self.populations_are_initialized = True
#
# File ~/Documents/synthpop/synthpop/population.py:182, in Population.__init__(self, pop_params, population_index, glbl_params, **positional_kwargs)
#     176 self.pop_params.metallicity_func_kwargs.sun = self.sun
#     178 # placeholder for profiles etc. initialized via the assign_subclasses
#     179 (
#     180     self.population_density, self.imf, self.age, self.metallicity,
#     181     self.kinematics, self.evolution, self.extinction
# --> 182     ) = self.assign_subclasses()
#     184 # get magnitudes from evolution class
#     185 if isinstance(self.evolution, list):
#
# File ~/Documents/synthpop/synthpop/population.py:223, in Population.assign_subclasses(self)
#     210 def assign_subclasses(self):
#     211     """initialization of all the subclass
#     212     Returns
#     213     -------
#    (...)
#     220     extinction
#     221     """
# --> 223     evolution = self.get_evolution_class()
#     224     extinction = self.get_extinction_class()
#     225     population_density = self.get_population_density_class()
#
# File ~/Documents/synthpop/synthpop/population.py:270, in Population.get_evolution_class(self)
#     267 ev_kwargs.columns = columns
#     269 ev_init.append(ev_kwargs)
# --> 270 evolution_i = Evo(
#     271     iso_kwargs=ev_kwargs.init_kwargs,
#     272     int_kwargs=ev_kwargs.init_kwargs,
#     273     logger=logger)
#     275 val = getattr(ev_kwargs, "min_mass", evolution_i.min_mass)
#     276 if val < evolution_i.min_mass:
#
# File ~/Documents/synthpop/synthpop/modules/evolution/_evolution.py:275, in CombineEvolution.<locals>.Evolution.__init__(self, int_kwargs, iso_kwargs, logger)
#     273 if iso_kwargs is None:
#     274     iso_kwargs = {}
# --> 275 Isochrones.__init__(self, **iso_kwargs)
#     277 # initialize Interpolator
#     278 if int_kwargs is None:
#
# File ~/Documents/synthpop/synthpop/modules/evolution/spisea_iso.py:90, in SpiseaIso.__init__(self, columns, use_global, evolution_model_name, **kwargs)
#      88         self.isochrones = spisea_isochrones
#      89     else:
# ---> 90         self.isochrones = self.load_isochrones()
#      91 else:
#      92     self.isochrones = self.load_isochrones()
#
# File ~/Documents/synthpop/synthpop/modules/evolution/spisea_iso.py:229, in SpiseaIso.load_isochrones(self)
#     217 for i,feh in enumerate(self.feh_grid):
#     218     #feh_str = ('m' if nn<0.0 else 'p') + f'{np.abs(feh):1.2f}'
#     219     #for iso_file in iso_files:
#    (...)
#     226         #             new_cols_needed.append(col)
#     227         # else:
#     228     m_h = np.log10(self.evolution_model.z_list[i] / self.evolution_model.z_solar)
# --> 229     isochrones[feh] = self.generate_isochrones(feh, m_h)
#     230         #     iso_tmp.to_hdf(fname, key='iso')
#     233 return pandas.concat(isochrones.values())
#
# File ~/Documents/synthpop/synthpop/modules/evolution/spisea_iso.py:177, in SpiseaIso.generate_isochrones(self, feh, m_h)
#     175 for log_age in self.log_age_list:
#     176     print(m_h)
# --> 177     iso_tmp = synthetic.IsochronePhot(log_age, 0.0, 10.0, metallicity=m_h,
#     178                     evo_model=self.evolution_model,
#     179                     atm_func=self.atm_func,
#     180                     red_law=self.red_law,
#     181                     filters=calc_filters,
#     182                     iso_dir=self.FOLDER+'/tmp/',
#     183                     recomp=True).points
#     184     iso_tmp['log10_isochrone_age_yr']=log_age
#     185     isos_tmp.append(iso_tmp.to_pandas())
#
# File ~/Documents/spisea/spisea/synthetic.py:999, in IsochronePhot.__init__(self, logAge, AKs, distance, metallicity, evo_model, atm_func, wd_atm_func, wave_range, red_law, mass_sampling, iso_dir, min_mass, max_mass, rebin, recomp, filters)
#     997 if (not file_exists) | (recomp==True):
#     998     self.recalc = True
# --> 999     Isochrone.__init__(self, logAge, AKs, distance,
#    1000                        metallicity=metallicity,
#    1001                        evo_model=evo_model, atm_func=atm_func,
#    1002                        wd_atm_func=wd_atm_func,
#    1003                        wave_range=wave_range,
#    1004                        red_law=red_law, mass_sampling=mass_sampling,
#    1005                        min_mass=min_mass, max_mass=max_mass, rebin=rebin)
#    1006     self.verbose = True
#    1008     # Make photometry
#
# File ~/Documents/spisea/spisea/synthetic.py:792, in Isochrone.__init__(self, logAge, AKs, distance, metallicity, evo_model, atm_func, wd_atm_func, red_law, mass_sampling, wave_range, min_mass, max_mass, rebin)
#     789     star = wd_atm_func(temperature=T, gravity=gravity, metallicity=metallicity,
#     790                            verbose=False)
#     791 else:
# --> 792     star = atm_func(temperature=T, gravity=gravity, metallicity=metallicity,
#     793                         rebin=rebin)
#     795 # Trim wavelength range down to JHKL range (0.5 - 5.2 microns)
#     796 star = spectrum.trimSpectrum(star, wave_range[0], wave_range[1])
#
# File ~/Documents/spisea/spisea/atmospheres.py:857, in get_merged_atmosphere(metallicity, temperature, gravity, verbose, rebin)
#     855     if verbose:
#     856         print( 'ATLAS/Phoenix merged atmosphere')
# --> 857     return get_atlas_phoenix_atmosphere(metallicity=metallicity,
#     858                                     temperature=temperature,
#     859                                     gravity=gravity)
#     861 if (temperature >= 5500) & (temperature < 20000):
#     862     if verbose:
#
# File ~/Documents/spisea/spisea/atmospheres.py:690, in get_atlas_phoenix_atmosphere(metallicity, temperature, gravity)
#     687     sp = pysynphot.Icat('merged_atlas_phoenix', temperature, metallicity, gravity)
#     688 except:
#     689     # Check atmosphere catalog bounds
# --> 690     (temperature, gravity, metallicity) = get_atmosphere_bounds('merged_atlas_phoenix',
#     691                                                metallicity=metallicity,
#     692                                                temperature=temperature,
#     693                                                gravity=gravity)
#     695     sp = pysynphot.Icat('merged_atlas_phoenix', temperature, metallicity, gravity)
#     697 # Do some error checking
#
# File ~/Documents/spisea/spisea/atmospheres.py:41, in get_atmosphere_bounds(model_dir, metallicity, temperature, gravity, dZ_limit)
#      39 metallicity_new = metal_list[metal_idx]
#      40 if np.min(np.abs(metal_list - metallicity)) > dZ_limit:
# ---> 41     raise ValueError("Metallicity value "+str(metallicity)+" not within dZ_limit="+str(dZ_limit)+
#      42         " of valid metallicity value (range: "+str(np.min(metal_list))+" - "+str(np.max(metal_list))+").")
#      44 z_filt = np.where(z_arr == metal_list[metal_idx])
#      45 teff_arr = teff_arr[z_filt]
#
# ValueError: Metallicity value -4.0061603087048185 not within dZ_limit=0.5 of valid metallicity value (range: -2.5 - 0.5).

# %%
import json
import pysynphot
from spisea import synthetic

# %%
with open('synthpop/modules/evolution/spisea_filters.json') as f:
    d = json.load(f)

# %%
def do_filts(sys,flts):
    efflamsi = {}
    for flt in flts:
            flt_name = sys+','+flt
            filt = synthetic.get_filter_info(flt_name)
            obs = pysynphot.Observation(pysynphot.Vega, filt).efflam()
            assert str(filt.waveunits) == 'angstrom'
            efflamsi[flt_name.replace(',','-')] = obs*1e-4
    return efflamsi

efflams = {}
for sys in d:
    flts = d[sys]
    if isinstance(flts,dict):
        for subsys in flts:
            efflams.update(do_filts(sys+','+subsys,flts[subsys]))
    else:
        efflams.update(do_filts(sys,flts))
# Out:
# (2MASS_J) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (2MASS_H) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (2MASS_Ks) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ctio_osiris_H) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ctio_osiris_K) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (decam_u) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (decam_g) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (decam_r) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (decam_i) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (decam_z) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (decam_y) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (gaia_dr2_rev_Gbp) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (hawki_J) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (hawki_H) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (hawki_Ks) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f218w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f225w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f275w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f280n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f336w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f343n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f373n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f390m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f390w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f395n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f410m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f438w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f467m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f469n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f487n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f502n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f621m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f631n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f645n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f656n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f657n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f658n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f665n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f673n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f680n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f689m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f763m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f845m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,f953n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq232n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq243n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq378n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq387n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq422m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq436n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq437n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq492n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq508n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq575n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq619n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq634n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq672n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq674n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq727n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq750n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq889n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq906n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq924n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis1,fq937n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f218w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f225w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f275w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f280n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f336w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f343n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f373n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f390m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f390w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f395n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f410m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f438w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f467m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f469n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f487n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f502n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f621m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f631n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f645n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f656n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f657n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f658n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f665n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f673n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f680n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f689m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f763m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f845m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,f953n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq232n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq243n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq378n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq387n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq422m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq436n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq437n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq492n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq508n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq575n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq619n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq634n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq672n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq674n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq727n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq750n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq889n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq906n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq924n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,uvis2,fq937n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,ir,f098m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,ir,f105w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,ir,f110w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,ir,f125w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,ir,f126n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,ir,f127m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,ir,f128n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,ir,f130n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,ir,f132n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,ir,f139m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,ir,f140w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,ir,f153m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,ir,f160w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,ir,f164n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (wfc3,ir,f167n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,hrc,f344n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,hrc,f435w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,hrc,f502n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,hrc,f550m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,hrc,f658n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,hrc,f660n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,hrc,f892n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,sbc,f115lp) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,sbc,f125lp) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,sbc,f140lp) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,sbc,f150lp) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,sbc,f165lp) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,sbc,f122m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,wfc1,f435w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,wfc1,f502n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,wfc1,f550m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,wfc1,f658n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,wfc1,f660n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,wfc1,f892n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,wfc2,f435w) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,wfc2,f502n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,wfc2,f550m) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,wfc2,f658n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,wfc2,f660n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (acs,wfc2,f892n) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ubv_U) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ubv_B) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ubv_V) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ubv_R) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ubv_I) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jg_J) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jg_H) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jg_K) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F070W) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F090W) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F115W) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F140M) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F150W) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F162M) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F164N) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F182M) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F187N) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F200W) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F210M) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F212N) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F250M) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F277W) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F300M) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F322W2) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F323N) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F335M) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F356W) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F360M) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F405N) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F410M) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F430M) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F444W) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F460M) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F466N) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F470N) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (jwst_F480M) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (nirc1_H) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (nirc1_K) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (NIRC2_J) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (NIRC2_H) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (NIRC2_Ks) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (NIRC2_Kcont) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (NIRC2_Ms) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (NIRC2_Brgamma) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (NIRC2_FeII) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (naco_J) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (naco_H) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (naco_Ks) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ps1_g) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ps1_r) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ps1_i) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ps1_z) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ps1_y) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/Users/mhuston/NotBacked/spisea_data/cdbs/comp/nonhst/roman_wfi_f062_003_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/Users/mhuston/NotBacked/spisea_data/cdbs/comp/nonhst/roman_wfi_f087_003_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/Users/mhuston/NotBacked/spisea_data/cdbs/comp/nonhst/roman_wfi_f106_003_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/Users/mhuston/NotBacked/spisea_data/cdbs/comp/nonhst/roman_wfi_f129_003_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/Users/mhuston/NotBacked/spisea_data/cdbs/comp/nonhst/roman_wfi_f158_003_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/Users/mhuston/NotBacked/spisea_data/cdbs/comp/nonhst/roman_wfi_f146_003_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/Users/mhuston/NotBacked/spisea_data/cdbs/comp/nonhst/roman_wfi_f184_003_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/Users/mhuston/NotBacked/spisea_data/cdbs/comp/nonhst/roman_wfi_f213_002_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ukirt_J) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ukirt_H) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ukirt_K) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (rubin_u) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (rubin_z) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (VISTA_Z) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (VISTA_Y) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (VISTA_J) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (VISTA_H) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (VISTA_Ks) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (UnnamedArrayBandpass) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (ztf_i) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.

# %%
# Serializing json
json_object = json.dumps(efflams, indent=4)

# Writing to sample.json
with open("/Users/mhuston/Documents/synthpop/synthpop/config_files/AAA_effective_wavelengths_spisea.json", "w") as outfile:
    outfile.write(json_object)
